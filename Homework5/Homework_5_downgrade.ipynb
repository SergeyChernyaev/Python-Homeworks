# %% [markdown]
# ### Задание 1
# Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# {‘1840e0b9d4’: ‘Продукты’, …}

# %%
import json
purchases = {}
freq={}
with open('purchase_log.txt', encoding='utf-8') as f: # открыть безопасно в нужной кодировке
    for i, line in enumerate(f):
        data = json.loads(line) # преобразуем строку в словарь
        
        purchases.setdefault(data['user_id'], [])
        purchases[data['user_id']].append(data['category'])
        if data['user_id'] in purchases:
                if data['user_id'] != 'user_id':
                    freq.setdefault(data['user_id'], 0)
                    # d.setdefault(j, []).append(i)
                    freq[data['user_id']] += 1

f.close()    
#for i, item in enumerate(purchases.items()):            
#    print(i, item[0],item[1], len (item[1]))
    #if len(item[1]) > 20:
     #   print(i, item, len (item[1]))
   # if i > 4:
   #     break
i = 0        
for key, item in freq.items():
    if item > 1:
        print (i,key,item)
        print (purchases[key])
        i += 1
print ('Количество неуникальных лидов:', i)
# Out:
# 0 c9d93ee37c 2
# ['Продукты', 'Электроника']
# 1 6cd9581955 2
# ['Досуг', 'Электроника']
# 2 735284e60a 2
# ['Электроника', 'Бытовая техника']
# 3 66eb0896dd 2
# ['Электроника', 'Продукты']
# 4 2b95759653 2
# ['Электроника', 'Досуг']
# 5 c128f25790 2
# ['Электроника', 'Продукты']
# 6 8db7dee4e5 2
# ['Досуг', 'Бытовая техника']
# 7 eac6f49767 2
# ['Продукты', 'Бытовая техника']
# 8 0f67a45667 2
# ['Бытовая техника', 'Электроника']
# 9 79ccbb3fd4 2
# ['Электроника', 'Бытовая техника']
# 10 a0e85fc020 2
# ['Строительство и ремонт', 'Электроника']
# 11 6e221b2eab 2
# ['Досуг', 'Досуг']
# 12 6aed364e68 2
# ['Бытовая техника', 'Строительство и ремонт']
# 13 770e3f3085 2
# ['Электроника', 'Досуг']
# 14 6f24969f4e 2
# ['Электроника', 'Строительство и ремонт']
# 15 fb08911f55 2
# ['Бытовая техника', 'Продукты']
# 16 547851f4ed 2
# ['не определена', 'Бытовая техника']
# 17 c820a4e067 2
# ['Досуг', 'Электроника']
# 18 d7591f155d 2
# ['Бытовая техника', 'Продукты']
# 19 a83a4f090b 2
# ['Досуг', 'Электроника']
# 20 db80c3347c 2
# ['Досуг', 'Бытовая техника']
# 21 e730f09bcb 2
# ['Продукты', 'Товары для животных']
# 22 794873db83 2
# ['Электроника', 'Бытовая техника']
# 23 1e9ee03024 2
# ['Электроника', 'Досуг']
# 24 238f528dc6 2
# ['Электроника', 'Продукты']
# 25 b8f32aa7ad 2
# ['Продукты', 'Строительство и ремонт']
# 26 ecbdc12a05 2
# ['Электроника', 'Бытовая техника']
# 27 96fe9c94d7 2
# ['Бытовая техника', 'Бытовая техника']
# 28 50b55c40b8 2
# ['Электроника', 'Досуг']
# 29 444fada9b3 2
# ['Строительство и ремонт', 'Электроника']
# 30 eeafac5e9b 2
# ['Досуг', 'Досуг']
# 31 b5e80971bc 2
# ['Бытовая техника', 'Бытовая техника']
# 32 e58b133dd1 2
# ['Товары для животных', 'Досуг']
# 33 8183284984 2
# ['Электроника', 'Строительство и ремонт']
# 34 14603f630f 2
# ['Электроника', 'Бытовая техника']
# 35 9026563a44 2
# ['Бытовая техника', 'Электроника']
# 36 4d5cb41fbe 2
# ['Досуг', 'Бытовая техника']
# 37 def665bbd8 2
# ['Электроника', 'Товары для животных']
# 38 d1a8fe7183 2
# ['Электроника', 'Строительство и ремонт']
# 39 74181d6746 2
# ['Бытовая техника', 'Продукты']
# 40 18b309cbcd 2
# ['Строительство и ремонт', 'Продукты']
# 41 1eff221952 2
# ['Досуг', 'Бытовая техника']
# 42 dcb5222249 2
# ['Электроника', 'Продукты']
# 43 765f971255 2
# ['Продукты', 'Продукты']
# 44 a20a98d263 2
# ['Бытовая техника', 'Досуг']
# 45 02fd760e37 2
# ['Бытовая техника', 'Строительство и ремонт']
# 46 c5579186cf 2
# ['Электроника', 'Электроника']
# 47 2eab7b4a9e 2
# ['Электроника', 'Бытовая техника']
# 48 1a4ca1f65f 2
# ['Товары для животных', 'Электроника']
# 49 ee21044266 2
# ['Электроника', 'Строительство и ремонт']
# 50 21ba796cce 2
# ['Бытовая техника', 'Продукты']
# 51 7e57837b0e 2
# ['Строительство и ремонт', 'Бытовая техника']
# 52 d8591ff67e 2
# ['Продукты', 'Досуг']
# 53 79c54b84f5 2
# ['Электроника', 'Товары для животных']
# 54 1a05a78802 2
# ['Бытовая техника', 'Электроника']
# 55 6306e5fb9a 2
# ['Бытовая техника', 'Бытовая техника']
# 56 cb27698837 2
# ['Электроника', 'Продукты']
# 57 184a8f0bcd 2
# ['Досуг', 'Бытовая техника']
# 58 a33eee80c0 2
# ['Досуг', 'Бытовая техника']
# 59 f88d3da3bc 2
# ['Бытовая техника', 'Строительство и ремонт']
# 60 f6b1100ecf 2
# ['Электроника', 'Строительство и ремонт']
# 61 d40bd96c68 2
# ['Бытовая техника', 'Электроника']
# 62 20d4693ccd 2
# ['Электроника', 'Досуг']
# 63 a9da271104 2
# ['Товары для животных', 'Продукты']
# 64 24a24098c6 2
# ['Бытовая техника', 'Электроника']
# 65 0748b57ac8 2
# ['Электроника', 'Электроника']
# 66 bd001fe274 2
# ['Досуг', 'Бытовая техника']
# 67 6e2f9d4968 2
# ['Бытовая техника', 'Бытовая техника']
# 68 3672ab3fea 2
# ['Товары для животных', 'Электроника']
# 69 ba4d099c83 2
# ['Досуг', 'Бытовая техника']
# 70 b558a90cf6 2
# ['Досуг', 'Досуг']
# 71 cc9324c31f 2
# ['Бытовая техника', 'Электроника']
# 72 0061aaf3f9 2
# ['Продукты', 'Электроника']
# 73 de3b7b155e 2
# ['Продукты', 'Досуг']
# 74 3f6034ec71 2
# ['Строительство и ремонт', 'Досуг']
# 75 46a48fd576 2
# ['не определена', 'Бытовая техника']
# 76 956eae8fe4 2
# ['Бытовая техника', 'Электроника']
# 77 fd3c2d449c 2
# ['Бытовая техника', 'Строительство и ремонт']
# 78 b8daff067e 2
# ['Бытовая техника', 'Продукты']
# 79 654350d700 2
# ['Продукты', 'Электроника']
# 80 802536eb05 2
# ['Продукты', 'Бытовая техника']
# 81 e583bd2f96 2
# ['Бытовая техника', 'Продукты']
# 82 d2cb888065 2
# ['Бытовая техника', 'Электроника']
# 83 11fa982535 2
# ['Бытовая техника', 'Строительство и ремонт']
# 84 afa9bd8942 2
# ['Бытовая техника', 'Электроника']
# 85 d1d4481e5e 2
# ['Досуг', 'Продукты']
# 86 3023e173f7 2
# ['Досуг', 'Товары для животных']
# 87 e54babf03f 2
# ['Электроника', 'Товары для животных']
# 88 47a781511f 2
# ['Электроника', 'Электроника']
# 89 1ced7d3a08 2
# ['Продукты', 'Электроника']
# 90 4f55d96938 2
# ['Бытовая техника', 'Бытовая техника']
# 91 632432ceba 2
# ['Электроника', 'Строительство и ремонт']
# 92 34299edc11 2
# ['Бытовая техника', 'Строительство и ремонт']
# 93 548be9b909 2
# ['Продукты', 'Электроника']
# 94 5bec46baa6 2
# ['Бытовая техника', 'Продукты']
# 95 c18137bc4b 2
# ['Электроника', 'Продукты']
# 96 110f74ec1c 2
# ['Досуг', 'Бытовая техника']
# 97 b52ec5a611 2
# ['Продукты', 'Электроника']
# 98 c25f1c323f 2
# ['Электроника', 'Электроника']
# 99 7d38b7ca2a 2
# ['Бытовая техника', 'Продукты']
# 100 3b95494065 2
# ['Товары для животных', 'Бытовая техника']
# 101 a261006f7d 2
# ['Строительство и ремонт', 'Бытовая техника']
# 102 c9150cf5bd 2
# ['Электроника', 'Электроника']
# 103 b0c9fbb51d 2
# ['Бытовая техника', 'Продукты']
# 104 a996358fad 2
# ['Бытовая техника', 'Досуг']
# 105 b56f30981f 2
# ['Бытовая техника', 'Бытовая техника']
# 106 e1e38aaf20 2
# ['Досуг', 'Бытовая техника']
# 107 2aa2000e5c 2
# ['Электроника', 'Электроника']
# 108 02ce3f6ba4 2
# ['Досуг', 'Бытовая техника']
# 109 a732f7f1fc 2
# ['Строительство и ремонт', 'Строительство и ремонт']
# 110 f4348b19ae 2
# ['Досуг', 'Досуг']
# 111 fb45c1ec25 2
# ['Строительство и ремонт', 'Товары для животных']
# 112 bebf3c893b 2
# ['Электроника', 'Бытовая техника']
# 113 8e72f03f2d 2
# ['Строительство и ремонт', 'Электроника']
# 114 ffb4426f85 2
# ['Досуг', 'Электроника']
# 115 80fd44e819 2
# ['Электроника', 'Электроника']
# 116 1454768cb5 2
# ['Товары для животных', 'Строительство и ремонт']
# 117 af398954ef 2
# ['не определена', 'Бытовая техника']
# 118 47c57bc8b3 2
# ['Бытовая техника', 'Электроника']
# 119 31d965acee 2
# ['Электроника', 'Досуг']
# 120 323c146023 2
# ['Товары для животных', 'Бытовая техника']
# 121 254508ea14 2
# ['Продукты', 'Строительство и ремонт']
# 122 b9dac24e71 2
# ['Продукты', 'Досуг']
# 123 4b462d5b26 2
# ['Продукты', 'Продукты']
# 124 0c80bacc1d 2
# ['Электроника', 'Строительство и ремонт']
# 125 10664afadb 2
# ['Бытовая техника', 'Бытовая техника']
# 126 2ace88ec4e 2
# ['Товары для животных', 'Бытовая техника']
# 127 1d93a3bbc9 2
# ['Электроника', 'Бытовая техника']
# 128 ae0a638508 2
# ['Электроника', 'Электроника']
# 129 1a2861c914 2
# ['Продукты', 'Бытовая техника']
# 130 2b0b866926 2
# ['Электроника', 'Электроника']
# 131 7411b8c3b0 2
# ['Строительство и ремонт', 'Электроника']
# 132 db69883971 2
# ['Электроника', 'Товары для животных']
# 133 d7531a88e6 2
# ['Продукты', 'Электроника']
# 134 38d802df81 2
# ['Бытовая техника', 'Бытовая техника']
# 135 7b3d30d2e5 2
# ['Бытовая техника', 'Электроника']
# 136 d39014b20f 2
# ['Досуг', 'Бытовая техника']
# 137 773888ae96 2
# ['Бытовая техника', 'Электроника']
# 138 e881b44e58 2
# ['Бытовая техника', 'Продукты']
# 139 d205f39e2f 2
# ['Электроника', 'Электроника']
# 140 e81cd17e7c 2
# ['Строительство и ремонт', 'Электроника']
# 141 9485ace004 2
# ['Досуг', 'Досуг']
# 142 19f240d84b 2
# ['Электроника', 'Досуг']
# 143 838e2a42d6 2
# ['Досуг', 'Бытовая техника']
# 144 65a1393165 2
# ['Электроника', 'Строительство и ремонт']
# 145 5e5acc9250 2
# ['Бытовая техника', 'Бытовая техника']
# 146 210a0baf36 2
# ['Продукты', 'Бытовая техника']
# 147 864582371f 2
# ['Товары для животных', 'Электроника']
# 148 5a1c92b8a0 2
# ['Досуг', 'Продукты']
# 149 3a97258c77 2
# ['Товары для животных', 'Электроника']
# 150 4e618112f0 2
# ['Электроника', 'Строительство и ремонт']
# 151 dd60289c0e 2
# ['Досуг', 'Электроника']
# 152 39d8617b35 2
# ['Продукты', 'не определена']
# 153 99bb13837e 2
# ['Продукты', 'Продукты']
# 154 8c35b6e785 2
# ['Электроника', 'Продукты']
# 155 923847d030 2
# ['Строительство и ремонт', 'Строительство и ремонт']
# 156 8b38740ade 2
# ['Электроника', 'Строительство и ремонт']
# 157 f442992e4b 2
# ['Досуг', 'Досуг']
# 158 f14cd641d2 2
# ['Электроника', 'Электроника']
# 159 8e1e446003 2
# ['Досуг', 'Продукты']
# 160 fbb157a4be 2
# ['Товары для животных', 'Бытовая техника']
# 161 4639930a5d 2
# ['Строительство и ремонт', 'Продукты']
# 162 397b76c1f1 2
# ['Электроника', 'Продукты']
# 163 e8e5ee9214 2
# ['Продукты', 'Строительство и ремонт']
# 164 729721a94a 2
# ['Строительство и ремонт', 'Электроника']
# 165 ce8dede5f5 2
# ['Бытовая техника', 'Продукты']
# 166 d3c6d994bf 2
# ['Электроника', 'Продукты']
# 167 515f9db7c5 2
# ['Бытовая техника', 'Продукты']
# 168 9840c6b3ab 2
# ['Бытовая техника', 'Досуг']
# 169 4433811ba8 2
# ['Бытовая техника', 'Строительство и ремонт']
# 170 207babd4f4 2
# ['Электроника', 'Строительство и ремонт']
# 171 b496ac4422 2
# ['Электроника', 'Бытовая техника']
# 172 e81e6b9798 2
# ['Электроника', 'Электроника']
# 173 7a2681da41 2
# ['Бытовая техника', 'Товары для животных']
# 174 06448dd4a6 2
# ['Строительство и ремонт', 'Электроника']
# 175 1ecbbe2f83 2
# ['Электроника', 'Электроника']
# 176 8e6ce12fda 2
# ['Строительство и ремонт', 'Электроника']
# 177 1212eccd3c 2
# ['Товары для животных', 'Продукты']
# 178 4ec09dbc3f 2
# ['Бытовая техника', 'Электроника']
# 179 2c04c6c8cc 2
# ['Досуг', 'Электроника']
# 180 6f0f91fb34 2
# ['Электроника', 'Продукты']
# 181 8a6983da34 2
# ['Досуг', 'Строительство и ремонт']
# 182 66631c7d2a 2
# ['Электроника', 'Бытовая техника']
# 183 e6b9646b31 2
# ['Продукты', 'Продукты']
# 184 2adcbe3b07 2
# ['Электроника', 'Электроника']
# 185 e27492096e 2
# ['Электроника', 'Бытовая техника']
# 186 ac4b189474 2
# ['Бытовая техника', 'Электроника']
# 187 c3d9c49204 2
# ['Продукты', 'Бытовая техника']
# 188 453e6be0a5 2
# ['Электроника', 'Досуг']
# 189 bf64652fc9 2
# ['Электроника', 'Электроника']
# 190 e44408c06c 2
# ['Продукты', 'Продукты']
# 191 2a5af4a0fa 2
# ['Бытовая техника', 'Строительство и ремонт']
# 192 ce0d61b53c 2
# ['Строительство и ремонт', 'Товары для животных']
# 193 a7d9f1b37a 2
# ['Досуг', 'Продукты']
# 194 b42e0c23d7 2
# ['Продукты', 'Электроника']
# 195 e886d3f270 2
# ['Досуг', 'Бытовая техника']
# 196 c960c48aa2 2
# ['Бытовая техника', 'Товары для животных']
# 197 c6c0a88cc9 2
# ['Бытовая техника', 'Электроника']
# 198 3fe36dee40 2
# ['Товары для животных', 'Строительство и ремонт']
# 199 f97bbdfe1a 2
# ['Бытовая техника', 'Строительство и ремонт']
# 200 e0fa03e0ae 2
# ['Электроника', 'Досуг']
# 201 3743a63831 2
# ['Электроника', 'Электроника']
# 202 2e5e0ad707 2
# ['Бытовая техника', 'Бытовая техника']
# 203 bd9825b36b 2
# ['Электроника', 'Продукты']
# 204 bccf39d61f 2
# ['Товары для животных', 'Строительство и ремонт']
# 205 14f71dfe94 2
# ['Электроника', 'Продукты']
# 206 19c7b13ca8 2
# ['Продукты', 'Электроника']
# 207 09fb80a724 2
# ['Бытовая техника', 'Бытовая техника']
# 208 99c3c6e5a1 2
# ['Досуг', 'Электроника']
# 209 78e6ea28b5 2
# ['Электроника', 'Продукты']
# 210 6d3951a02a 2
# ['Бытовая техника', 'Электроника']
# 211 8752630e1a 2
# ['Продукты', 'Товары для животных']
# 212 ba65b4c95a 2
# ['Продукты', 'Продукты']
# 213 a30dd6734c 2
# ['Электроника', 'Электроника']
# 214 49cd8db664 2
# ['Продукты', 'Электроника']
# 215 aab42382dc 2
# ['Строительство и ремонт', 'Электроника']
# 216 53b11ab165 2
# ['Бытовая техника', 'Продукты']
# 217 76d5ce4e20 2
# ['Товары для животных', 'Электроника']
# 218 44deaa8ec8 2
# ['Электроника', 'Строительство и ремонт']
# 219 15b76d1770 2
# ['Бытовая техника', 'Товары для животных']
# 220 ab483a3116 2
# ['Бытовая техника', 'Электроника']
# 221 42426dce41 2
# ['Досуг', 'Электроника']
# 222 a7a34c5baa 2
# ['Электроника', 'Электроника']
# 223 2dbc7c240f 2
# ['Электроника', 'Электроника']
# 224 2ac4b8c067 2
# ['Электроника', 'Строительство и ремонт']
# 225 79821f7f18 2
# ['Электроника', 'Досуг']
# 226 546ac0be8e 2
# ['Досуг', 'Бытовая техника']
# 227 89e9471a1f 2
# ['не определена', 'Продукты']
# 228 de9ac9dc86 2
# ['Бытовая техника', 'Продукты']
# 229 41f0f1f431 2
# ['Электроника', 'Товары для животных']
# 230 0d864620fa 2
# ['Бытовая техника', 'Электроника']
# 231 f2bd941f91 2
# ['Бытовая техника', 'Электроника']
# 232 3e05ac27c2 2
# ['Электроника', 'Товары для животных']
# 233 72c2495600 2
# ['Продукты', 'Электроника']
# 234 e7895536a9 2
# ['Электроника', 'Бытовая техника']
# 235 231bee9e75 2
# ['Продукты', 'Электроника']
# 236 d68727fb42 2
# ['Электроника', 'Досуг']
# 237 2996d41992 2
# ['Бытовая техника', 'Продукты']
# 238 24786d4e2a 2
# ['Продукты', 'Досуг']
# 239 341fd3cb66 2
# ['Электроника', 'Электроника']
# 240 ec491b688c 2
# ['Продукты', 'Досуг']
# 241 d3e1fcad4a 2
# ['Продукты', 'Электроника']
# 242 cdd73843c6 2
# ['Электроника', 'Электроника']
# 243 c1b4b20fe5 2
# ['Строительство и ремонт', 'Строительство и ремонт']
# 244 29fdf69412 2
# ['Бытовая техника', 'Бытовая техника']
# 245 a18639951d 2
# ['Досуг', 'Досуг']
# 246 564a002c8a 2
# ['Электроника', 'Продукты']
# 247 687f011566 3
# ['Товары для животных', 'Электроника', 'Товары для животных']
# 248 5ecf3e05ab 2
# ['Электроника', 'Электроника']
# 249 d46917db91 2
# ['Электроника', 'Электроника']
# 250 fa803f369e 2
# ['Строительство и ремонт', 'Досуг']
# 251 9f76cee6c2 2
# ['Электроника', 'Электроника']
# 252 03987e7451 2
# ['Электроника', 'Продукты']
# 253 ed8b4aa6c2 2
# ['Строительство и ремонт', 'Электроника']
# 254 097d683f3b 2
# ['Электроника', 'Строительство и ремонт']
# 255 2c15cf1f5a 2
# ['Электроника', 'Продукты']
# 256 80f6e59f68 2
# ['Электроника', 'Электроника']
# 257 3e4ac617e6 2
# ['Продукты', 'Досуг']
# 258 7a1dd1f6a2 2
# ['Товары для животных', 'Товары для животных']
# 259 0466a803d0 2
# ['Бытовая техника', 'Продукты']
# 260 6815c9f892 2
# ['Досуг', 'Электроника']
# 261 6f55fd90d4 2
# ['Электроника', 'Строительство и ремонт']
# 262 41118e7b49 2
# ['Электроника', 'Электроника']
# 263 60ac929f57 2
# ['Бытовая техника', 'Бытовая техника']
# 264 b4ed8f3250 2
# ['Досуг', 'Досуг']
# 265 f4dde5ff04 2
# ['Досуг', 'Продукты']
# 266 a5f6b7ee81 2
# ['Электроника', 'Досуг']
# 267 43e4a7de00 2
# ['Продукты', 'Досуг']
# 268 314814c500 2
# ['Электроника', 'Продукты']
# 269 67f2938e5d 2
# ['Продукты', 'Продукты']
# 270 b2e104bbee 2
# ['Бытовая техника', 'Бытовая техника']
# 271 a24edc5224 2
# ['Электроника', 'Досуг']
# 272 b77bd86c8f 2
# ['Товары для животных', 'Бытовая техника']
# 273 df0261aa00 2
# ['Электроника', 'Бытовая техника']
# 274 9374206f00 2
# ['Продукты', 'Электроника']
# 275 c3f238b983 2
# ['Электроника', 'Электроника']
# 276 8be423eb10 2
# ['Бытовая техника', 'Досуг']
# 277 82e8d8aa7c 2
# ['Электроника', 'Строительство и ремонт']
# 278 6a433d9bad 2
# ['Электроника', 'Бытовая техника']
# 279 a294d53937 2
# ['Электроника', 'Электроника']
# 280 7ab91d4cbd 2
# ['Электроника', 'Бытовая техника']
# 281 4db125fc4f 2
# ['Бытовая техника', 'Товары для животных']
# 282 b8017b7471 2
# ['Досуг', 'Электроника']
# 283 fe94c62069 2
# ['Электроника', 'Бытовая техника']
# 284 b085c894a2 2
# ['Бытовая техника', 'Электроника']
# 285 e567cc4282 2
# ['Электроника', 'Бытовая техника']
# 286 3525f293ea 2
# ['Электроника', 'Строительство и ремонт']
# 287 4afc837b3f 2
# ['Электроника', 'Строительство и ремонт']
# 288 ed4177f629 2
# ['Бытовая техника', 'Продукты']
# 289 b45949f759 2
# ['Бытовая техника', 'Строительство и ремонт']
# 290 a24b800b81 2
# ['Электроника', 'Электроника']
# 291 a6bc29362a 2
# ['Бытовая техника', 'Досуг']
# 292 cd736575df 2
# ['Строительство и ремонт', 'Продукты']
# 293 cab28642f8 2
# ['Электроника', 'Досуг']
# 294 1b6d41a7b5 2
# ['Досуг', 'Продукты']
# 295 f966a1ccd5 2
# ['Бытовая техника', 'Продукты']
# 296 f15fe41dec 2
# ['Досуг', 'Электроника']
# 297 ffb83955b3 2
# ['Электроника', 'Продукты']
# 298 bf7b5d2ebe 2
# ['Продукты', 'Товары для животных']
# 299 506b61e682 2
# ['Продукты', 'Бытовая техника']
# 300 7b98da590b 2
# ['Досуг', 'Досуг']
# 301 b334fceb9e 2
# ['Строительство и ремонт', 'Продукты']
# 302 d7149a3281 2
# ['Досуг', 'Электроника']
# 303 ba60027bcb 2
# ['Электроника', 'Электроника']
# 304 f44e6e8f9c 2
# ['Электроника', 'Электроника']
# 305 758cb84f4a 2
# ['Бытовая техника', 'Товары для животных']
# 306 2e0646f421 2
# ['Электроника', 'Бытовая техника']
# 307 560da7c770 2
# ['Электроника', 'Электроника']
# 308 689253b114 2
# ['Бытовая техника', 'Электроника']
# 309 64842ee9cf 2
# ['не определена', 'Товары для животных']
# 310 927072544a 2
# ['Досуг', 'Электроника']
# 311 53c0d53386 2
# ['Электроника', 'Досуг']
# 312 eaa44d0262 2
# ['Электроника', 'Продукты']
# 313 4caec716fc 2
# ['Электроника', 'Бытовая техника']
# 314 faaca82798 2
# ['Электроника', 'Электроника']
# 315 9f6b7d8833 2
# ['Электроника', 'Досуг']
# 316 e883729daa 2
# ['Электроника', 'Продукты']
# 317 f202136bfd 2
# ['Бытовая техника', 'Строительство и ремонт']
# 318 b170e9323e 2
# ['Электроника', 'Строительство и ремонт']
# 319 b8245c1596 2
# ['Товары для животных', 'Бытовая техника']
# 320 ae735e3a76 2
# ['не определена', 'Досуг']
# 321 191d0fff0e 2
# ['Строительство и ремонт', 'Товары для животных']
# 322 cd1447abed 2
# ['Досуг', 'Электроника']
# 323 983f7544d3 2
# ['Электроника', 'Бытовая техника']
# 324 d8c9a62d20 2
# ['Электроника', 'Электроника']
# 325 dde8397ea8 2
# ['Досуг', 'Продукты']
# 326 c9c0e9f96f 2
# ['Электроника', 'Бытовая техника']
# 327 e597b4c3a4 2
# ['Досуг', 'Бытовая техника']
# 328 03787309eb 2
# ['Строительство и ремонт', 'Электроника']
# 329 159f7237b0 2
# ['Товары для животных', 'Электроника']
# 330 dcaf633914 2
# ['Электроника', 'Досуг']
# 331 e72ff07aa4 2
# ['Досуг', 'Продукты']
# 332 d2a1a47f44 2
# ['Продукты', 'Продукты']
# 333 5bb8cc4ca7 2
# ['Досуг', 'Продукты']
# 334 e9f1e288da 2
# ['Строительство и ремонт', 'Бытовая техника']
# 335 a6ba61f6c5 2
# ['Бытовая техника', 'Бытовая техника']
# 336 09a1e8b696 2
# ['Электроника', 'Электроника']
# 337 b8e3882f17 2
# ['Досуг', 'Товары для животных']
# 338 90001f724e 2
# ['Электроника', 'Бытовая техника']
# 339 b72089f1d3 2
# ['Досуг', 'Электроника']
# 340 8b931a5d8d 2
# ['Электроника', 'Электроника']
# 341 2d9364f231 2
# ['Товары для животных', 'Бытовая техника']
# 342 ba32b9e250 2
# ['Электроника', 'Электроника']
# 343 47b449e80a 2
# ['Строительство и ремонт', 'Бытовая техника']
# 344 7851140b7e 2
# ['Бытовая техника', 'Бытовая техника']
# 345 89d29f76f4 2
# ['Электроника', 'Электроника']
# 346 98aa1ada30 2
# ['Электроника', 'Электроника']
# 347 4f0313df2d 2
# ['Электроника', 'Досуг']
# 348 dd9bed600f 2
# ['Бытовая техника', 'Бытовая техника']
# 349 ba1adc1011 2
# ['Бытовая техника', 'Бытовая техника']
# 350 9d2390dff0 2
# ['Строительство и ремонт', 'Товары для животных']
# 351 04afabb984 2
# ['Продукты', 'Электроника']
# 352 85a73b9d2a 2
# ['Бытовая техника', 'Продукты']
# 353 96e506b229 2
# ['Электроника', 'Продукты']
# 354 ffd34380bc 2
# ['Электроника', 'Бытовая техника']
# 355 1e67abcd85 2
# ['Электроника', 'Продукты']
# 356 908ee50c64 2
# ['Товары для животных', 'Бытовая техника']
# 357 0938049467 2
# ['Товары для животных', 'Электроника']
# 358 6a67d38042 2
# ['Строительство и ремонт', 'Электроника']
# 359 b7174ac76c 2
# ['Бытовая техника', 'Бытовая техника']
# 360 241359766f 2
# ['Электроника', 'Бытовая техника']
# 361 a2f2a8df0d 2
# ['Товары для животных', 'Досуг']
# 362 0d38211101 2
# ['Товары для животных', 'Строительство и ремонт']
# 363 f6ec4a4955 2
# ['Товары для животных', 'Бытовая техника']
# 364 7b59109bc6 2
# ['Строительство и ремонт', 'Бытовая техника']
# 365 3e571d0db7 2
# ['Электроника', 'Товары для животных']
# 366 e615233d0e 2
# ['Продукты', 'Товары для животных']
# 367 0a255e1e1a 2
# ['Бытовая техника', 'Строительство и ремонт']
# 368 cf96beeb0c 2
# ['Строительство и ремонт', 'Электроника']
# 369 225e9cb569 2
# ['Электроника', 'Досуг']
# 370 cc847e75fd 2
# ['Электроника', 'Электроника']
# 371 e9dfbaaa0a 2
# ['Продукты', 'Электроника']
# 372 f58280f615 2
# ['Досуг', 'Досуг']
# 373 d2cd6791d8 2
# ['Досуг', 'Электроника']
# 374 47874db6c4 2
# ['Электроника', 'Бытовая техника']
# 375 96a42f6fdc 2
# ['Продукты', 'Электроника']
# 376 9ff216bd1d 2
# ['Электроника', 'Продукты']
# 377 efe52c9648 2
# ['Досуг', 'Досуг']
# 378 5302cd44fa 2
# ['Досуг', 'Продукты']
# 379 b9583295a6 2
# ['Досуг', 'Электроника']
# 380 baf6b97021 2
# ['Бытовая техника', 'Бытовая техника']
# 381 87461b2350 2
# ['Бытовая техника', 'Продукты']
# 382 148122c62a 2
# ['Электроника', 'Досуг']
# 383 7207856a97 2
# ['Досуг', 'Электроника']
# 384 8465d437e7 2
# ['Продукты', 'Электроника']
# 385 5fb00ef7e4 2
# ['Бытовая техника', 'Электроника']
# 386 3b883d1a2e 2
# ['Досуг', 'Строительство и ремонт']
# 387 b76c4509c7 2
# ['Товары для животных', 'Электроника']
# 388 f1e60e8605 2
# ['Электроника', 'Электроника']
# 389 7a32f2b4a9 2
# ['Бытовая техника', 'Досуг']
# 390 f6e789e651 2
# ['Досуг', 'Досуг']
# 391 b421a5c721 2
# ['Электроника', 'Бытовая техника']
# 392 0faf7d45e9 2
# ['Электроника', 'Строительство и ремонт']
# 393 f732e583cc 2
# ['Продукты', 'Электроника']
# 394 605fbcb086 2
# ['Досуг', 'Электроника']
# 395 1e6d718770 2
# ['Электроника', 'Бытовая техника']
# 396 d5c214ba7c 2
# ['Продукты', 'Досуг']
# 397 615ae3be6c 2
# ['Строительство и ремонт', 'Электроника']
# 398 7db73a1d9a 2
# ['Строительство и ремонт', 'Электроника']
# 399 1494be9d89 2
# ['Электроника', 'Бытовая техника']
# 400 584c982f2b 2
# ['Электроника', 'Продукты']
# 401 02a3642b58 2
# ['Электроника', 'Строительство и ремонт']
# 402 5afbfd9f9e 2
# ['Электроника', 'Товары для животных']
# 403 7d175bcd3c 2
# ['Бытовая техника', 'Продукты']
# 404 797e17a116 2
# ['Продукты', 'Досуг']
# 405 06f5186ba1 2
# ['Электроника', 'Бытовая техника']
# 406 ce09396b70 2
# ['Досуг', 'Бытовая техника']
# 407 5b60d55040 2
# ['Досуг', 'Продукты']
# 408 03c32ff197 2
# ['Электроника', 'Продукты']
# 409 b5edf4bf0d 2
# ['Бытовая техника', 'Электроника']
# 410 15b6958b46 2
# ['Досуг', 'Бытовая техника']
# 411 c22ad160a0 2
# ['Строительство и ремонт', 'Строительство и ремонт']
# 412 f8e955496a 2
# ['Бытовая техника', 'Товары для животных']
# 413 e4473fd601 2
# ['Досуг', 'Строительство и ремонт']
# 414 74de78a3c7 2
# ['Бытовая техника', 'Продукты']
# 415 ef1e702b02 2
# ['Электроника', 'Электроника']
# 416 7e75186080 2
# ['Товары для животных', 'Продукты']
# 417 f689c7d4d6 2
# ['Электроника', 'Электроника']
# 418 a8f5963a9a 2
# ['Товары для животных', 'Электроника']
# 419 85160dce8b 2
# ['Строительство и ремонт', 'Досуг']
# 420 375fb29597 2
# ['Продукты', 'Электроника']
# 421 5f9413e04d 2
# ['Строительство и ремонт', 'Бытовая техника']
# 422 184558d5b6 2
# ['Продукты', 'Бытовая техника']
# 423 ab1654edf8 2
# ['Электроника', 'Товары для животных']
# 424 48ed2c753e 2
# ['Бытовая техника', 'Электроника']
# 425 4383eb3939 2
# ['Бытовая техника', 'Электроника']
# 426 cd63e90f9b 2
# ['Электроника', 'Продукты']
# 427 f762d95d53 2
# ['Продукты', 'Электроника']
# 428 d7f4b08b4e 2
# ['Продукты', 'Строительство и ремонт']
# 429 a6ce5b4f9b 2
# ['Электроника', 'Электроника']
# 430 4402fef3bf 2
# ['Бытовая техника', 'Строительство и ремонт']
# 431 9a9899d15a 2
# ['Продукты', 'Бытовая техника']
# 432 dcb49f52f1 2
# ['Товары для животных', 'Досуг']
# 433 f773d5b627 2
# ['Бытовая техника', 'Бытовая техника']
# 434 84b9dd5247 2
# ['Продукты', 'Досуг']
# 435 ec099caba6 2
# ['Бытовая техника', 'Электроника']
# 436 bd6af0e970 2
# ['Бытовая техника', 'Досуг']
# 437 4a75e860b8 2
# ['Досуг', 'Досуг']
# 438 a4babb56db 2
# ['Электроника', 'Продукты']
# 439 f5aa732e7b 2
# ['Строительство и ремонт', 'Бытовая техника']
# 440 87b4db965a 2
# ['Электроника', 'Бытовая техника']
# 441 dd3b425657 2
# ['Бытовая техника', 'Бытовая техника']
# 442 6064efbf8d 2
# ['Электроника', 'Досуг']
# 443 5ffac0d49b 2
# ['Продукты', 'Строительство и ремонт']
# 444 1ed6708a27 2
# ['Электроника', 'Досуг']
# 445 5185036892 2
# ['Электроника', 'Строительство и ремонт']
# 446 60dcb47324 2
# ['Строительство и ремонт', 'Продукты']
# 447 275dc83a98 2
# ['Продукты', 'Электроника']
# 448 9af28baad9 2
# ['Бытовая техника', 'Досуг']
# 449 0c1063d977 2
# ['Продукты', 'Строительство и ремонт']
# 450 486e0845fa 2
# ['Продукты', 'Товары для животных']
# 451 eea8a7dd03 2
# ['Бытовая техника', 'Товары для животных']
# 452 546a54e7a7 2
# ['Досуг', 'Электроника']
# 453 0410aa6599 2
# ['Бытовая техника', 'Товары для животных']
# 454 8e959cad08 2
# ['Электроника', 'Электроника']
# 455 6ad0538fd6 2
# ['Строительство и ремонт', 'Бытовая техника']
# 456 a5ec64938f 2
# ['Электроника', 'Бытовая техника']
# 457 3c36d2bd19 2
# ['Электроника', 'Строительство и ремонт']
# 458 9146f7295c 2
# ['Досуг', 'Продукты']
# 459 8247caa729 2
# ['Электроника', 'Бытовая техника']
# 460 6932f2f715 2
# ['Бытовая техника', 'Продукты']
# 461 7dfe8b53a7 2
# ['Электроника', 'Электроника']
# 462 bca8e2d204 2
# ['Электроника', 'Электроника']
# 463 14d4abf7b1 2
# ['Электроника', 'Электроника']
# 464 928e57af5d 2
# ['Товары для животных', 'Электроника']
# 465 a93b956d56 2
# ['Бытовая техника', 'Электроника']
# 466 871b512f09 2
# ['Строительство и ремонт', 'Товары для животных']
# 467 a7ff399958 2
# ['Электроника', 'Товары для животных']
# 468 6cfcb06cdd 2
# ['Строительство и ремонт', 'Электроника']
# 469 dedbfbec91 2
# ['Электроника', 'Бытовая техника']
# 470 e84ebcdd10 2
# ['Электроника', 'Бытовая техника']
# 471 696ecb19b6 2
# ['Досуг', 'Досуг']
# 472 74045c8dcd 2
# ['Электроника', 'Электроника']
# 473 4035a1e111 2
# ['Строительство и ремонт', 'Досуг']
# 474 d76191aefb 2
# ['Продукты', 'Электроника']
# 475 a5faa03d45 2
# ['не определена', 'Бытовая техника']
# 476 c7e1501398 2
# ['Досуг', 'Продукты']
# 477 23ce883d8d 2
# ['Электроника', 'Досуг']
# 478 25f0532946 2
# ['Строительство и ремонт', 'Строительство и ремонт']
# 479 be8bbc4d87 2
# ['Электроника', 'Бытовая техника']
# 480 d5c59248c4 2
# ['Продукты', 'Электроника']
# Количество неуникальных лидов: 481

# %% [markdown]
# # Задание 2
# Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.

# %%
import pandas as pd
import json
import numpy as np
purchases = {}

f_visit = open('visit_log.csv', encoding='utf-8')  
f_funnel = open ('funnel.csv', 'w', encoding='utf-8')

with open('purchase_log.txt', encoding='utf-8') as f_purchase: # открыть безопасно в нужной кодировке
# Сделали словарь
     for line in f_purchase:
        data = json.loads(line) # преобразуем строку в словарь
        purchases.setdefault(data['user_id'], [])
        purchases[data['user_id']].append(data['category'])
f_purchase.close()

print (purchases['eac6f49767'])

with open ('funnel.csv', 'w', encoding='utf-8') as f_funnel: # открыть безопасно на запись воронку в нужной кодировке
# Записать первую строку файла:
    f_funnel.write('user_id,source,category\n')
    
    with open('visit_log.csv', encoding='utf-8') as f_visit:    
        for line in f_visit:    
            line_list = line.strip().split(',')
            if line_list[0] in purchases: # ключ найден и 
                if line_list[0] != 'user_id': # это не название столбца 
                    print ('Ключ найден', line_list[0], purchases[line_list[0]])
                    print ('line_list', line_list, 'Словарь:", purchases[line_list[0]])
                           
                    line_list.append(purchases[line_list[0]])
                    #print (line_list)
                    #print(str(my_list3).strip('[]'))
            # Склеить строку:
                    #str_= str(line_list).strip('[]')
                    #print (str_, len(str_))
            # print ('Строка для записи:', str_)
                    f_funnel.write(str_+'\n')
 
        
f_visit.close()
f_funnel.close()
# Посмотреть датасет:
df = pd.read_csv('funnel.csv')
df.info()
# Out:
# ['Продукты', 'Бытовая техника']
# Ключ найден 1840e0b9d4 ['Продукты']
# line_list ['1840e0b9d4', 'other'] Словарь: ['Продукты']
# ['1840e0b9d4', 'other', ['Продукты']]
# Ключ найден 4e4f90fcfb ['Электроника']
# line_list ['4e4f90fcfb', 'context'] Словарь: ['Электроника']
# ['4e4f90fcfb', 'context', ['Электроника']]
# Ключ найден afea8d72fc ['Электроника']
# line_list ['afea8d72fc', 'other'] Словарь: ['Электроника']
# ['afea8d72fc', 'other', ['Электроника']]
# Ключ найден 2824221f38 ['Продукты']
# line_list ['2824221f38', 'email'] Словарь: ['Продукты']
# ['2824221f38', 'email', ['Продукты']]
# Ключ найден 373a6055fe ['Бытовая техника']
# line_list ['373a6055fe', 'other'] Словарь: ['Бытовая техника']
# ['373a6055fe', 'other', ['Бытовая техника']]
# Ключ найден 9b2ab046f3 ['Электроника']
# line_list ['9b2ab046f3', 'other'] Словарь: ['Электроника']
# ['9b2ab046f3', 'other', ['Электроника']]
# Ключ найден 9f39d307c3 ['Электроника']
# line_list ['9f39d307c3', 'context'] Словарь: ['Электроника']
# ['9f39d307c3', 'context', ['Электроника']]
# Ключ найден 44edeffc91 ['Продукты']
# line_list ['44edeffc91', 'context'] Словарь: ['Продукты']
# ['44edeffc91', 'context', ['Продукты']]
# Ключ найден 704474fa2d ['Продукты']
# line_list ['704474fa2d', 'other'] Словарь: ['Продукты']
# ['704474fa2d', 'other', ['Продукты']]
# Ключ найден 1de31be403 ['Бытовая техника']
# line_list ['1de31be403', 'other'] Словарь: ['Бытовая техника']
# ['1de31be403', 'other', ['Бытовая техника']]
# Ключ найден 5da0dedf13 ['Досуг']
# line_list ['5da0dedf13', 'context'] Словарь: ['Досуг']
# ['5da0dedf13', 'context', ['Досуг']]
# Ключ найден b71f36a5e4 ['Продукты']
# line_list ['b71f36a5e4', 'other'] Словарь: ['Продукты']
# ['b71f36a5e4', 'other', ['Продукты']]
# Ключ найден 79843a685a ['Продукты']
# line_list ['79843a685a', 'context'] Словарь: ['Продукты']
# ['79843a685a', 'context', ['Продукты']]
# Ключ найден ff68cee0d6 ['Бытовая техника']
# line_list ['ff68cee0d6', 'context'] Словарь: ['Бытовая техника']
# ['ff68cee0d6', 'context', ['Бытовая техника']]
# Ключ найден e8447c40e2 ['Досуг']
# line_list ['e8447c40e2', 'email'] Словарь: ['Досуг']
# ['e8447c40e2', 'email', ['Досуг']]
# Ключ найден b9ef8fdf47 ['Продукты']
# line_list ['b9ef8fdf47', 'other'] Словарь: ['Продукты']
# ['b9ef8fdf47', 'other', ['Продукты']]
# Ключ найден 98d290be27 ['Электроника']
# line_list ['98d290be27', 'other'] Словарь: ['Электроника']
# ['98d290be27', 'other', ['Электроника']]
# Ключ найден 3fff459bda ['Электроника']
# line_list ['3fff459bda', 'other'] Словарь: ['Электроника']
# ['3fff459bda', 'other', ['Электроника']]
# Ключ найден fa0079a5a8 ['Досуг']
# line_list ['fa0079a5a8', 'other'] Словарь: ['Досуг']
# ['fa0079a5a8', 'other', ['Досуг']]
# Ключ найден fdd6b2fc76 ['Бытовая техника']
# line_list ['fdd6b2fc76', 'context'] Словарь: ['Бытовая техника']
# ['fdd6b2fc76', 'context', ['Бытовая техника']]
# Ключ найден 54ecd881a2 ['Бытовая техника']
# line_list ['54ecd881a2', 'other'] Словарь: ['Бытовая техника']
# ['54ecd881a2', 'other', ['Бытовая техника']]
# Ключ найден 22d2f03a17 ['Досуг']
# line_list ['22d2f03a17', 'context'] Словарь: ['Досуг']
# ['22d2f03a17', 'context', ['Досуг']]
# Ключ найден c9fa1b54d5 ['Продукты']
# line_list ['c9fa1b54d5', 'other'] Словарь: ['Продукты']
# ['c9fa1b54d5', 'other', ['Продукты']]
# Ключ найден 3f8e1ccd3f ['Электроника']
# line_list ['3f8e1ccd3f', 'other'] Словарь: ['Электроника']
# ['3f8e1ccd3f', 'other', ['Электроника']]
# Ключ найден 81a9988b83 ['Электроника']
# line_list ['81a9988b83', 'context'] Словарь: ['Электроника']
# ['81a9988b83', 'context', ['Электроника']]
# Ключ найден 65f44a2eb7 ['Досуг']
# line_list ['65f44a2eb7', 'context'] Словарь: ['Досуг']
# ['65f44a2eb7', 'context', ['Досуг']]
# Ключ найден 6df948569b ['Бытовая техника']
# line_list ['6df948569b', 'other'] Словарь: ['Бытовая техника']
# ['6df948569b', 'other', ['Бытовая техника']]
# Ключ найден 5f8fbb0149 ['Бытовая техника']
# line_list ['5f8fbb0149', 'other'] Словарь: ['Бытовая техника']
# ['5f8fbb0149', 'other', ['Бытовая техника']]
# Ключ найден 3ecff691fd ['Электроника']
# line_list ['3ecff691fd', 'context'] Словарь: ['Электроника']
# ['3ecff691fd', 'context', ['Электроника']]
# Ключ найден dd0e912251 ['Электроника']
# line_list ['dd0e912251', 'other'] Словарь: ['Электроника']
# ['dd0e912251', 'other', ['Электроника']]
# Ключ найден 9250593d55 ['Электроника']
# line_list ['9250593d55', 'other'] Словарь: ['Электроника']
# ['9250593d55', 'other', ['Электроника']]
# Ключ найден 37c4e090e4 ['Электроника']
# line_list ['37c4e090e4', 'other'] Словарь: ['Электроника']
# ['37c4e090e4', 'other', ['Электроника']]
# Ключ найден 22fa3ea76f ['Электроника']
# line_list ['22fa3ea76f', 'other'] Словарь: ['Электроника']
# ['22fa3ea76f', 'other', ['Электроника']]
# Ключ найден 73b876b237 ['Электроника']
# line_list ['73b876b237', 'context'] Словарь: ['Электроника']
# ['73b876b237', 'context', ['Электроника']]
# Ключ найден ed6b87f95d ['Досуг']
# line_list ['ed6b87f95d', 'context'] Словарь: ['Досуг']
# ['ed6b87f95d', 'context', ['Досуг']]
# Ключ найден f983a69d67 ['Товары для животных']
# line_list ['f983a69d67', 'other'] Словарь: ['Товары для животных']
# ['f983a69d67', 'other', ['Товары для животных']]
# Ключ найден 4ea17212f8 ['Продукты']
# line_list ['4ea17212f8', 'other'] Словарь: ['Продукты']
# ['4ea17212f8', 'other', ['Продукты']]
# Ключ найден c6de96a5e2 ['Товары для животных']
# line_list ['c6de96a5e2', 'other'] Словарь: ['Товары для животных']
# ['c6de96a5e2', 'other', ['Товары для животных']]
# Ключ найден 4175fd2e58 ['Электроника']
# line_list ['4175fd2e58', 'other'] Словарь: ['Электроника']
# ['4175fd2e58', 'other', ['Электроника']]
# Ключ найден d8e3bcee53 ['Продукты']
# line_list ['d8e3bcee53', 'context'] Словарь: ['Продукты']
# ['d8e3bcee53', 'context', ['Продукты']]
# Ключ найден 680aa815f9 ['Продукты']
# line_list ['680aa815f9', 'other'] Словарь: ['Продукты']
# ['680aa815f9', 'other', ['Продукты']]
# Ключ найден 4a92a68cf9 ['Электроника']
# line_list ['4a92a68cf9', 'other'] Словарь: ['Электроника']
# ['4a92a68cf9', 'other', ['Электроника']]
# Ключ найден 905e60cb52 ['Бытовая техника']
# line_list ['905e60cb52', 'other'] Словарь: ['Бытовая техника']
# ['905e60cb52', 'other', ['Бытовая техника']]
# Ключ найден 393bcfb298 ['Продукты']
# line_list ['393bcfb298', 'other'] Словарь: ['Продукты']
# ['393bcfb298', 'other', ['Продукты']]
# Ключ найден 06d450cc57 ['Электроника']
# line_list ['06d450cc57', 'context'] Словарь: ['Электроника']
# ['06d450cc57', 'context', ['Электроника']]
# Ключ найден b60ce22f17 ['Электроника']
# line_list ['b60ce22f17', 'other'] Словарь: ['Электроника']
# ['b60ce22f17', 'other', ['Электроника']]
# Ключ найден 6f159c4c2e ['Товары для животных']
# line_list ['6f159c4c2e', 'other'] Словарь: ['Товары для животных']
# ['6f159c4c2e', 'other', ['Товары для животных']]
# Ключ найден 564202f6bd ['Электроника']
# line_list ['564202f6bd', 'context'] Словарь: ['Электроника']
# ['564202f6bd', 'context', ['Электроника']]
# Ключ найден 1908683775 ['Электроника']
# line_list ['1908683775', 'other'] Словарь: ['Электроника']
# ['1908683775', 'other', ['Электроника']]
# Ключ найден 8fd957a463 ['Продукты']
# line_list ['8fd957a463', 'other'] Словарь: ['Продукты']
# ['8fd957a463', 'other', ['Продукты']]
# Ключ найден 72e0a3f1d0 ['Бытовая техника']
# line_list ['72e0a3f1d0', 'other'] Словарь: ['Бытовая техника']
# ['72e0a3f1d0', 'other', ['Бытовая техника']]
# Ключ найден 7f5f56e517 ['Досуг']
# line_list ['7f5f56e517', 'other'] Словарь: ['Досуг']
# ['7f5f56e517', 'other', ['Досуг']]
# Ключ найден bc1a0a7e26 ['Досуг']
# line_list ['bc1a0a7e26', 'other'] Словарь: ['Досуг']
# ['bc1a0a7e26', 'other', ['Досуг']]
# Ключ найден 17639fe89d ['Досуг']
# line_list ['17639fe89d', 'other'] Словарь: ['Досуг']
# ['17639fe89d', 'other', ['Досуг']]
# Ключ найден 74c9201f84 ['Электроника']
# line_list ['74c9201f84', 'context'] Словарь: ['Электроника']
# ['74c9201f84', 'context', ['Электроника']]
# Ключ найден bc4ebda0df ['Досуг']
# line_list ['bc4ebda0df', 'other'] Словарь: ['Досуг']
# ['bc4ebda0df', 'other', ['Досуг']]
# Ключ найден fe4615dd15 ['Досуг']
# line_list ['fe4615dd15', 'other'] Словарь: ['Досуг']
# ['fe4615dd15', 'other', ['Досуг']]
# Ключ найден d2c560746d ['Бытовая техника']
# line_list ['d2c560746d', 'other'] Словарь: ['Бытовая техника']
# ['d2c560746d', 'other', ['Бытовая техника']]
# Ключ найден f0a93d52d2 ['Электроника']
# line_list ['f0a93d52d2', 'other'] Словарь: ['Электроника']
# ['f0a93d52d2', 'other', ['Электроника']]
# Ключ найден fe52ded300 ['Электроника']
# line_list ['fe52ded300', 'other'] Словарь: ['Электроника']
# ['fe52ded300', 'other', ['Электроника']]
# Ключ найден dbe70d84e4 ['Строительство и ремонт']
# line_list ['dbe70d84e4', 'context'] Словарь: ['Строительство и ремонт']
# ['dbe70d84e4', 'context', ['Строительство и ремонт']]
# Ключ найден f660dbcc3f ['Электроника']
# line_list ['f660dbcc3f', 'context'] Словарь: ['Электроника']
# ['f660dbcc3f', 'context', ['Электроника']]
# Ключ найден f93283c9ee ['Бытовая техника']
# line_list ['f93283c9ee', 'other'] Словарь: ['Бытовая техника']
# ['f93283c9ee', 'other', ['Бытовая техника']]
# Ключ найден 66bea9bf58 ['Бытовая техника']
# line_list ['66bea9bf58', 'other'] Словарь: ['Бытовая техника']
# ['66bea9bf58', 'other', ['Бытовая техника']]
# Ключ найден 111c52d9bc ['Продукты']
# line_list ['111c52d9bc', 'other'] Словарь: ['Продукты']
# ['111c52d9bc', 'other', ['Продукты']]
# Ключ найден 16dc76e94d ['Электроника']
# line_list ['16dc76e94d', 'other'] Словарь: ['Электроника']
# ['16dc76e94d', 'other', ['Электроника']]
# Ключ найден 87f37b380c ['Продукты']
# line_list ['87f37b380c', 'other'] Словарь: ['Продукты']
# ['87f37b380c', 'other', ['Продукты']]
# Ключ найден 365e3edd2e ['Бытовая техника']
# line_list ['365e3edd2e', 'other'] Словарь: ['Бытовая техника']
# ['365e3edd2e', 'other', ['Бытовая техника']]
# Ключ найден 830421d975 ['Продукты']
# line_list ['830421d975', 'other'] Словарь: ['Продукты']
# ['830421d975', 'other', ['Продукты']]
# Ключ найден 7d6c62f0a2 ['Бытовая техника']
# line_list ['7d6c62f0a2', 'context'] Словарь: ['Бытовая техника']
# ['7d6c62f0a2', 'context', ['Бытовая техника']]
# Ключ найден 77465a0b61 ['Бытовая техника']
# line_list ['77465a0b61', 'other'] Словарь: ['Бытовая техника']
# ['77465a0b61', 'other', ['Бытовая техника']]
# Ключ найден ee9eb52181 ['Товары для животных']
# line_list ['ee9eb52181', 'email'] Словарь: ['Товары для животных']
# ['ee9eb52181', 'email', ['Товары для животных']]
# Ключ найден 871c1fa9ae ['Продукты']
# line_list ['871c1fa9ae', 'other'] Словарь: ['Продукты']
# ['871c1fa9ae', 'other', ['Продукты']]
# Ключ найден 03b91dba06 ['Электроника']
# line_list ['03b91dba06', 'other'] Словарь: ['Электроника']
# ['03b91dba06', 'other', ['Электроника']]
# Ключ найден 6cb42b2632 ['Бытовая техника']
# line_list ['6cb42b2632', 'email'] Словарь: ['Бытовая техника']
# ['6cb42b2632', 'email', ['Бытовая техника']]
# Ключ найден c7f6fbe42f ['Бытовая техника']
# line_list ['c7f6fbe42f', 'other'] Словарь: ['Бытовая техника']
# ['c7f6fbe42f', 'other', ['Бытовая техника']]
# Ключ найден 9ab8f3bbb8 ['Бытовая техника']
# line_list ['9ab8f3bbb8', 'context'] Словарь: ['Бытовая техника']
# ['9ab8f3bbb8', 'context', ['Бытовая техника']]
# Ключ найден 63df9ee9d3 ['Электроника']
# line_list ['63df9ee9d3', 'context'] Словарь: ['Электроника']
# ['63df9ee9d3', 'context', ['Электроника']]
# Ключ найден 2ffd6c724d ['Продукты']
# line_list ['2ffd6c724d', 'other'] Словарь: ['Продукты']
# ['2ffd6c724d', 'other', ['Продукты']]
# Ключ найден af24cffd03 ['Электроника']
# line_list ['af24cffd03', 'context'] Словарь: ['Электроника']
# ['af24cffd03', 'context', ['Электроника']]
# Ключ найден 421149bb9a ['Строительство и ремонт']
# line_list ['421149bb9a', 'other'] Словарь: ['Строительство и ремонт']
# ['421149bb9a', 'other', ['Строительство и ремонт']]
# Ключ найден 24300c6d1c ['Электроника']
# line_list ['24300c6d1c', 'other'] Словарь: ['Электроника']
# ['24300c6d1c', 'other', ['Электроника']]
# Ключ найден 40fe35eb76 ['Строительство и ремонт']
# line_list ['40fe35eb76', 'email'] Словарь: ['Строительство и ремонт']
# ['40fe35eb76', 'email', ['Строительство и ремонт']]
# Ключ найден 9ca11a651f ['Электроника']
# line_list ['9ca11a651f', 'email'] Словарь: ['Электроника']
# ['9ca11a651f', 'email', ['Электроника']]
# Ключ найден b7e640032f ['Электроника']
# line_list ['b7e640032f', 'other'] Словарь: ['Электроника']
# ['b7e640032f', 'other', ['Электроника']]
# Ключ найден 3691ad282b ['Электроника']
# line_list ['3691ad282b', 'other'] Словарь: ['Электроника']
# ['3691ad282b', 'other', ['Электроника']]
# Ключ найден 00ea2f7484 ['Электроника']
# line_list ['00ea2f7484', 'other'] Словарь: ['Электроника']
# ['00ea2f7484', 'other', ['Электроника']]
# Ключ найден 6f198ac1c9 ['Бытовая техника']
# line_list ['6f198ac1c9', 'other'] Словарь: ['Бытовая техника']
# ['6f198ac1c9', 'other', ['Бытовая техника']]
# Ключ найден 0d479d4259 ['Электроника']
# line_list ['0d479d4259', 'other'] Словарь: ['Электроника']
# ['0d479d4259', 'other', ['Электроника']]
# Ключ найден 2c8067b7a3 ['Продукты']
# line_list ['2c8067b7a3', 'other'] Словарь: ['Продукты']
# ['2c8067b7a3', 'other', ['Продукты']]
# Ключ найден b461051101 ['Досуг']
# line_list ['b461051101', 'other'] Словарь: ['Досуг']
# ['b461051101', 'other', ['Досуг']]
# Ключ найден d39a1d56c3 ['Бытовая техника']
# line_list ['d39a1d56c3', 'context'] Словарь: ['Бытовая техника']
# ['d39a1d56c3', 'context', ['Бытовая техника']]
# Ключ найден 316ab03143 ['Товары для животных']
# line_list ['316ab03143', 'None'] Словарь: ['Товары для животных']
# ['316ab03143', 'None', ['Товары для животных']]
# Ключ найден 78ed39a415 ['Электроника']
# line_list ['78ed39a415', 'other'] Словарь: ['Электроника']
# ['78ed39a415', 'other', ['Электроника']]
# Ключ найден fd2c2b59b9 ['Бытовая техника']
# line_list ['fd2c2b59b9', 'context'] Словарь: ['Бытовая техника']
# ['fd2c2b59b9', 'context', ['Бытовая техника']]
# Ключ найден 19d1e4e036 ['Товары для животных']
# line_list ['19d1e4e036', 'context'] Словарь: ['Товары для животных']
# ['19d1e4e036', 'context', ['Товары для животных']]
# Ключ найден 9e765c6822 ['Продукты']
# line_list ['9e765c6822', 'other'] Словарь: ['Продукты']
# ['9e765c6822', 'other', ['Продукты']]
# Ключ найден ddd50eaa45 ['Электроника']
# line_list ['ddd50eaa45', 'other'] Словарь: ['Электроника']
# ['ddd50eaa45', 'other', ['Электроника']]
# Ключ найден e07b13abd0 ['Бытовая техника']
# line_list ['e07b13abd0', 'email'] Словарь: ['Бытовая техника']
# ['e07b13abd0', 'email', ['Бытовая техника']]
# Ключ найден c21b82499e ['Электроника']
# line_list ['c21b82499e', 'context'] Словарь: ['Электроника']
# ['c21b82499e', 'context', ['Электроника']]
# Ключ найден da79d9ff30 ['Товары для животных']
# line_list ['da79d9ff30', 'other'] Словарь: ['Товары для животных']
# ['da79d9ff30', 'other', ['Товары для животных']]
# Ключ найден eded5c6792 ['Досуг']
# line_list ['eded5c6792', 'context'] Словарь: ['Досуг']
# ['eded5c6792', 'context', ['Досуг']]
# Ключ найден e3654c7f1a ['Досуг']
# line_list ['e3654c7f1a', 'other'] Словарь: ['Досуг']
# ['e3654c7f1a', 'other', ['Досуг']]
# Ключ найден d20bf10c78 ['Бытовая техника']
# line_list ['d20bf10c78', 'other'] Словарь: ['Бытовая техника']
# ['d20bf10c78', 'other', ['Бытовая техника']]
# Ключ найден 12de58d8e6 ['Продукты']
# line_list ['12de58d8e6', 'other'] Словарь: ['Продукты']
# ['12de58d8e6', 'other', ['Продукты']]
# Ключ найден ab8e0c1a01 ['Досуг']
# line_list ['ab8e0c1a01', 'context'] Словарь: ['Досуг']
# ['ab8e0c1a01', 'context', ['Досуг']]
# Ключ найден ea10f78fec ['Продукты']
# line_list ['ea10f78fec', 'other'] Словарь: ['Продукты']
# ['ea10f78fec', 'other', ['Продукты']]
# Ключ найден de85ea0eb6 ['Электроника']
# line_list ['de85ea0eb6', 'other'] Словарь: ['Электроника']
# ['de85ea0eb6', 'other', ['Электроника']]
# Ключ найден dfe6f4ebb4 ['Бытовая техника']
# line_list ['dfe6f4ebb4', 'other'] Словарь: ['Бытовая техника']
# ['dfe6f4ebb4', 'other', ['Бытовая техника']]
# Ключ найден 9d25ac3886 ['Досуг']
# line_list ['9d25ac3886', 'context'] Словарь: ['Досуг']
# ['9d25ac3886', 'context', ['Досуг']]
# Ключ найден ddf1af2d3f ['Бытовая техника']
# line_list ['ddf1af2d3f', 'other'] Словарь: ['Бытовая техника']
# ['ddf1af2d3f', 'other', ['Бытовая техника']]
# Ключ найден d47dd8b814 ['Электроника']
# line_list ['d47dd8b814', 'other'] Словарь: ['Электроника']
# ['d47dd8b814', 'other', ['Электроника']]
# Ключ найден c5e1bf636a ['Электроника']
# line_list ['c5e1bf636a', 'context'] Словарь: ['Электроника']
# ['c5e1bf636a', 'context', ['Электроника']]
# Ключ найден eb5654cf30 ['Продукты']
# line_list ['eb5654cf30', 'other'] Словарь: ['Продукты']
# ['eb5654cf30', 'other', ['Продукты']]
# Ключ найден a86e69db63 ['Продукты']
# line_list ['a86e69db63', 'other'] Словарь: ['Продукты']
# ['a86e69db63', 'other', ['Продукты']]
# Ключ найден d15327eae3 ['Электроника']
# line_list ['d15327eae3', 'email'] Словарь: ['Электроника']
# ['d15327eae3', 'email', ['Электроника']]
# Ключ найден 5278408c4c ['Электроника']
# line_list ['5278408c4c', 'other'] Словарь: ['Электроника']
# ['5278408c4c', 'other', ['Электроника']]
# Ключ найден 91802f78b2 ['Электроника']
# line_list ['91802f78b2', 'other'] Словарь: ['Электроника']
# ['91802f78b2', 'other', ['Электроника']]
# Ключ найден f46375940f ['Досуг']
# line_list ['f46375940f', 'context'] Словарь: ['Досуг']
# ['f46375940f', 'context', ['Досуг']]
# Ключ найден 152ea9bb42 ['Бытовая техника']
# line_list ['152ea9bb42', 'other'] Словарь: ['Бытовая техника']
# ['152ea9bb42', 'other', ['Бытовая техника']]
# Ключ найден 06569907e6 ['Бытовая техника']
# line_list ['06569907e6', 'other'] Словарь: ['Бытовая техника']
# ['06569907e6', 'other', ['Бытовая техника']]
# Ключ найден 9f5bf9b73f ['Строительство и ремонт']
# line_list ['9f5bf9b73f', 'other'] Словарь: ['Строительство и ремонт']
# ['9f5bf9b73f', 'other', ['Строительство и ремонт']]
# Ключ найден ec11793734 ['Продукты']
# line_list ['ec11793734', 'other'] Словарь: ['Продукты']
# ['ec11793734', 'other', ['Продукты']]
# Ключ найден 0cf6ee6c84 ['Бытовая техника']
# line_list ['0cf6ee6c84', 'context'] Словарь: ['Бытовая техника']
# ['0cf6ee6c84', 'context', ['Бытовая техника']]
# Ключ найден f9a3ef9ac2 ['Продукты']
# line_list ['f9a3ef9ac2', 'context'] Словарь: ['Продукты']
# ['f9a3ef9ac2', 'context', ['Продукты']]
# Ключ найден 716a1b4e10 ['Продукты']
# line_list ['716a1b4e10', 'context'] Словарь: ['Продукты']
# ['716a1b4e10', 'context', ['Продукты']]
# Ключ найден 42e3b7d1a1 ['Бытовая техника']
# line_list ['42e3b7d1a1', 'other'] Словарь: ['Бытовая техника']
# ['42e3b7d1a1', 'other', ['Бытовая техника']]
# Ключ найден 426fa041ad ['Электроника']
# line_list ['426fa041ad', 'other'] Словарь: ['Электроника']
# ['426fa041ad', 'other', ['Электроника']]
# Ключ найден e63af2c8b8 ['Бытовая техника']
# line_list ['e63af2c8b8', 'other'] Словарь: ['Бытовая техника']
# ['e63af2c8b8', 'other', ['Бытовая техника']]
# Ключ найден c0cd6e93e6 ['Электроника']
# line_list ['c0cd6e93e6', 'other'] Словарь: ['Электроника']
# ['c0cd6e93e6', 'other', ['Электроника']]
# Ключ найден 85ff218333 ['Строительство и ремонт']
# line_list ['85ff218333', 'other'] Словарь: ['Строительство и ремонт']
# ['85ff218333', 'other', ['Строительство и ремонт']]
# Ключ найден f0dfb618b4 ['Товары для животных']
# line_list ['f0dfb618b4', 'other'] Словарь: ['Товары для животных']
# ['f0dfb618b4', 'other', ['Товары для животных']]
# Ключ найден f537f6c8ea ['Бытовая техника']
# line_list ['f537f6c8ea', 'other'] Словарь: ['Бытовая техника']
# ['f537f6c8ea', 'other', ['Бытовая техника']]
# Ключ найден 733b99b95b ['Электроника']
# line_list ['733b99b95b', 'other'] Словарь: ['Электроника']
# ['733b99b95b', 'other', ['Электроника']]
# Ключ найден 749e8694c5 ['Товары для животных']
# line_list ['749e8694c5', 'context'] Словарь: ['Товары для животных']
# ['749e8694c5', 'context', ['Товары для животных']]
# Ключ найден 116f29a8af ['Электроника']
# line_list ['116f29a8af', 'email'] Словарь: ['Электроника']
# ['116f29a8af', 'email', ['Электроника']]
# Ключ найден 29586e4061 ['Продукты']
# line_list ['29586e4061', 'other'] Словарь: ['Продукты']
# ['29586e4061', 'other', ['Продукты']]
# Ключ найден e9eaffa80a ['Бытовая техника']
# line_list ['e9eaffa80a', 'context'] Словарь: ['Бытовая техника']
# ['e9eaffa80a', 'context', ['Бытовая техника']]
# Ключ найден da237781d5 ['Продукты']
# line_list ['da237781d5', 'context'] Словарь: ['Продукты']
# ['da237781d5', 'context', ['Продукты']]
# Ключ найден b7195283e1 ['Товары для животных']
# line_list ['b7195283e1', 'other'] Словарь: ['Товары для животных']
# ['b7195283e1', 'other', ['Товары для животных']]
# Ключ найден 62f37b821c ['Досуг']
# line_list ['62f37b821c', 'context'] Словарь: ['Досуг']
# ['62f37b821c', 'context', ['Досуг']]
# Ключ найден 69ae0afab1 ['Продукты']
# line_list ['69ae0afab1', 'other'] Словарь: ['Продукты']
# ['69ae0afab1', 'other', ['Продукты']]
# Ключ найден 7fa3bf64b4 ['Досуг']
# line_list ['7fa3bf64b4', 'other'] Словарь: ['Досуг']
# ['7fa3bf64b4', 'other', ['Досуг']]
# Ключ найден 4e603d8878 ['Строительство и ремонт']
# line_list ['4e603d8878', 'other'] Словарь: ['Строительство и ремонт']
# ['4e603d8878', 'other', ['Строительство и ремонт']]
# Ключ найден f1b744e6ef ['Бытовая техника']
# line_list ['f1b744e6ef', 'other'] Словарь: ['Бытовая техника']
# ['f1b744e6ef', 'other', ['Бытовая техника']]
# Ключ найден 6812661e1c ['Электроника']
# line_list ['6812661e1c', 'other'] Словарь: ['Электроника']
# ['6812661e1c', 'other', ['Электроника']]
# Ключ найден fea946e2a6 ['Электроника']
# line_list ['fea946e2a6', 'other'] Словарь: ['Электроника']
# ['fea946e2a6', 'other', ['Электроника']]
# Ключ найден 6aff7a1677 ['Бытовая техника']
# line_list ['6aff7a1677', 'context'] Словарь: ['Бытовая техника']
# ['6aff7a1677', 'context', ['Бытовая техника']]
# Ключ найден e43ad75353 ['Продукты']
# line_list ['e43ad75353', 'email'] Словарь: ['Продукты']
# ['e43ad75353', 'email', ['Продукты']]
# Ключ найден 88afad2ad9 ['Продукты']
# line_list ['88afad2ad9', 'other'] Словарь: ['Продукты']
# ['88afad2ad9', 'other', ['Продукты']]
# Ключ найден 0fa7c5b19c ['Товары для животных']
# line_list ['0fa7c5b19c', 'other'] Словарь: ['Товары для животных']
# ['0fa7c5b19c', 'other', ['Товары для животных']]
# Ключ найден bed9ab14bd ['Товары для животных']
# line_list ['bed9ab14bd', 'other'] Словарь: ['Товары для животных']
# ['bed9ab14bd', 'other', ['Товары для животных']]
# Ключ найден b30f6a38da ['Электроника']
# line_list ['b30f6a38da', 'other'] Словарь: ['Электроника']
# ['b30f6a38da', 'other', ['Электроника']]
# Ключ найден 74b06f9902 ['Строительство и ремонт']
# line_list ['74b06f9902', 'email'] Словарь: ['Строительство и ремонт']
# ['74b06f9902', 'email', ['Строительство и ремонт']]
# Ключ найден 397005e41e ['Бытовая техника']
# line_list ['397005e41e', 'other'] Словарь: ['Бытовая техника']
# ['397005e41e', 'other', ['Бытовая техника']]
# Ключ найден 80023b95ac ['Электроника']
# line_list ['80023b95ac', 'other'] Словарь: ['Электроника']
# ['80023b95ac', 'other', ['Электроника']]
# Ключ найден 9fb91262f8 ['Бытовая техника']
# line_list ['9fb91262f8', 'other'] Словарь: ['Бытовая техника']
# ['9fb91262f8', 'other', ['Бытовая техника']]
# Ключ найден f34a165ad2 ['Электроника']
# line_list ['f34a165ad2', 'other'] Словарь: ['Электроника']
# ['f34a165ad2', 'other', ['Электроника']]
# Ключ найден 5b7c1e9769 ['Бытовая техника']
# line_list ['5b7c1e9769', 'email'] Словарь: ['Бытовая техника']
# ['5b7c1e9769', 'email', ['Бытовая техника']]
# Ключ найден 5655da0e0b ['Электроника']
# line_list ['5655da0e0b', 'other'] Словарь: ['Электроника']
# ['5655da0e0b', 'other', ['Электроника']]
# Ключ найден ef33021c36 ['не определена']
# line_list ['ef33021c36', 'context'] Словарь: ['не определена']
# ['ef33021c36', 'context', ['не определена']]
# Ключ найден b15321ea7c ['Продукты']
# line_list ['b15321ea7c', 'other'] Словарь: ['Продукты']
# ['b15321ea7c', 'other', ['Продукты']]
# Ключ найден 0d4f4664e0 ['Продукты']
# line_list ['0d4f4664e0', 'context'] Словарь: ['Продукты']
# ['0d4f4664e0', 'context', ['Продукты']]
# Ключ найден 90ecb23d7c ['Электроника']
# line_list ['90ecb23d7c', 'other'] Словарь: ['Электроника']
# ['90ecb23d7c', 'other', ['Электроника']]
# Ключ найден a2468d6c33 ['Электроника']
# line_list ['a2468d6c33', 'context'] Словарь: ['Электроника']
# ['a2468d6c33', 'context', ['Электроника']]
# Ключ найден a8660dcfae ['Бытовая техника']
# line_list ['a8660dcfae', 'context'] Словарь: ['Бытовая техника']
# ['a8660dcfae', 'context', ['Бытовая техника']]
# Ключ найден 8abc724d78 ['Бытовая техника']
# line_list ['8abc724d78', 'other'] Словарь: ['Бытовая техника']
# ['8abc724d78', 'other', ['Бытовая техника']]
# Ключ найден a7bfa5d0cc ['Досуг']
# line_list ['a7bfa5d0cc', 'context'] Словарь: ['Досуг']
# ['a7bfa5d0cc', 'context', ['Досуг']]
# Ключ найден 6e6293a54b ['Досуг']
# line_list ['6e6293a54b', 'context'] Словарь: ['Досуг']
# ['6e6293a54b', 'context', ['Досуг']]
# Ключ найден 2bfb139a80 ['Электроника']
# line_list ['2bfb139a80', 'other'] Словарь: ['Электроника']
# ['2bfb139a80', 'other', ['Электроника']]
# Ключ найден 48b9ea8b65 ['Электроника']
# line_list ['48b9ea8b65', 'other'] Словарь: ['Электроника']
# ['48b9ea8b65', 'other', ['Электроника']]
# Ключ найден fb9acee964 ['Бытовая техника']
# line_list ['fb9acee964', 'None'] Словарь: ['Бытовая техника']
# ['fb9acee964', 'None', ['Бытовая техника']]
# Ключ найден 69775511be ['Досуг']
# line_list ['69775511be', 'context'] Словарь: ['Досуг']
# ['69775511be', 'context', ['Досуг']]
# Ключ найден 95bf67fda9 ['Продукты']
# line_list ['95bf67fda9', 'other'] Словарь: ['Продукты']
# ['95bf67fda9', 'other', ['Продукты']]
# Ключ найден ca899d23dd ['Бытовая техника']
# line_list ['ca899d23dd', 'other'] Словарь: ['Бытовая техника']
# ['ca899d23dd', 'other', ['Бытовая техника']]
# Ключ найден 2de051e056 ['Электроника']
# line_list ['2de051e056', 'context'] Словарь: ['Электроника']
# ['2de051e056', 'context', ['Электроника']]
# Ключ найден 0da9ca70fe ['Продукты']
# line_list ['0da9ca70fe', 'context'] Словарь: ['Продукты']
# ['0da9ca70fe', 'context', ['Продукты']]
# Ключ найден fcc5bebc42 ['Бытовая техника']
# line_list ['fcc5bebc42', 'context'] Словарь: ['Бытовая техника']
# ['fcc5bebc42', 'context', ['Бытовая техника']]
# Ключ найден 51f6ce88cc ['Бытовая техника']
# line_list ['51f6ce88cc', 'other'] Словарь: ['Бытовая техника']
# ['51f6ce88cc', 'other', ['Бытовая техника']]
# Ключ найден 74a55eee1d ['Электроника']
# line_list ['74a55eee1d', 'other'] Словарь: ['Электроника']
# ['74a55eee1d', 'other', ['Электроника']]
# Ключ найден 69475b45df ['Бытовая техника']
# line_list ['69475b45df', 'context'] Словарь: ['Бытовая техника']
# ['69475b45df', 'context', ['Бытовая техника']]
# Ключ найден 816800e62f ['Бытовая техника']
# line_list ['816800e62f', 'context'] Словарь: ['Бытовая техника']
# ['816800e62f', 'context', ['Бытовая техника']]
# Ключ найден 28ce699720 ['Бытовая техника']
# line_list ['28ce699720', 'other'] Словарь: ['Бытовая техника']
# ['28ce699720', 'other', ['Бытовая техника']]
# Ключ найден f0d57ef042 ['Электроника']
# line_list ['f0d57ef042', 'other'] Словарь: ['Электроника']
# ['f0d57ef042', 'other', ['Электроника']]
# Ключ найден 39325a5a80 ['Досуг']
# line_list ['39325a5a80', 'other'] Словарь: ['Досуг']
# ['39325a5a80', 'other', ['Досуг']]
# Ключ найден c577b4b31e ['Продукты']
# line_list ['c577b4b31e', 'other'] Словарь: ['Продукты']
# ['c577b4b31e', 'other', ['Продукты']]
# Ключ найден 4038202869 ['Электроника']
# line_list ['4038202869', 'other'] Словарь: ['Электроника']
# ['4038202869', 'other', ['Электроника']]
# Ключ найден 1405e18ffb ['Досуг']
# line_list ['1405e18ffb', 'context'] Словарь: ['Досуг']
# ['1405e18ffb', 'context', ['Досуг']]
# Ключ найден c0cc01a6a4 ['Электроника']
# line_list ['c0cc01a6a4', 'other'] Словарь: ['Электроника']
# ['c0cc01a6a4', 'other', ['Электроника']]
# Ключ найден 4cd8bde9ac ['Продукты']
# line_list ['4cd8bde9ac', 'context'] Словарь: ['Продукты']
# ['4cd8bde9ac', 'context', ['Продукты']]
# Ключ найден f924cacd6d ['Электроника']
# line_list ['f924cacd6d', 'other'] Словарь: ['Электроника']
# ['f924cacd6d', 'other', ['Электроника']]
# Ключ найден 8c5eeb346a ['Бытовая техника']
# line_list ['8c5eeb346a', 'context'] Словарь: ['Бытовая техника']
# ['8c5eeb346a', 'context', ['Бытовая техника']]
# Ключ найден 853f7ea287 ['Продукты']
# line_list ['853f7ea287', 'other'] Словарь: ['Продукты']
# ['853f7ea287', 'other', ['Продукты']]
# Ключ найден 3b1fb2ad3f ['Электроника']
# line_list ['3b1fb2ad3f', 'other'] Словарь: ['Электроника']
# ['3b1fb2ad3f', 'other', ['Электроника']]
# Ключ найден 8c45fdbf5a ['Электроника']
# line_list ['8c45fdbf5a', 'other'] Словарь: ['Электроника']
# ['8c45fdbf5a', 'other', ['Электроника']]
# Ключ найден 614aaf466d ['Бытовая техника']
# line_list ['614aaf466d', 'other'] Словарь: ['Бытовая техника']
# ['614aaf466d', 'other', ['Бытовая техника']]
# Ключ найден a6a4ff39f8 ['Бытовая техника']
# line_list ['a6a4ff39f8', 'other'] Словарь: ['Бытовая техника']
# ['a6a4ff39f8', 'other', ['Бытовая техника']]
# Ключ найден 55effa36e0 ['Продукты']
# line_list ['55effa36e0', 'other'] Словарь: ['Продукты']
# ['55effa36e0', 'other', ['Продукты']]
# Ключ найден 51d4f4b9d5 ['Бытовая техника']
# line_list ['51d4f4b9d5', 'other'] Словарь: ['Бытовая техника']
# ['51d4f4b9d5', 'other', ['Бытовая техника']]
# Ключ найден 694fdf8197 ['Электроника']
# line_list ['694fdf8197', 'context'] Словарь: ['Электроника']
# ['694fdf8197', 'context', ['Электроника']]
# Ключ найден 33a4dbd193 ['Электроника']
# line_list ['33a4dbd193', 'other'] Словарь: ['Электроника']
# ['33a4dbd193', 'other', ['Электроника']]
# Ключ найден bc2b6ade51 ['Электроника']
# line_list ['bc2b6ade51', 'other'] Словарь: ['Электроника']
# ['bc2b6ade51', 'other', ['Электроника']]
# Ключ найден e371c40a07 ['Электроника']
# line_list ['e371c40a07', 'context'] Словарь: ['Электроника']
# ['e371c40a07', 'context', ['Электроника']]
# Ключ найден 74d3a4830b ['Продукты']
# line_list ['74d3a4830b', 'context'] Словарь: ['Продукты']
# ['74d3a4830b', 'context', ['Продукты']]
# Ключ найден be78adf037 ['Электроника']
# line_list ['be78adf037', 'other'] Словарь: ['Электроника']
# ['be78adf037', 'other', ['Электроника']]
# Ключ найден fceaddb1f5 ['Электроника']
# line_list ['fceaddb1f5', 'other'] Словарь: ['Электроника']
# ['fceaddb1f5', 'other', ['Электроника']]
# Ключ найден 63f9ec63df ['Бытовая техника']
# line_list ['63f9ec63df', 'None'] Словарь: ['Бытовая техника']
# ['63f9ec63df', 'None', ['Бытовая техника']]
# Ключ найден 627fb82e41 ['Бытовая техника']
# line_list ['627fb82e41', 'other'] Словарь: ['Бытовая техника']
# ['627fb82e41', 'other', ['Бытовая техника']]
# Ключ найден a7091d1405 ['Бытовая техника']
# line_list ['a7091d1405', 'other'] Словарь: ['Бытовая техника']
# ['a7091d1405', 'other', ['Бытовая техника']]
# Ключ найден c74d0b4602 ['Электроника']
# line_list ['c74d0b4602', 'context'] Словарь: ['Электроника']
# ['c74d0b4602', 'context', ['Электроника']]
# Ключ найден a8c4da0681 ['Электроника']
# line_list ['a8c4da0681', 'other'] Словарь: ['Электроника']
# ['a8c4da0681', 'other', ['Электроника']]
# Ключ найден 47ec449fbe ['Строительство и ремонт']
# line_list ['47ec449fbe', 'context'] Словарь: ['Строительство и ремонт']
# ['47ec449fbe', 'context', ['Строительство и ремонт']]
# Ключ найден ee19ad0e7b ['Бытовая техника']
# line_list ['ee19ad0e7b', 'other'] Словарь: ['Бытовая техника']
# ['ee19ad0e7b', 'other', ['Бытовая техника']]
# Ключ найден 9b63ed579f ['Строительство и ремонт']
# line_list ['9b63ed579f', 'context'] Словарь: ['Строительство и ремонт']
# ['9b63ed579f', 'context', ['Строительство и ремонт']]
# Ключ найден 508e26d325 ['Электроника']
# line_list ['508e26d325', 'other'] Словарь: ['Электроника']
# ['508e26d325', 'other', ['Электроника']]
# Ключ найден 9cdc26ff6c ['Электроника']
# line_list ['9cdc26ff6c', 'other'] Словарь: ['Электроника']
# ['9cdc26ff6c', 'other', ['Электроника']]
# Ключ найден be8c8f1a63 ['Продукты']
# line_list ['be8c8f1a63', 'context'] Словарь: ['Продукты']
# ['be8c8f1a63', 'context', ['Продукты']]
# Ключ найден c59381af1d ['Строительство и ремонт']
# line_list ['c59381af1d', 'other'] Словарь: ['Строительство и ремонт']
# ['c59381af1d', 'other', ['Строительство и ремонт']]
# Ключ найден bc40fc5c3b ['Продукты']
# line_list ['bc40fc5c3b', 'other'] Словарь: ['Продукты']
# ['bc40fc5c3b', 'other', ['Продукты']]
# Ключ найден 5bc256883c ['Электроника']
# line_list ['5bc256883c', 'other'] Словарь: ['Электроника']
# ['5bc256883c', 'other', ['Электроника']]
# Ключ найден 800ad1974f ['Электроника']
# line_list ['800ad1974f', 'other'] Словарь: ['Электроника']
# ['800ad1974f', 'other', ['Электроника']]
# Ключ найден 36b0b3a179 ['Бытовая техника']
# line_list ['36b0b3a179', 'email'] Словарь: ['Бытовая техника']
# ['36b0b3a179', 'email', ['Бытовая техника']]
# Ключ найден 0ea0c758a5 ['Продукты']
# line_list ['0ea0c758a5', 'other'] Словарь: ['Продукты']
# ['0ea0c758a5', 'other', ['Продукты']]
# Ключ найден 12764a8382 ['Строительство и ремонт']
# line_list ['12764a8382', 'context'] Словарь: ['Строительство и ремонт']
# ['12764a8382', 'context', ['Строительство и ремонт']]
# Ключ найден fbcb38042a ['Бытовая техника']
# line_list ['fbcb38042a', 'other'] Словарь: ['Бытовая техника']
# ['fbcb38042a', 'other', ['Бытовая техника']]
# Ключ найден b3fe11defe ['Продукты']
# line_list ['b3fe11defe', 'email'] Словарь: ['Продукты']
# ['b3fe11defe', 'email', ['Продукты']]
# Ключ найден 1909ff3b18 ['Продукты']
# line_list ['1909ff3b18', 'context'] Словарь: ['Продукты']
# ['1909ff3b18', 'context', ['Продукты']]
# Ключ найден cc85b81371 ['Продукты']
# line_list ['cc85b81371', 'other'] Словарь: ['Продукты']
# ['cc85b81371', 'other', ['Продукты']]
# Ключ найден 36d248e31c ['Продукты']
# line_list ['36d248e31c', 'context'] Словарь: ['Продукты']
# ['36d248e31c', 'context', ['Продукты']]
# Ключ найден 84b1b23768 ['Досуг']
# line_list ['84b1b23768', 'context'] Словарь: ['Досуг']
# ['84b1b23768', 'context', ['Досуг']]
# Ключ найден 44174c696c ['Продукты']
# line_list ['44174c696c', 'other'] Словарь: ['Продукты']
# ['44174c696c', 'other', ['Продукты']]
# Ключ найден 640232cec2 ['Бытовая техника']
# line_list ['640232cec2', 'context'] Словарь: ['Бытовая техника']
# ['640232cec2', 'context', ['Бытовая техника']]
# Ключ найден 2e8723f652 ['Продукты']
# line_list ['2e8723f652', 'other'] Словарь: ['Продукты']
# ['2e8723f652', 'other', ['Продукты']]
# Ключ найден 2ffcf27605 ['Бытовая техника']
# line_list ['2ffcf27605', 'other'] Словарь: ['Бытовая техника']
# ['2ffcf27605', 'other', ['Бытовая техника']]
# Ключ найден 94e132ac2a ['Досуг']
# line_list ['94e132ac2a', 'other'] Словарь: ['Досуг']
# ['94e132ac2a', 'other', ['Досуг']]
# Ключ найден 433af0c12b ['Продукты']
# line_list ['433af0c12b', 'other'] Словарь: ['Продукты']
# ['433af0c12b', 'other', ['Продукты']]
# Ключ найден 24c047fa51 ['Электроника']
# line_list ['24c047fa51', 'other'] Словарь: ['Электроника']
# ['24c047fa51', 'other', ['Электроника']]
# Ключ найден 30fa49eb81 ['Бытовая техника']
# line_list ['30fa49eb81', 'other'] Словарь: ['Бытовая техника']
# ['30fa49eb81', 'other', ['Бытовая техника']]
# Ключ найден d9a640bee2 ['Электроника']
# line_list ['d9a640bee2', 'other'] Словарь: ['Электроника']
# ['d9a640bee2', 'other', ['Электроника']]
# Ключ найден 147df43b96 ['Продукты']
# line_list ['147df43b96', 'context'] Словарь: ['Продукты']
# ['147df43b96', 'context', ['Продукты']]
# Ключ найден f84cfd5fdc ['Бытовая техника']
# line_list ['f84cfd5fdc', 'context'] Словарь: ['Бытовая техника']
# ['f84cfd5fdc', 'context', ['Бытовая техника']]
# Ключ найден 8684af0a5d ['Досуг']
# line_list ['8684af0a5d', 'other'] Словарь: ['Досуг']
# ['8684af0a5d', 'other', ['Досуг']]
# Ключ найден bbec49524b ['Электроника']
# line_list ['bbec49524b', 'context'] Словарь: ['Электроника']
# ['bbec49524b', 'context', ['Электроника']]
# Ключ найден e95d728116 ['Продукты']
# line_list ['e95d728116', 'other'] Словарь: ['Продукты']
# ['e95d728116', 'other', ['Продукты']]
# Ключ найден 5392a9dd06 ['Строительство и ремонт']
# line_list ['5392a9dd06', 'other'] Словарь: ['Строительство и ремонт']
# ['5392a9dd06', 'other', ['Строительство и ремонт']]
# Ключ найден 8c9c7efbdb ['Бытовая техника']
# line_list ['8c9c7efbdb', 'context'] Словарь: ['Бытовая техника']
# ['8c9c7efbdb', 'context', ['Бытовая техника']]
# Ключ найден 8e7cb8744a ['Продукты']
# line_list ['8e7cb8744a', 'other'] Словарь: ['Продукты']
# ['8e7cb8744a', 'other', ['Продукты']]
# Ключ найден a41b59347a ['не определена']
# line_list ['a41b59347a', 'other'] Словарь: ['не определена']
# ['a41b59347a', 'other', ['не определена']]
# Ключ найден c1a0da9976 ['Электроника']
# line_list ['c1a0da9976', 'other'] Словарь: ['Электроника']
# ['c1a0da9976', 'other', ['Электроника']]
# Ключ найден 9e7126c1f7 ['Строительство и ремонт']
# line_list ['9e7126c1f7', 'other'] Словарь: ['Строительство и ремонт']
# ['9e7126c1f7', 'other', ['Строительство и ремонт']]
# Ключ найден 49e9a83a56 ['Электроника']
# line_list ['49e9a83a56', 'context'] Словарь: ['Электроника']
# ['49e9a83a56', 'context', ['Электроника']]
# Ключ найден b3391af5f3 ['Бытовая техника']
# line_list ['b3391af5f3', 'other'] Словарь: ['Бытовая техника']
# ['b3391af5f3', 'other', ['Бытовая техника']]
# Ключ найден 9c4d9e37b8 ['Электроника']
# line_list ['9c4d9e37b8', 'other'] Словарь: ['Электроника']
# ['9c4d9e37b8', 'other', ['Электроника']]
# Ключ найден 1eee1b1995 ['Электроника']
# line_list ['1eee1b1995', 'other'] Словарь: ['Электроника']
# ['1eee1b1995', 'other', ['Электроника']]
# Ключ найден d61df629df ['Продукты']
# line_list ['d61df629df', 'other'] Словарь: ['Продукты']
# ['d61df629df', 'other', ['Продукты']]
# Ключ найден f67f61db9e ['Электроника']
# line_list ['f67f61db9e', 'other'] Словарь: ['Электроника']
# ['f67f61db9e', 'other', ['Электроника']]
# Ключ найден 73d9a7f6d5 ['Продукты']
# line_list ['73d9a7f6d5', 'other'] Словарь: ['Продукты']
# ['73d9a7f6d5', 'other', ['Продукты']]
# Ключ найден 5ebea046cd ['Электроника']
# line_list ['5ebea046cd', 'other'] Словарь: ['Электроника']
# ['5ebea046cd', 'other', ['Электроника']]
# Ключ найден eb7ff574cc ['Электроника']
# line_list ['eb7ff574cc', 'context'] Словарь: ['Электроника']
# ['eb7ff574cc', 'context', ['Электроника']]
# Ключ найден ccfa85981e ['Бытовая техника']
# line_list ['ccfa85981e', 'other'] Словарь: ['Бытовая техника']
# ['ccfa85981e', 'other', ['Бытовая техника']]
# Ключ найден 3def3c47e0 ['Электроника']
# line_list ['3def3c47e0', 'email'] Словарь: ['Электроника']
# ['3def3c47e0', 'email', ['Электроника']]
# Ключ найден 56183e3be7 ['Продукты']
# line_list ['56183e3be7', 'other'] Словарь: ['Продукты']
# ['56183e3be7', 'other', ['Продукты']]
# Ключ найден 5a8c6a6214 ['Досуг']
# line_list ['5a8c6a6214', 'other'] Словарь: ['Досуг']
# ['5a8c6a6214', 'other', ['Досуг']]
# Ключ найден 9c6916078e ['Бытовая техника']
# line_list ['9c6916078e', 'other'] Словарь: ['Бытовая техника']
# ['9c6916078e', 'other', ['Бытовая техника']]
# Ключ найден f99c733c58 ['Электроника']
# line_list ['f99c733c58', 'other'] Словарь: ['Электроника']
# ['f99c733c58', 'other', ['Электроника']]
# Ключ найден 301db812db ['Электроника']
# line_list ['301db812db', 'other'] Словарь: ['Электроника']
# ['301db812db', 'other', ['Электроника']]
# Ключ найден 27be75d1bf ['Электроника']
# line_list ['27be75d1bf', 'other'] Словарь: ['Электроника']
# ['27be75d1bf', 'other', ['Электроника']]
# Ключ найден ba38172577 ['Досуг']
# line_list ['ba38172577', 'context'] Словарь: ['Досуг']
# ['ba38172577', 'context', ['Досуг']]
# Ключ найден f0706bb95e ['Продукты']
# line_list ['f0706bb95e', 'other'] Словарь: ['Продукты']
# ['f0706bb95e', 'other', ['Продукты']]
# Ключ найден ac317ed5da ['Электроника']
# line_list ['ac317ed5da', 'other'] Словарь: ['Электроника']
# ['ac317ed5da', 'other', ['Электроника']]
# Ключ найден 56ac42291c ['Электроника']
# line_list ['56ac42291c', 'other'] Словарь: ['Электроника']
# ['56ac42291c', 'other', ['Электроника']]
# Ключ найден d2e5eece34 ['Бытовая техника']
# line_list ['d2e5eece34', 'email'] Словарь: ['Бытовая техника']
# ['d2e5eece34', 'email', ['Бытовая техника']]
# Ключ найден 5e5398d531 ['Электроника']
# line_list ['5e5398d531', 'context'] Словарь: ['Электроника']
# ['5e5398d531', 'context', ['Электроника']]
# Ключ найден 7c62be614e ['Строительство и ремонт']
# line_list ['7c62be614e', 'other'] Словарь: ['Строительство и ремонт']
# ['7c62be614e', 'other', ['Строительство и ремонт']]
# Ключ найден 8b2f2ce9f1 ['Электроника']
# line_list ['8b2f2ce9f1', 'other'] Словарь: ['Электроника']
# ['8b2f2ce9f1', 'other', ['Электроника']]
# Ключ найден 8d726fa305 ['Бытовая техника']
# line_list ['8d726fa305', 'other'] Словарь: ['Бытовая техника']
# ['8d726fa305', 'other', ['Бытовая техника']]
# Ключ найден 81ebf6e699 ['Электроника']
# line_list ['81ebf6e699', 'other'] Словарь: ['Электроника']
# ['81ebf6e699', 'other', ['Электроника']]
# Ключ найден 2ffc0ac898 ['Продукты']
# line_list ['2ffc0ac898', 'other'] Словарь: ['Продукты']
# ['2ffc0ac898', 'other', ['Продукты']]
# Ключ найден 3953e7d027 ['Электроника']
# line_list ['3953e7d027', 'context'] Словарь: ['Электроника']
# ['3953e7d027', 'context', ['Электроника']]
# Ключ найден abbaaeeec6 ['Товары для животных']
# line_list ['abbaaeeec6', 'context'] Словарь: ['Товары для животных']
# ['abbaaeeec6', 'context', ['Товары для животных']]
# Ключ найден b3347f9015 ['Электроника']
# line_list ['b3347f9015', 'other'] Словарь: ['Электроника']
# ['b3347f9015', 'other', ['Электроника']]
# Ключ найден 5f4ccaec06 ['Электроника']
# line_list ['5f4ccaec06', 'context'] Словарь: ['Электроника']
# ['5f4ccaec06', 'context', ['Электроника']]
# Ключ найден 61f09c8e23 ['Электроника']
# line_list ['61f09c8e23', 'other'] Словарь: ['Электроника']
# ['61f09c8e23', 'other', ['Электроника']]
# Ключ найден d4004b3288 ['Досуг']
# line_list ['d4004b3288', 'other'] Словарь: ['Досуг']
# ['d4004b3288', 'other', ['Досуг']]
# Ключ найден ccdb17354a ['Продукты']
# line_list ['ccdb17354a', 'context'] Словарь: ['Продукты']
# ['ccdb17354a', 'context', ['Продукты']]
# Ключ найден 2f15ed507f ['Электроника']
# line_list ['2f15ed507f', 'other'] Словарь: ['Электроника']
# ['2f15ed507f', 'other', ['Электроника']]
# Ключ найден 1165b9e353 ['Досуг']
# line_list ['1165b9e353', 'email'] Словарь: ['Досуг']
# ['1165b9e353', 'email', ['Досуг']]
# Ключ найден 0a22ae5507 ['Электроника']
# line_list ['0a22ae5507', 'other'] Словарь: ['Электроника']
# ['0a22ae5507', 'other', ['Электроника']]
# Ключ найден e43e102688 ['Досуг']
# line_list ['e43e102688', 'other'] Словарь: ['Досуг']
# ['e43e102688', 'other', ['Досуг']]
# Ключ найден 7e33fda510 ['Электроника']
# line_list ['7e33fda510', 'other'] Словарь: ['Электроника']
# ['7e33fda510', 'other', ['Электроника']]
# Ключ найден 2da9fe5598 ['Электроника']
# line_list ['2da9fe5598', 'other'] Словарь: ['Электроника']
# ['2da9fe5598', 'other', ['Электроника']]
# Ключ найден bdec18f74e ['Продукты']
# line_list ['bdec18f74e', 'context'] Словарь: ['Продукты']
# ['bdec18f74e', 'context', ['Продукты']]
# Ключ найден 41a4f49b7f ['Электроника']
# line_list ['41a4f49b7f', 'other'] Словарь: ['Электроника']
# ['41a4f49b7f', 'other', ['Электроника']]
# Ключ найден 9df56d0753 ['Продукты']
# line_list ['9df56d0753', 'email'] Словарь: ['Продукты']
# ['9df56d0753', 'email', ['Продукты']]
# Ключ найден 4dd6cf0dea ['Строительство и ремонт']
# line_list ['4dd6cf0dea', 'other'] Словарь: ['Строительство и ремонт']
# ['4dd6cf0dea', 'other', ['Строительство и ремонт']]
# Ключ найден c86f800915 ['Бытовая техника']
# line_list ['c86f800915', 'other'] Словарь: ['Бытовая техника']
# ['c86f800915', 'other', ['Бытовая техника']]
# Ключ найден 422ac66d5a ['Электроника']
# line_list ['422ac66d5a', 'other'] Словарь: ['Электроника']
# ['422ac66d5a', 'other', ['Электроника']]
# Ключ найден 7ff7a48697 ['Электроника']
# line_list ['7ff7a48697', 'other'] Словарь: ['Электроника']
# ['7ff7a48697', 'other', ['Электроника']]
# Ключ найден d8557c45f3 ['Продукты']
# line_list ['d8557c45f3', 'other'] Словарь: ['Продукты']
# ['d8557c45f3', 'other', ['Продукты']]
# Ключ найден 04405bf835 ['Продукты']
# line_list ['04405bf835', 'other'] Словарь: ['Продукты']
# ['04405bf835', 'other', ['Продукты']]
# Ключ найден 987dc6321c ['Электроника']
# line_list ['987dc6321c', 'other'] Словарь: ['Электроника']
# ['987dc6321c', 'other', ['Электроника']]
# Ключ найден 48a32ff3cc ['Электроника']
# line_list ['48a32ff3cc', 'context'] Словарь: ['Электроника']
# ['48a32ff3cc', 'context', ['Электроника']]
# Ключ найден deba35d5a8 ['Бытовая техника']
# line_list ['deba35d5a8', 'other'] Словарь: ['Бытовая техника']
# ['deba35d5a8', 'other', ['Бытовая техника']]
# Ключ найден 42ec6aa3cb ['Продукты']
# line_list ['42ec6aa3cb', 'other'] Словарь: ['Продукты']
# ['42ec6aa3cb', 'other', ['Продукты']]
# Ключ найден 3f93050f90 ['Досуг']
# line_list ['3f93050f90', 'other'] Словарь: ['Досуг']
# ['3f93050f90', 'other', ['Досуг']]
# Ключ найден 8a0c7e0dfc ['Товары для животных']
# line_list ['8a0c7e0dfc', 'context'] Словарь: ['Товары для животных']
# ['8a0c7e0dfc', 'context', ['Товары для животных']]
# Ключ найден 73aa62d288 ['Электроника']
# line_list ['73aa62d288', 'other'] Словарь: ['Электроника']
# ['73aa62d288', 'other', ['Электроника']]
# Ключ найден 3e75e9c62e ['Электроника']
# line_list ['3e75e9c62e', 'other'] Словарь: ['Электроника']
# ['3e75e9c62e', 'other', ['Электроника']]
# Ключ найден c9ca4f00dd ['Продукты']
# line_list ['c9ca4f00dd', 'email'] Словарь: ['Продукты']
# ['c9ca4f00dd', 'email', ['Продукты']]
# Ключ найден 72d11d2013 ['Бытовая техника']
# line_list ['72d11d2013', 'context'] Словарь: ['Бытовая техника']
# ['72d11d2013', 'context', ['Бытовая техника']]
# Ключ найден 991072196d ['Бытовая техника']
# line_list ['991072196d', 'context'] Словарь: ['Бытовая техника']
# ['991072196d', 'context', ['Бытовая техника']]
# Ключ найден 092337723c ['Электроника']
# line_list ['092337723c', 'other'] Словарь: ['Электроника']
# ['092337723c', 'other', ['Электроника']]
# Ключ найден 642295148f ['Электроника']
# line_list ['642295148f', 'other'] Словарь: ['Электроника']
# ['642295148f', 'other', ['Электроника']]
# Ключ найден e8dcb49bc2 ['Досуг']
# line_list ['e8dcb49bc2', 'other'] Словарь: ['Досуг']
# ['e8dcb49bc2', 'other', ['Досуг']]
# Ключ найден b97069ed8f ['Бытовая техника']
# line_list ['b97069ed8f', 'other'] Словарь: ['Бытовая техника']
# ['b97069ed8f', 'other', ['Бытовая техника']]
# Ключ найден f127ee3e08 ['Бытовая техника']
# line_list ['f127ee3e08', 'other'] Словарь: ['Бытовая техника']
# ['f127ee3e08', 'other', ['Бытовая техника']]
# Ключ найден 78c61cf048 ['Электроника']
# line_list ['78c61cf048', 'other'] Словарь: ['Электроника']
# ['78c61cf048', 'other', ['Электроника']]
# Ключ найден 28ed9a2680 ['Товары для животных']
# line_list ['28ed9a2680', 'context'] Словарь: ['Товары для животных']
# ['28ed9a2680', 'context', ['Товары для животных']]
# Ключ найден 547434b3fc ['Строительство и ремонт']
# line_list ['547434b3fc', 'context'] Словарь: ['Строительство и ремонт']
# ['547434b3fc', 'context', ['Строительство и ремонт']]
# Ключ найден ec0d778ca8 ['Электроника']
# line_list ['ec0d778ca8', 'other'] Словарь: ['Электроника']
# ['ec0d778ca8', 'other', ['Электроника']]
# Ключ найден 0680efd24d ['Электроника']
# line_list ['0680efd24d', 'context'] Словарь: ['Электроника']
# ['0680efd24d', 'context', ['Электроника']]
# Ключ найден 8c6a576009 ['Бытовая техника']
# line_list ['8c6a576009', 'other'] Словарь: ['Бытовая техника']
# ['8c6a576009', 'other', ['Бытовая техника']]
# Ключ найден 26daa6bcff ['Товары для животных']
# line_list ['26daa6bcff', 'email'] Словарь: ['Товары для животных']
# ['26daa6bcff', 'email', ['Товары для животных']]
# Ключ найден 63eea77eac ['Досуг']
# line_list ['63eea77eac', 'other'] Словарь: ['Досуг']
# ['63eea77eac', 'other', ['Досуг']]
# Ключ найден a771274455 ['Строительство и ремонт']
# line_list ['a771274455', 'context'] Словарь: ['Строительство и ремонт']
# ['a771274455', 'context', ['Строительство и ремонт']]
# Ключ найден c92680024a ['Досуг']
# line_list ['c92680024a', 'context'] Словарь: ['Досуг']
# ['c92680024a', 'context', ['Досуг']]
# Ключ найден 0f359c5def ['Электроника']
# line_list ['0f359c5def', 'context'] Словарь: ['Электроника']
# ['0f359c5def', 'context', ['Электроника']]
# Ключ найден 81b86551e0 ['Товары для животных']
# line_list ['81b86551e0', 'other'] Словарь: ['Товары для животных']
# ['81b86551e0', 'other', ['Товары для животных']]
# Ключ найден b694d9fb7e ['не определена']
# line_list ['b694d9fb7e', 'context'] Словарь: ['не определена']
# ['b694d9fb7e', 'context', ['не определена']]
# Ключ найден 34abde015c ['Бытовая техника']
# line_list ['34abde015c', 'other'] Словарь: ['Бытовая техника']
# ['34abde015c', 'other', ['Бытовая техника']]
# Ключ найден 2feeed4e90 ['Электроника']
# line_list ['2feeed4e90', 'context'] Словарь: ['Электроника']
# ['2feeed4e90', 'context', ['Электроника']]
# Ключ найден e50f766aee ['Электроника']
# line_list ['e50f766aee', 'other'] Словарь: ['Электроника']
# ['e50f766aee', 'other', ['Электроника']]
# Ключ найден 773030b2e2 ['Бытовая техника']
# line_list ['773030b2e2', 'context'] Словарь: ['Бытовая техника']
# ['773030b2e2', 'context', ['Бытовая техника']]
# Ключ найден a760d2ebe8 ['Электроника']
# line_list ['a760d2ebe8', 'other'] Словарь: ['Электроника']
# ['a760d2ebe8', 'other', ['Электроника']]
# Ключ найден b45d0d2b02 ['Электроника']
# line_list ['b45d0d2b02', 'other'] Словарь: ['Электроника']
# ['b45d0d2b02', 'other', ['Электроника']]
# Ключ найден 61c29f2324 ['Электроника']
# line_list ['61c29f2324', 'other'] Словарь: ['Электроника']
# ['61c29f2324', 'other', ['Электроника']]
# Ключ найден da177dee2e ['Досуг']
# line_list ['da177dee2e', 'email'] Словарь: ['Досуг']
# ['da177dee2e', 'email', ['Досуг']]
# Ключ найден e2389b2f7d ['Электроника']
# line_list ['e2389b2f7d', 'context'] Словарь: ['Электроника']
# ...
# ['e758146335', 'other', ['Строительство и ремонт']]
# Ключ найден cd905c57aa ['Бытовая техника']
# line_list ['cd905c57aa', 'None'] Словарь: ['Бытовая техника']
# ['cd905c57aa', 'None', ['Бытовая техника']]
# Ключ найден f3e91cb543 ['Досуг']
# line_list ['f3e91cb543', 'other'] Словарь: ['Досуг']
# ['f3e91cb543', 'other', ['Досуг']]
# Ключ найден 622b25f483 ['Досуг']
# line_list ['622b25f483', 'email'] Словарь: ['Досуг']
# ['622b25f483', 'email', ['Досуг']]
# Ключ найден f03ff3dbe8 ['Бытовая техника']
# line_list ['f03ff3dbe8', 'other'] Словарь: ['Бытовая техника']
# ['f03ff3dbe8', 'other', ['Бытовая техника']]
# Ключ найден a428e6da78 ['Электроника']
# line_list ['a428e6da78', 'other'] Словарь: ['Электроника']
# ['a428e6da78', 'other', ['Электроника']]
# Ключ найден 26a7174934 ['Продукты']
# line_list ['26a7174934', 'other'] Словарь: ['Продукты']
# ['26a7174934', 'other', ['Продукты']]
# Ключ найден 66e34ca328 ['Электроника']
# line_list ['66e34ca328', 'None'] Словарь: ['Электроника']
# ['66e34ca328', 'None', ['Электроника']]
# Ключ найден fb521bdcb1 ['Товары для животных']
# line_list ['fb521bdcb1', 'context'] Словарь: ['Товары для животных']
# ['fb521bdcb1', 'context', ['Товары для животных']]
# Ключ найден f14963f9be ['Досуг']
# line_list ['f14963f9be', 'other'] Словарь: ['Досуг']
# ['f14963f9be', 'other', ['Досуг']]
# Ключ найден b4ad705953 ['Электроника']
# line_list ['b4ad705953', 'other'] Словарь: ['Электроника']
# ['b4ad705953', 'other', ['Электроника']]
# Ключ найден 0d95f296f1 ['Бытовая техника']
# line_list ['0d95f296f1', 'other'] Словарь: ['Бытовая техника']
# ['0d95f296f1', 'other', ['Бытовая техника']]
# Ключ найден 95c8e0dc1b ['Электроника']
# line_list ['95c8e0dc1b', 'other'] Словарь: ['Электроника']
# ['95c8e0dc1b', 'other', ['Электроника']]
# Ключ найден d0421ad83c ['Электроника']
# line_list ['d0421ad83c', 'other'] Словарь: ['Электроника']
# ['d0421ad83c', 'other', ['Электроника']]
# Ключ найден 70764ab921 ['Продукты']
# line_list ['70764ab921', 'other'] Словарь: ['Продукты']
# ['70764ab921', 'other', ['Продукты']]
# Ключ найден eca409e56d ['Электроника']
# line_list ['eca409e56d', 'other'] Словарь: ['Электроника']
# ['eca409e56d', 'other', ['Электроника']]
# Ключ найден 5339ab841d ['Досуг']
# line_list ['5339ab841d', 'context'] Словарь: ['Досуг']
# ['5339ab841d', 'context', ['Досуг']]
# Ключ найден 9cd0b65ede ['Бытовая техника']
# line_list ['9cd0b65ede', 'other'] Словарь: ['Бытовая техника']
# ['9cd0b65ede', 'other', ['Бытовая техника']]
# Ключ найден 8a0143c024 ['Электроника']
# line_list ['8a0143c024', 'other'] Словарь: ['Электроника']
# ['8a0143c024', 'other', ['Электроника']]
# Ключ найден a1191d281e ['Бытовая техника']
# line_list ['a1191d281e', 'context'] Словарь: ['Бытовая техника']
# ['a1191d281e', 'context', ['Бытовая техника']]
# Ключ найден 02e34084cb ['Электроника']
# line_list ['02e34084cb', 'context'] Словарь: ['Электроника']
# ['02e34084cb', 'context', ['Электроника']]
# Ключ найден a73cac6b9a ['Бытовая техника']
# line_list ['a73cac6b9a', 'other'] Словарь: ['Бытовая техника']
# ['a73cac6b9a', 'other', ['Бытовая техника']]
# Ключ найден 901a2a0612 ['Продукты']
# line_list ['901a2a0612', 'other'] Словарь: ['Продукты']
# ['901a2a0612', 'other', ['Продукты']]
# Ключ найден 6dc224d8f1 ['Электроника']
# line_list ['6dc224d8f1', 'other'] Словарь: ['Электроника']
# ['6dc224d8f1', 'other', ['Электроника']]
# Ключ найден a002904e49 ['Бытовая техника']
# line_list ['a002904e49', 'other'] Словарь: ['Бытовая техника']
# ['a002904e49', 'other', ['Бытовая техника']]
# Ключ найден f7f784d26d ['Бытовая техника']
# line_list ['f7f784d26d', 'other'] Словарь: ['Бытовая техника']
# ['f7f784d26d', 'other', ['Бытовая техника']]
# Ключ найден 1eb58523e7 ['Бытовая техника']
# line_list ['1eb58523e7', 'other'] Словарь: ['Бытовая техника']
# ['1eb58523e7', 'other', ['Бытовая техника']]
# Ключ найден ded30b0f2d ['Товары для животных']
# line_list ['ded30b0f2d', 'other'] Словарь: ['Товары для животных']
# ['ded30b0f2d', 'other', ['Товары для животных']]
# Ключ найден 90f80bcea2 ['Досуг']
# line_list ['90f80bcea2', 'other'] Словарь: ['Досуг']
# ['90f80bcea2', 'other', ['Досуг']]
# Ключ найден 742dd9666c ['Товары для животных']
# line_list ['742dd9666c', 'context'] Словарь: ['Товары для животных']
# ['742dd9666c', 'context', ['Товары для животных']]
# Ключ найден 9318c6b9e4 ['Досуг']
# line_list ['9318c6b9e4', 'context'] Словарь: ['Досуг']
# ['9318c6b9e4', 'context', ['Досуг']]
# Ключ найден d9ab9329bf ['Продукты']
# line_list ['d9ab9329bf', 'context'] Словарь: ['Продукты']
# ['d9ab9329bf', 'context', ['Продукты']]
# Ключ найден a4bd6b796e ['Досуг']
# line_list ['a4bd6b796e', 'context'] Словарь: ['Досуг']
# ['a4bd6b796e', 'context', ['Досуг']]
# Ключ найден 7735ac7082 ['Бытовая техника']
# line_list ['7735ac7082', 'email'] Словарь: ['Бытовая техника']
# ['7735ac7082', 'email', ['Бытовая техника']]
# Ключ найден f5b67594ab ['Электроника']
# line_list ['f5b67594ab', 'other'] Словарь: ['Электроника']
# ['f5b67594ab', 'other', ['Электроника']]
# Ключ найден 3d21113c5c ['Строительство и ремонт']
# line_list ['3d21113c5c', 'other'] Словарь: ['Строительство и ремонт']
# ['3d21113c5c', 'other', ['Строительство и ремонт']]
# Ключ найден b70c884c54 ['Строительство и ремонт']
# line_list ['b70c884c54', 'email'] Словарь: ['Строительство и ремонт']
# ['b70c884c54', 'email', ['Строительство и ремонт']]
# Ключ найден 71439d55c1 ['Товары для животных']
# line_list ['71439d55c1', 'context'] Словарь: ['Товары для животных']
# ['71439d55c1', 'context', ['Товары для животных']]
# Ключ найден 8d62a06095 ['Электроника']
# line_list ['8d62a06095', 'email'] Словарь: ['Электроника']
# ['8d62a06095', 'email', ['Электроника']]
# Ключ найден 1feae681af ['Продукты']
# line_list ['1feae681af', 'other'] Словарь: ['Продукты']
# ['1feae681af', 'other', ['Продукты']]
# Ключ найден b4ffc06119 ['Товары для животных']
# line_list ['b4ffc06119', 'context'] Словарь: ['Товары для животных']
# ['b4ffc06119', 'context', ['Товары для животных']]
# Ключ найден 7ab1eec6c8 ['Бытовая техника']
# line_list ['7ab1eec6c8', 'other'] Словарь: ['Бытовая техника']
# ['7ab1eec6c8', 'other', ['Бытовая техника']]
# Ключ найден 5b0b36c12d ['Бытовая техника']
# line_list ['5b0b36c12d', 'other'] Словарь: ['Бытовая техника']
# ['5b0b36c12d', 'other', ['Бытовая техника']]
# Ключ найден 39dc1d0b39 ['Электроника']
# line_list ['39dc1d0b39', 'other'] Словарь: ['Электроника']
# ['39dc1d0b39', 'other', ['Электроника']]
# Ключ найден 4d0a159581 ['Товары для животных']
# line_list ['4d0a159581', 'context'] Словарь: ['Товары для животных']
# ['4d0a159581', 'context', ['Товары для животных']]
# Ключ найден 76e40432fa ['Электроника']
# line_list ['76e40432fa', 'other'] Словарь: ['Электроника']
# ['76e40432fa', 'other', ['Электроника']]
# Ключ найден fa3b6fba7c ['Бытовая техника']
# line_list ['fa3b6fba7c', 'email'] Словарь: ['Бытовая техника']
# ['fa3b6fba7c', 'email', ['Бытовая техника']]
# Ключ найден 45176343fb ['Продукты']
# line_list ['45176343fb', 'context'] Словарь: ['Продукты']
# ['45176343fb', 'context', ['Продукты']]
# Ключ найден 2be2563901 ['Электроника']
# line_list ['2be2563901', 'context'] Словарь: ['Электроника']
# ['2be2563901', 'context', ['Электроника']]
# Ключ найден fd63fc3138 ['Бытовая техника']
# line_list ['fd63fc3138', 'other'] Словарь: ['Бытовая техника']
# ['fd63fc3138', 'other', ['Бытовая техника']]
# Ключ найден d8dd615b78 ['Бытовая техника']
# line_list ['d8dd615b78', 'other'] Словарь: ['Бытовая техника']
# ['d8dd615b78', 'other', ['Бытовая техника']]
# Ключ найден 3029dd6c1a ['Электроника']
# line_list ['3029dd6c1a', 'context'] Словарь: ['Электроника']
# ['3029dd6c1a', 'context', ['Электроника']]
# Ключ найден d9fd51e640 ['Электроника']
# line_list ['d9fd51e640', 'other'] Словарь: ['Электроника']
# ['d9fd51e640', 'other', ['Электроника']]
# Ключ найден 1387a98f60 ['Бытовая техника']
# line_list ['1387a98f60', 'other'] Словарь: ['Бытовая техника']
# ['1387a98f60', 'other', ['Бытовая техника']]
# Ключ найден 429da32fee ['Электроника']
# line_list ['429da32fee', 'other'] Словарь: ['Электроника']
# ['429da32fee', 'other', ['Электроника']]
# Ключ найден 8d2ce84203 ['Досуг']
# line_list ['8d2ce84203', 'other'] Словарь: ['Досуг']
# ['8d2ce84203', 'other', ['Досуг']]
# Ключ найден a055824cdc ['Досуг']
# line_list ['a055824cdc', 'other'] Словарь: ['Досуг']
# ['a055824cdc', 'other', ['Досуг']]
# Ключ найден 464faddee3 ['Электроника']
# line_list ['464faddee3', 'other'] Словарь: ['Электроника']
# ['464faddee3', 'other', ['Электроника']]
# Ключ найден 8393f7c1e4 ['Бытовая техника']
# line_list ['8393f7c1e4', 'context'] Словарь: ['Бытовая техника']
# ['8393f7c1e4', 'context', ['Бытовая техника']]
# Ключ найден 10ba855d84 ['Товары для животных']
# line_list ['10ba855d84', 'context'] Словарь: ['Товары для животных']
# ['10ba855d84', 'context', ['Товары для животных']]
# Ключ найден 9e663cc486 ['Продукты']
# line_list ['9e663cc486', 'context'] Словарь: ['Продукты']
# ['9e663cc486', 'context', ['Продукты']]
# Ключ найден 004e4cdfe6 ['Бытовая техника']
# line_list ['004e4cdfe6', 'context'] Словарь: ['Бытовая техника']
# ['004e4cdfe6', 'context', ['Бытовая техника']]
# Ключ найден ce5fb6b9e1 ['Электроника']
# line_list ['ce5fb6b9e1', 'other'] Словарь: ['Электроника']
# ['ce5fb6b9e1', 'other', ['Электроника']]
# Ключ найден 069ecab1ae ['Строительство и ремонт']
# line_list ['069ecab1ae', 'other'] Словарь: ['Строительство и ремонт']
# ['069ecab1ae', 'other', ['Строительство и ремонт']]
# Ключ найден 8c5f3b9e62 ['Бытовая техника']
# line_list ['8c5f3b9e62', 'other'] Словарь: ['Бытовая техника']
# ['8c5f3b9e62', 'other', ['Бытовая техника']]
# Ключ найден 5d3d597428 ['Товары для животных']
# line_list ['5d3d597428', 'other'] Словарь: ['Товары для животных']
# ['5d3d597428', 'other', ['Товары для животных']]
# Ключ найден ab07e8520a ['не определена']
# line_list ['ab07e8520a', 'other'] Словарь: ['не определена']
# ['ab07e8520a', 'other', ['не определена']]
# Ключ найден 9d4fe1902c ['Строительство и ремонт']
# line_list ['9d4fe1902c', 'context'] Словарь: ['Строительство и ремонт']
# ['9d4fe1902c', 'context', ['Строительство и ремонт']]
# Ключ найден 919e245372 ['Электроника']
# line_list ['919e245372', 'other'] Словарь: ['Электроника']
# ['919e245372', 'other', ['Электроника']]
# Ключ найден 92216bd918 ['Электроника']
# line_list ['92216bd918', 'other'] Словарь: ['Электроника']
# ['92216bd918', 'other', ['Электроника']]
# Ключ найден b9bca3bd75 ['Товары для животных']
# line_list ['b9bca3bd75', 'email'] Словарь: ['Товары для животных']
# ['b9bca3bd75', 'email', ['Товары для животных']]
# Ключ найден a261006f7d ['Строительство и ремонт', 'Бытовая техника']
# line_list ['a261006f7d', 'context'] Словарь: ['Строительство и ремонт', 'Бытовая техника']
# ['a261006f7d', 'context', ['Строительство и ремонт', 'Бытовая техника']]
# Ключ найден d611c0bdf1 ['Товары для животных']
# line_list ['d611c0bdf1', 'other'] Словарь: ['Товары для животных']
# ['d611c0bdf1', 'other', ['Товары для животных']]
# Ключ найден b9d8f0da57 ['Досуг']
# line_list ['b9d8f0da57', 'other'] Словарь: ['Досуг']
# ['b9d8f0da57', 'other', ['Досуг']]
# Ключ найден 4bb528651b ['Бытовая техника']
# line_list ['4bb528651b', 'other'] Словарь: ['Бытовая техника']
# ['4bb528651b', 'other', ['Бытовая техника']]
# Ключ найден b0fab399d7 ['Электроника']
# line_list ['b0fab399d7', 'other'] Словарь: ['Электроника']
# ['b0fab399d7', 'other', ['Электроника']]
# Ключ найден 2342c299ce ['Товары для животных']
# line_list ['2342c299ce', 'other'] Словарь: ['Товары для животных']
# ['2342c299ce', 'other', ['Товары для животных']]
# Ключ найден b951fb06e6 ['Электроника']
# line_list ['b951fb06e6', 'email'] Словарь: ['Электроника']
# ['b951fb06e6', 'email', ['Электроника']]
# Ключ найден a45bbd7bd5 ['Электроника']
# line_list ['a45bbd7bd5', 'other'] Словарь: ['Электроника']
# ['a45bbd7bd5', 'other', ['Электроника']]
# Ключ найден 71edaae03e ['Электроника']
# line_list ['71edaae03e', 'other'] Словарь: ['Электроника']
# ['71edaae03e', 'other', ['Электроника']]
# Ключ найден 88b1ba09e2 ['Досуг']
# line_list ['88b1ba09e2', 'context'] Словарь: ['Досуг']
# ['88b1ba09e2', 'context', ['Досуг']]
# Ключ найден cac7b93244 ['Электроника']
# line_list ['cac7b93244', 'other'] Словарь: ['Электроника']
# ['cac7b93244', 'other', ['Электроника']]
# Ключ найден aa9b08050a ['Товары для животных']
# line_list ['aa9b08050a', 'context'] Словарь: ['Товары для животных']
# ['aa9b08050a', 'context', ['Товары для животных']]
# Ключ найден 432b9cae38 ['Электроника']
# line_list ['432b9cae38', 'other'] Словарь: ['Электроника']
# ['432b9cae38', 'other', ['Электроника']]
# Ключ найден 633cbfba4e ['Электроника']
# line_list ['633cbfba4e', 'other'] Словарь: ['Электроника']
# ['633cbfba4e', 'other', ['Электроника']]
# Ключ найден 5921482738 ['Бытовая техника']
# line_list ['5921482738', 'other'] Словарь: ['Бытовая техника']
# ['5921482738', 'other', ['Бытовая техника']]
# Ключ найден 0f3ed5571c ['Строительство и ремонт']
# line_list ['0f3ed5571c', 'other'] Словарь: ['Строительство и ремонт']
# ['0f3ed5571c', 'other', ['Строительство и ремонт']]
# Ключ найден c4f2ae309e ['Электроника']
# line_list ['c4f2ae309e', 'other'] Словарь: ['Электроника']
# ['c4f2ae309e', 'other', ['Электроника']]
# Ключ найден 533062ddec ['Досуг']
# line_list ['533062ddec', 'other'] Словарь: ['Досуг']
# ['533062ddec', 'other', ['Досуг']]
# Ключ найден 4bab171829 ['Электроника']
# line_list ['4bab171829', 'other'] Словарь: ['Электроника']
# ['4bab171829', 'other', ['Электроника']]
# Ключ найден 5c607da34b ['Досуг']
# line_list ['5c607da34b', 'email'] Словарь: ['Досуг']
# ['5c607da34b', 'email', ['Досуг']]
# Ключ найден 11134918c7 ['Товары для животных']
# line_list ['11134918c7', 'other'] Словарь: ['Товары для животных']
# ['11134918c7', 'other', ['Товары для животных']]
# Ключ найден a6520bd626 ['Бытовая техника']
# line_list ['a6520bd626', 'other'] Словарь: ['Бытовая техника']
# ['a6520bd626', 'other', ['Бытовая техника']]
# Ключ найден 0138caf64f ['Продукты']
# line_list ['0138caf64f', 'other'] Словарь: ['Продукты']
# ['0138caf64f', 'other', ['Продукты']]
# Ключ найден 6795894998 ['Электроника']
# line_list ['6795894998', 'context'] Словарь: ['Электроника']
# ['6795894998', 'context', ['Электроника']]
# Ключ найден a27d801529 ['Строительство и ремонт']
# line_list ['a27d801529', 'context'] Словарь: ['Строительство и ремонт']
# ['a27d801529', 'context', ['Строительство и ремонт']]
# Ключ найден 99d70f8705 ['Бытовая техника']
# line_list ['99d70f8705', 'other'] Словарь: ['Бытовая техника']
# ['99d70f8705', 'other', ['Бытовая техника']]
# Ключ найден 32dfa9a18a ['Бытовая техника']
# line_list ['32dfa9a18a', 'other'] Словарь: ['Бытовая техника']
# ['32dfa9a18a', 'other', ['Бытовая техника']]
# Ключ найден 88c64d7399 ['Бытовая техника']
# line_list ['88c64d7399', 'context'] Словарь: ['Бытовая техника']
# ['88c64d7399', 'context', ['Бытовая техника']]
# Ключ найден 3e76a5f0c5 ['Бытовая техника']
# line_list ['3e76a5f0c5', 'other'] Словарь: ['Бытовая техника']
# ['3e76a5f0c5', 'other', ['Бытовая техника']]
# Ключ найден 415cc39944 ['Строительство и ремонт']
# line_list ['415cc39944', 'other'] Словарь: ['Строительство и ремонт']
# ['415cc39944', 'other', ['Строительство и ремонт']]
# Ключ найден d457ef8c36 ['Электроника']
# line_list ['d457ef8c36', 'context'] Словарь: ['Электроника']
# ['d457ef8c36', 'context', ['Электроника']]
# Ключ найден cb2da172f8 ['Строительство и ремонт']
# line_list ['cb2da172f8', 'other'] Словарь: ['Строительство и ремонт']
# ['cb2da172f8', 'other', ['Строительство и ремонт']]
# Ключ найден 047fbda813 ['Бытовая техника']
# line_list ['047fbda813', 'other'] Словарь: ['Бытовая техника']
# ['047fbda813', 'other', ['Бытовая техника']]
# Ключ найден cf797f912d ['Бытовая техника']
# line_list ['cf797f912d', 'other'] Словарь: ['Бытовая техника']
# ['cf797f912d', 'other', ['Бытовая техника']]
# Ключ найден 9ff57c335f ['Товары для животных']
# line_list ['9ff57c335f', 'context'] Словарь: ['Товары для животных']
# ['9ff57c335f', 'context', ['Товары для животных']]
# Ключ найден bdc8054507 ['Электроника']
# line_list ['bdc8054507', 'other'] Словарь: ['Электроника']
# ['bdc8054507', 'other', ['Электроника']]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13798 entries, 0 to 13797
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   13798 non-null  object
#  1   source    13798 non-null  object
#  2   category  13798 non-null  object
# dtypes: object(3)
# memory usage: 323.5+ KB

# %% [markdown]
# Начало датасета:

# %%
df.head(20)

# %% [markdown]
# Частоты категорий:

# %%
df['category'].value_counts()

# %% [markdown]
# Частоты по каналам прихода лидов:

# %%
df['source'].value_counts()
