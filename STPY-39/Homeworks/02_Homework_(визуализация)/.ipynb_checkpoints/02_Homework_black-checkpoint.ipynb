# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 11,7

# %% [markdown]
# ###### Обязательная часть
# Вам необходимо провести базовый EDA выбранного набора данных.
#
# **Требования к анализу:**
#
#     построить не менее 4 визуализаций различных видов;
#     каждая визуализация должным образом оформлена и читается даже в отрыве от контекста;
#     по каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).

# %% [markdown]
# Источник данных для **EDA-анализа** - рейтинг высших учебных заведений России "Национальное признание": https://univer.expert/akademicheskiye-reytingi-vuzov-2022/obshchiy-reyting-2022/,
#
#
# Для анализа интересен по следующим соображениям:
# 1. Наличие бальной характеристики.
# 2. Наличие разбивки по регионам (городам).
# 3. Наличие дополнительной категориальной характеристики - участие в проекте 2030
#
# Сам рейтинг имеет серьёзные ограничения по областям применения о чем говорят и сами разработчики.
# https://univer.expert/akademicheskiye-reytingi-vuzov-2021/metodologiya-reytinga-2021/#12
# См. например позицию Университета "Иннополис"

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %% [markdown]
# Исходные ВУЗов с ненулевым рейтингом в количестве 614 строк данные методом Copy->Past были скопированы со страницы https://univer.expert/akademicheskiye-reytingi-vuzov-2022/obshchiy-reyting-2022/ в файл формата "MS Excel" **high_school_rating.xlsx** .
#
#
# Название и значения столбцов:
#
#
# * rank - позиция в рейтинге (int8)
# * name - полное наименование ВУЗа (object)
# * city  - город расположения
# * status - статус участия в национальном проекте «Приоритет-2030» (object)
# * points - количество набранных баллов по методике оценивания (float32)

# %%
# ?pd.read_excel

# %%
# прочитаем данные в датафрейм pandas:
df = pd.read_excel('high_school_rating.xlsx', 
                   sheet_name='2022', 
                   dtype = {
                        "Rank": 'Float16',  
                        "Points": 'Float16'
                            }
                  )
# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None)
# Сброс ограничений на количество выводимых строк
pd.set_option('display.max_rows', None)
#pd.set_option('display.colheader_justify', 'right' )
df
# Out:
#       Rank  \
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# 20    21.0
# 21    22.0
# 22    23.0
# 23    24.0
# 24    25.0
# 25    26.0
# 26    27.0
# 27    28.0
# 28    29.0
# 29    30.0
# 30    31.0
# 31    32.0
# 32    33.0
# 33    34.0
# 34    35.0
# 35    36.0
# 36    37.0
# 37    38.0
# 38    39.0
# 39    40.0
# 40    41.0
# 41    42.0
# 42    43.0
# 43    44.0
# 44    45.0
# 45    46.0
# 46    47.0
# 47    48.0
# 48    49.0
# 49    50.0
# 50    51.0
# 51    52.0
# 52    53.0
# 53    54.0
# 54    55.0
# 55    56.0
# 56    57.0
# 57    58.0
# 58    59.0
# 59    60.0
# 60    61.0
# 61    62.0
# 62    63.0
# 63    64.0
# 64    65.0
# 65    66.0
# 66    67.0
# 67    68.0
# 560          Не участник                 Хабаровск     0.759766
# 561          Не участник                    Пущино     0.750000
# 562          Не участник           Санкт-Петербург     0.729980
# 563          Не участник                Красноярск     0.689941
# 564          Не участник                    Москва     0.680176
# 565          Не участник                   Воронеж     0.680176
# 566          Не участник              Невинномысск     0.669922
# 567          Не участник           Санкт-Петербург     0.620117
# 568          Не участник                 Челябинск     0.580078
# 569          Не участник                    Москва     0.560059
# 570          Не участник                    Москва     0.529785
# 571          Не участник                    Казань     0.500000
# 572          Не участник                 Челябинск     0.479980
# 573          Не участник                 Краснодар     0.459961
# 574          Не участник                    Москва     0.459961
# 575          Не участник                    Видное     0.449951
# 576        Базовый грант                    Москва     0.439941
# 577          Не участник           Санкт-Петербург     0.419922
# 578          Не участник           Санкт-Петербург     0.409912
# 579          Не участник                 Астрахань     0.399902
# 580          Не участник                  Смоленск     0.389893
# 581          Не участник             Сергиев Посад     0.379883
# 582          Не участник                    Москва     0.370117
# 583          Не участник                    Москва     0.350098
# 584          Не участник                      Омск     0.320068
# 585          Не участник                     Курск     0.320068
# 586          Не участник                    Москва     0.290039
# 587          Не участник            Ростов-на-Дону     0.250000
# 588          Не участник                    Москва     0.239990
# 589          Не участник              Магнитогорск     0.229980
# 590          Не участник                    Москва     0.219971
# 591          Не участник               Симферополь     0.209961
# 592          Не участник                    Москва     0.209961
# 593          Не участник                   Воронеж     0.209961
# 594          Не участник               Симферополь     0.180054
# 595          Не участник                    Москва     0.180054
# 596          Не участник                     Тверь     0.180054
# 597          Не участник                   Нальчик     0.160034
# 598          Не участник                   Чурапча     0.150024
# 599          Не участник                   Саратов     0.140015
# 600          Не участник                   Армавир     0.140015
# 601          Не участник                  Красково     0.130005
# 602          Не участник                    Казань     0.130005
# 603          Не участник                 Хабаровск     0.119995
# 604          Не участник                  Норильск     0.099976
# 605          Не участник                    Москва     0.099976
# 606          Не участник                   Саратов     0.090027
# 607          Не участник                 Волгоград     0.090027
# 608          Не участник                 Чебоксары     0.080017
# 609          Не участник                  Кострома     0.080017
# 610          Не участник                  Тольятти     0.070007
# 611          Не участник                 Волгоград     0.070007
# 612          Не участник                    Якутск     0.049988
# 613          Не участник                   Воронеж     0.029999

# %% [markdown]
# Общие характеристики:

# %%
df.info()
# Увидеть пропуски (они были) и исправить в исходнике
df[df.isnull().any(axis=1)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    614 non-null    float16
#  1   Name    614 non-null    object
#  2   Status  614 non-null    object
#  3   City    614 non-null    object
#  4   Points  614 non-null    float16
# dtypes: float16(2), object(3)
# memory usage: 16.9+ KB
# Empty DataFrame
# Columns: [Rank, Name, Status, City, Points]
# Index: []

# %% [markdown]
# Общее статистическое описание датафрейма:

# %%
df.describe()
# Out:
#          Rank       Points
# count  614.00   614.000000
# mean      inf    50.375000
# std       inf          inf
# min      1.00     0.029999
# 25%    154.25     3.152832
# 50%    307.50    13.988281
# 75%    460.75    36.781250
# max    614.00  2332.000000

# %%
Даже без дополнительного анализа виден разрыв между лучшми и слабыми ВУЗами России
# Out:
#   File "<ipython-input-116-416025264b09>", line 1
#     Даже без дополнительного анализа виден разрыв между лучшми и слабыми ВУЗами России
#          ^
# SyntaxError: invalid syntax

# %%
IQR_points = df['Points'].quantile(0.75) - df['Points'].quantile(0.25)
print(f'Межквартильный размах для всех ВУЗов: {IQR_points:.2f}')

# %%
Лучшие ВУЗы России с точки зрения описательной статистики очевидно попадут в нетипичные выбросы:

# %%
# Расчёт выбросов для столбца "Points" по «внутренним границам»:
q1 = df['Points'].quantile(0.25)
q3 = df['Points'].quantile(0.75)
iqr = q3 - q1
lower_bound_int = q1 - (1.5 * iqr) 
upper_bound_int = q3 + (1.5 * iqr)
print ('Значение "выбросов" столбца рейтинга по "внутренним границам" (1,5 межквартильного размаха):')
df_abnormal = df[~df['Points'].between(lower_bound_int, upper_bound_int, inclusive=True)]
df_abnormal
# Out:
# Значение "выбросов" столбца рейтинга по "внутренним границам" (1,5 межквартильного размаха):
#     Rank  \
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    8.0
# 8    9.0
# 9   10.0
# 10  11.0
# 11  12.0
# 12  13.0
# 13  14.0
# 14  15.0
# 15  16.0
# 16  17.0
# 17  18.0
# 18  19.0
# 19  20.0
# 20  21.0
# 21  22.0
# 22  23.0
# 23  24.0
# 24  25.0
# 25  26.0
# 26  27.0
# 27  28.0
# 28  29.0
# 29  30.0
# 30  31.0
# 31  32.0
# 32  33.0
# 33  34.0
# 34  35.0
# 35  36.0
# 36  37.0
# 37  38.0
# 38  39.0
# 39  40.0
# 40  41.0
# 41  42.0
# 42  43.0
# 43  44.0
# 44  45.0
# 45  46.0
# 46  47.0
# 47  48.0
# 48  49.0
# 49  50.0
# 50  51.0
# 51  52.0
# 52  53.0
# 53  54.0
# 54  55.0
# 55  56.0
# 56  57.0
# 57  58.0
# 58  59.0
# 59  60.0
# 60  61.0
# 61  62.0
# 62  63.0
# 63  64.0
# 64  65.0
# 65  66.0
# 66  67.0
# 67  68.0
# 68  69.0
# 69  70.0
# 70  71.0
# 71  72.0
# 72  73.0
# 73  74.0
# 74  75.0
# 75  76.0
# 76  77.0
# 77  78.0
# 78  79.0
# 79  80.0
# 80  81.0
# 81  82.0
#
#                                                                                                                    Name  \
# 0                                                          Московский государственный университет имени М.В. Ломоносова
# 1                                                                       Санкт-Петербургский государственный университет
# 2                                                   Национальный исследовательский университет “Высшая школа экономики”
# 3    Московский государственный технический университет имени Н.Э. Баумана (национальный исследовательский университет)
# 4                                                        Санкт-Петербургский политехнический университет Петра Великого
# 5                  Российская академия народного хозяйства и государственной службы при Президенте Российской Федерации
# 6                                         Первый Московский государственный медицинский университет имени И.М. Сеченова
# 7                                                                       Казанский (Приволжский) федеральный университет
# 8                                                             Российский экономический университет имени Г.В. Плеханова
# 9                          Уральский федеральный университет имени первого Президента Российской Федерации Б.Н. Ельцина
# 10                                                                                        Южный федеральный университет
# 11                                                                                Российский университет дружбы народов
# 12                                                              Национальный исследовательский ядерный университет МИФИ
# 13                                                   Национальный исследовательский Томский государственный университет
# 14                                                   Национальный исследовательский Томский политехнический университет
# 73                                                                  Российский государственный гуманитарный университет
# 74                             Казанский национальный исследовательский технический университет имени А.Н. Туполева-КАИ
# 75                                                                               Санкт-Петербургский горный университет
# 76                                                                    Сибирский государственный медицинский университет
# 77                                                                                Алтайский государственный университет
# 78                                                                Кубанский государственный технологический университет
# 79                          Первый Санкт-Петербургский государственный медицинский университет имени акад. И.П. Павлова
# 80                                    Петербургский государственный университет путей сообщения Императора Александра I
# 81                                                                                Кубанский государственный университет
#
#                  Status             City     Points
# 0      «Над программой»           Москва  2332.0000
# 1      «Над программой»  Санкт-Петербург   876.5000
# 2           Первая лига           Москва   792.0000
# 3           Первая лига           Москва   681.0000
# 4           Первая лига  Санкт-Петербург   598.5000
# 5           Первая лига           Москва   566.5000
# 6           Вторая лига           Москва   564.5000
# 7           Первая лига           Казань   550.0000
# 8         Базовый грант           Москва   508.7500
# 9           Первая лига     Екатеринбург   490.7500
# 10          Третья лига   Ростов-на-Дону   440.7500
# 11        Базовый грант           Москва   428.2500
# 12          Первая лига           Москва   422.5000
# 13          Первая лига            Томск   417.7500
# 14          Первая лига            Томск   406.2500
# 15          Не участник           Москва   401.2500
# 16          Вторая лига  Нижний Новгород   373.0000
# 17          Первая лига           Москва   360.7500
# 18          Вторая лига           Москва   322.0000
# 19          Третья лига       Красноярск   300.2500
# 20          Третья лига       Ставрополь   293.0000
# 21          Третья лига        Челябинск   287.2500
# 22        Базовый грант           Москва   284.0000
# 23          Третья лига              Уфа   273.0000
# 24          Первая лига  Санкт-Петербург   253.2500
# 25        Базовый грант        Волгоград   235.6250
# 26        Базовый грант   Ростов-на-Дону   235.5000
# 27          Вторая лига           Москва   235.3750
# 28        Базовый грант           Москва   229.5000
# 29        Базовый грант           Казань   227.1250
# 30        Базовый грант          Саратов   223.8750
# 31        Базовый грант          Саранск   214.7500
# 32          Первая лига           Москва   212.6250
# 33          Третья лига           Москва   212.2500
# 34        Базовый грант           Самара   209.1250
# 35        Базовый грант            Пермь   207.6250
# 36        Базовый грант           Москва   205.3750
# 37        Базовый грант           Москва   204.2500
# 38          Первая лига        Краснодар   198.2500
# 39        Базовый грант       Ставрополь   184.2500
# 40          Третья лига              Уфа   177.6250
# 41          Не участник           Рязань   177.2500
# 42          Вторая лига         Белгород   169.2500
# 43          Первая лига           Тюмень   166.7500
# 44          Не участник     Магнитогорск   163.5000
# 45          Вторая лига      Новосибирск   157.8750
# 46          Не участник  Санкт-Петербург   156.3750
# 47          Вторая лига  Санкт-Петербург   156.1250
# 48          Не участник           Тюмень   155.8750
# 49          Не участник           Самара   155.2500
# 50        Базовый грант           Москва   154.5000
# 51          Не участник           Москва   154.1250
# 52  Кандидат на участие           Москва   154.0000
# 53          Первая лига     Долгопрудный   150.1250
# 54          Не участник          Воронеж   149.8750
# 55          Вторая лига      Владивосток   149.1250
# 56        Базовый грант           Москва   147.3750
# 57          Третья лига          Иркутск   144.6250
# 58          Не участник  Санкт-Петербург   143.1250
# 59        Базовый грант         Белгород   141.5000
# 60          Вторая лига           Москва   141.2500
# 61          Первая лига           Москва   135.3750
# 62          Не участник          Воронеж   134.5000
# 63        Базовый грант           Москва   127.5625
# 64        Базовый грант         Кемерово   126.3125
# 65          Вторая лига      Симферополь   123.2500
# 66        Базовый грант  Санкт-Петербург   120.3750
# 67        Базовый грант            Пермь   119.3750
# 68          Не участник          Саратов   117.4375
# 69        Базовый грант            Курск   114.9375
# 70          Третья лига             Омск   108.5000
# 71          Третья лига  Нижний Новгород   106.5000
# 72        Базовый грант          Саратов   106.5000
# 73          Не участник           Москва   104.8750
# 74        Базовый грант           Казань   103.5000
# 75          Третья лига  Санкт-Петербург    98.4375
# 76          Третья лига            Томск    96.7500
# 77        Базовый грант          Барнаул    96.1875
# 78          Не участник        Краснодар    94.2500
# 79        Базовый грант  Санкт-Петербург    93.6875
# 80        Базовый грант  Санкт-Петербург    88.0625
# 81          Не участник        Краснодар    87.3125

# %% [markdown]
# **Вывод:** Интересно что в зону "выбросов" попадают исключительно ВУЗы с верхней границы. Выбросов в нижней части рейтинга не имеется.

# %%
print(f'Общее количество "нетипичных ВУЗов": {len(df_abnormal)}')
print('_________________________________________________________')
print('В разбивке по городам:')
df_abnormal.groupby(['City'])['Points'].agg('count').sort_values(ascending=False)

#df_group_abnorm.info()
#print(df_group_abnorm)
# Out:
# Общее количество "нетипичных ВУЗов": 82
# _________________________________________________________
# В разбивке по городам:
# City
# Москва             26
# Санкт-Петербург    10
# Краснодар           3
# Казань              3
# Томск               3
# Саратов             3
# Ростов-на-Дону      2
# Уфа                 2
# Воронеж             2
# Пермь               2
# Нижний Новгород     2
# Самара              2
# Белгород            2
# Ставрополь          2
# Тюмень              2
# Кемерово            1
# Владивосток         1
# Долгопрудный        1
# Екатеринбург        1
# Иркутск             1
# Волгоград           1
# Челябинск           1
# Красноярск          1
# Курск               1
# Магнитогорск        1
# Новосибирск         1
# Омск                1
# Рязань              1
# Саранск             1
# Симферополь         1
# Барнаул             1
# Name: Points, dtype: int64

# %%
# очень хорошо подходит для поиска выбросов!
df['Points'].plot(kind='box',
                   title='Распределение всех рейтингов ВУЗов', grid=True)

# %% [markdown]
# Проанализируем рейтинги ВУЗов по категориям программы **"Приоритет 2030"**:

# %%
#Проанализируем рейтинги по группам программы Приоритет 2030
display(df.groupby(['Status'])['Points'].agg(['count', 'median','min','max']))
all_in_prog = len(df.loc[df['Status'].isin([ '«Над программой»', 
                                             'Базовый грант',
                                             'Первая лига', 
                                             'Вторая лига', 
                                             'Третья лига'])])
all_in_rating = len(df)

print(f'Всего в программу "Приоритет-2030" входит  {all_in_prog} вуза(ов)')
print(f'из общего числа в {all_in_rating} вузов указанных в рейтинге')
print(f'что составляет {(all_in_prog/all_in_rating)*100:.1f} %')
# Out:
#                      count       median         min      max
# Status
# «Над программой»         2  1604.000000  876.500000  2332.00
# Базовый грант           57    83.187500    0.439941   508.75
# Вторая лига             16   145.250000   14.093750   564.50
# Кандидат на участие     15    33.656250   10.070312   154.00
# Не участник            494     9.328125    0.029999   401.25
# Первая лига             18   383.500000   66.687500   792.00
# Третья лига             12   195.000000   96.750000   440.75
# Всего в программу "Приоритет-2030" входит  105 вуза(ов)
# из общего числа в 614 вузов указанных в рейтинге
# что составляет 17.1 %

# %% [markdown]
# что достаточно точно соответствует действительности:

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %%
groups_by_status = df[['Name', 'Status']].groupby('Status').count()

groups_by_status
# Out:
#                      Name
# Status
# «Над программой»        2
# Базовый грант          57
# Вторая лига            16
# Кандидат на участие    15
# Не участник           494
# Первая лига            18
# Третья лига            12

# %%
 groups_by_status.loc[['«Над программой»', 
                      'Базовый грант', 
                      'Первая лига', 
                      'Вторая лига', 
                      'Третья лига', 
                       ]].plot.bar(color="green", 
                                   title='Распределение вузов в рейтинге по типам грантов программы "Приоритет-2030"'
                                  )

# %% [markdown]
# Бокс-плоты статистических характеристик групп вузов по признаку вовлечения в  программу **"Приоритет 2030"**

# %%
df.boxplot(column=['Points'], by='Status',grid=True, color='black')

# %% [markdown]
# Визуализация наглядно демонстрирует серьёзных разрыв в статистических показателях между элитной группой "Над программой" состоящей из Московского и Санкт-Петербургского университетов и остальными учебными заведениями высшей школы России.

# %%
Попробуем исключить элитную группу из рассмотрения:

# %%
df.loc[df['Status']!='«Над программой»'].boxplot(column=['Points'], by='Status',grid=True, color='black')

# %% [markdown]
# Интересно посмотреть выбросы из групп кандитат на участие и не участник. Они могли бы войти в число грантополучателей.
# Кто такие первая, вторая и третья лиги???

# %% [markdown]
# Группировка вузов по расположению:

# %%
df_city_group = df.groupby(['City'])['Points'].agg(['count',
                                                    'median',
                                                    'min',
                                                    'max']).sort_values(by='count',  ascending=False)
df_city_group
# Out:
#                           count      median         min          max
# City
# Москва                      101   18.359375    0.099976  2332.000000
# Санкт-Петербург              60   16.781250    0.409912   876.500000
# Екатеринбург                 16   16.390625    0.839844   490.750000
# Казань                       16   11.453125    0.130005   550.000000
# Воронеж                      16   10.132812    0.029999   149.875000
# Новосибирск                  16   13.625000    1.209961   157.875000
# Самара                       13   14.757812    2.759766   209.125000
# Омск                         12   19.406250    0.320068   108.500000
# Нижний Новгород              10   18.593750    3.160156   373.000000
# Краснодар                     9   28.156250    0.459961   198.250000
# Пермь                         9   12.210938    1.290039   207.625000
# Волгоград                     9   22.593750    0.070007   235.625000
# Уфа                           9   22.140625    1.799805   273.000000
# Ростов-на-Дону                9   31.218750    0.250000   440.750000
# Хабаровск                     8    5.519531    0.119995    20.062500
# Челябинск                     8   22.968750    0.479980   287.250000
# Саратов                       8   38.125000    0.090027   223.875000
# Курск                         7   16.468750    0.320068   114.937500
# Красноярск                    7   26.687500    0.689941   300.250000
# Иваново                       7   14.242188    4.429688    26.375000
# Ярославль                     7    6.640625    1.490234    45.531250
# Барнаул                       7   14.570312    3.150391    96.187500
# Тюмень                        6   15.781250    0.759766   166.750000
# Томск                         6   72.125000   22.906250   417.750000
# Смоленск                      6    3.734375    0.389893    23.046875
# Рязань                        6   23.406250    1.120117   177.250000
# Белгород                      6   31.859375    3.539062   169.250000
# Орел                          6    6.132812    1.709961    80.187500
# Иркутск                       6   25.468750    5.269531   144.625000
# Братск                        1   17.421875   17.421875    17.421875
# Биробиджан                    1    3.750000    3.750000     3.750000
# Бийск                         1    4.429688    4.429688     4.429688
# Балашиха                      1   13.078125   13.078125    13.078125
# Череповец                     1   14.851562   14.851562    14.851562
# Черкесск                      1   19.656250   19.656250    19.656250
# Чурапча                       1    0.150024    0.150024     0.150024
# Шадринск                      1    4.281250    4.281250     4.281250
# Электроизолятор               1    1.790039    1.790039     1.790039
# Элиста                        1   32.031250   32.031250    32.031250
# Южно-Сахалинск                1    2.470703    2.470703     2.470703
# Ангарск                       1    5.109375    5.109375     5.109375
# Железногорск                  1    1.030273    1.030273     1.030273
# Калуга                        1    4.328125    4.328125     4.328125
# Сколково                      1    3.039062    3.039062     3.039062
# Курган                        1   10.312500   10.312500    10.312500
# Малаховка                     1   12.156250   12.156250    12.156250
# Альметьевск                   1    9.546875    9.546875     9.546875
# Мытищи                        1   40.687500   40.687500    40.687500
# Набережные Челны              1    1.849609    1.849609     1.849609
# Нижневартовск                 1    7.761719    7.761719     7.761719
# Магас                         1    3.640625    3.640625     3.640625
# Магадан                       1    1.000000    1.000000     1.000000
# Новороссийск                  1    8.203125    8.203125     8.203125
# Люберцы                       1   43.187500   43.187500    43.187500
# Новочеркасск                  1   73.437500   73.437500    73.437500
# Норильск                      1    0.099976    0.099976     0.099976
# Лесниково                     1   10.656250   10.656250    10.656250
# Кызыл                         1    4.750000    4.750000     4.750000
# Орехово-Зуево                 1    9.281250    9.281250     9.281250
# Красково                      1    0.130005    0.130005     0.130005
# Молодежный                    1    8.273438    8.273438     8.273438
# Персиановский                 1   62.687500   62.687500    62.687500
# Королев                       1   17.296875   17.296875    17.296875
# Псков                         1   16.453125   16.453125    16.453125
# Пущино                        1    0.750000    0.750000     0.750000
# Пятигорск                     1   25.515625   25.515625    25.515625
# Коломна                       1   15.937500   15.937500    15.937500
# Рыбинск                       1    3.779297    3.779297     3.779297
# Ковров                        1    1.509766    1.509766     1.509766
# Княгинино                     1   11.359375   11.359375    11.359375
# Керчь                         1    2.250000    2.250000     2.250000
# Саранск                       1  214.750000  214.750000   214.750000
# Карачаевск                    1    0.850098    0.850098     0.850098
# Севастополь                   1   16.546875   16.546875    16.546875
# Сергиев Посад                 1    0.379883    0.379883     0.379883
# Абакан                        1    6.660156    6.660156     6.660156

# %% [markdown]
# Города с количеством вузов в рейтинге более 10:

# %%
df_city_group_10 =df_city_group.loc[df_city_group['count'] >= 10]
df_city_group_10
# Out:
#                  count     median       min       max
# City
# Москва             101  18.359375  0.099976  2332.000
# Санкт-Петербург     60  16.781250  0.409912   876.500
# Екатеринбург        16  16.390625  0.839844   490.750
# Казань              16  11.453125  0.130005   550.000
# Воронеж             16  10.132812  0.029999   149.875
# Новосибирск         16  13.625000  1.209961   157.875
# Самара              13  14.757812  2.759766   209.125
# Омск                12  19.406250  0.320068   108.500
# Нижний Новгород     10  18.593750  3.160156   373.000

# %%
df.groupby(['City'])['Points'].plot(kind='box',
                   title='Распределение cтатистики по городам', grid=True)

# очень хорошо подходит для поиска выбросов!
#df['User_Score'].plot(kind='box',
#                   title='Распределение оценок пользователей', grid=True)
# Out:
# City
# Абакан                      AxesSubplot(0.125,0.125;0.775x0.755)
# Альметьевск                 AxesSubplot(0.125,0.125;0.775x0.755)
# Ангарск                     AxesSubplot(0.125,0.125;0.775x0.755)
# Армавир                     AxesSubplot(0.125,0.125;0.775x0.755)
# Архангельск                 AxesSubplot(0.125,0.125;0.775x0.755)
# Астрахань                   AxesSubplot(0.125,0.125;0.775x0.755)
# Балашиха                    AxesSubplot(0.125,0.125;0.775x0.755)
# Барнаул                     AxesSubplot(0.125,0.125;0.775x0.755)
# Белгород                    AxesSubplot(0.125,0.125;0.775x0.755)
# Бийск                       AxesSubplot(0.125,0.125;0.775x0.755)
# Биробиджан                  AxesSubplot(0.125,0.125;0.775x0.755)
# Благовещенск                AxesSubplot(0.125,0.125;0.775x0.755)
# Братск                      AxesSubplot(0.125,0.125;0.775x0.755)
# Брянск                      AxesSubplot(0.125,0.125;0.775x0.755)
# Великие Луки                AxesSubplot(0.125,0.125;0.775x0.755)
# Великий Новгород            AxesSubplot(0.125,0.125;0.775x0.755)
# Видное                      AxesSubplot(0.125,0.125;0.775x0.755)
# Владивосток                 AxesSubplot(0.125,0.125;0.775x0.755)
# Владикавказ                 AxesSubplot(0.125,0.125;0.775x0.755)
# Владимир                    AxesSubplot(0.125,0.125;0.775x0.755)
# Волгоград                   AxesSubplot(0.125,0.125;0.775x0.755)
# Волжский                    AxesSubplot(0.125,0.125;0.775x0.755)
# Вологда                     AxesSubplot(0.125,0.125;0.775x0.755)
# Воронеж                     AxesSubplot(0.125,0.125;0.775x0.755)
# Гатчина                     AxesSubplot(0.125,0.125;0.775x0.755)
# Глазов                      AxesSubplot(0.125,0.125;0.775x0.755)
# Горно-Алтайск               AxesSubplot(0.125,0.125;0.775x0.755)
# Грозный                     AxesSubplot(0.125,0.125;0.775x0.755)
# Долгопрудный                AxesSubplot(0.125,0.125;0.775x0.755)
# Дубна                       AxesSubplot(0.125,0.125;0.775x0.755)
# Екатеринбург                AxesSubplot(0.125,0.125;0.775x0.755)
# Елец                        AxesSubplot(0.125,0.125;0.775x0.755)
# Ессентуки                   AxesSubplot(0.125,0.125;0.775x0.755)
# Железногорск                AxesSubplot(0.125,0.125;0.775x0.755)
# Иваново                     AxesSubplot(0.125,0.125;0.775x0.755)
# Ижевск                      AxesSubplot(0.125,0.125;0.775x0.755)
# Иркутск                     AxesSubplot(0.125,0.125;0.775x0.755)
# Йошкар-Ола                  AxesSubplot(0.125,0.125;0.775x0.755)
# Казань                      AxesSubplot(0.125,0.125;0.775x0.755)
# Калининград                 AxesSubplot(0.125,0.125;0.775x0.755)
# Калуга                      AxesSubplot(0.125,0.125;0.775x0.755)
# Карачаевск                  AxesSubplot(0.125,0.125;0.775x0.755)
# Кемерово                    AxesSubplot(0.125,0.125;0.775x0.755)
# Керчь                       AxesSubplot(0.125,0.125;0.775x0.755)
# Киров                       AxesSubplot(0.125,0.125;0.775x0.755)
# Княгинино                   AxesSubplot(0.125,0.125;0.775x0.755)
# Ковров                      AxesSubplot(0.125,0.125;0.775x0.755)
# Коломна                     AxesSubplot(0.125,0.125;0.775x0.755)
# Комсомольск-на-Амуре        AxesSubplot(0.125,0.125;0.775x0.755)
# Королев                     AxesSubplot(0.125,0.125;0.775x0.755)
# Кострома                    AxesSubplot(0.125,0.125;0.775x0.755)
# Красково                    AxesSubplot(0.125,0.125;0.775x0.755)
# Краснодар                   AxesSubplot(0.125,0.125;0.775x0.755)
# Красноярск                  AxesSubplot(0.125,0.125;0.775x0.755)
# Курган                      AxesSubplot(0.125,0.125;0.775x0.755)
# Курск                       AxesSubplot(0.125,0.125;0.775x0.755)
# Кызыл                       AxesSubplot(0.125,0.125;0.775x0.755)
# Лесниково                   AxesSubplot(0.125,0.125;0.775x0.755)
# Липецк                      AxesSubplot(0.125,0.125;0.775x0.755)
# Люберцы                     AxesSubplot(0.125,0.125;0.775x0.755)
# Магадан                     AxesSubplot(0.125,0.125;0.775x0.755)
# Магас                       AxesSubplot(0.125,0.125;0.775x0.755)
# Магнитогорск                AxesSubplot(0.125,0.125;0.775x0.755)
# Майкоп                      AxesSubplot(0.125,0.125;0.775x0.755)
# Малаховка                   AxesSubplot(0.125,0.125;0.775x0.755)
# Махачкала                   AxesSubplot(0.125,0.125;0.775x0.755)
# Мичуринск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Молодежный                  AxesSubplot(0.125,0.125;0.775x0.755)
# Москва                      AxesSubplot(0.125,0.125;0.775x0.755)
# Мурманск                    AxesSubplot(0.125,0.125;0.775x0.755)
# Мытищи                      AxesSubplot(0.125,0.125;0.775x0.755)
# Набережные Челны            AxesSubplot(0.125,0.125;0.775x0.755)
# Нальчик                     AxesSubplot(0.125,0.125;0.775x0.755)
# Невинномысск                AxesSubplot(0.125,0.125;0.775x0.755)
# Нижневартовск               AxesSubplot(0.125,0.125;0.775x0.755)
# Нижний Новгород             AxesSubplot(0.125,0.125;0.775x0.755)
# Новокузнецк                 AxesSubplot(0.125,0.125;0.775x0.755)
# Новороссийск                AxesSubplot(0.125,0.125;0.775x0.755)
# Новосибирск                 AxesSubplot(0.125,0.125;0.775x0.755)
# Новочеркасск                AxesSubplot(0.125,0.125;0.775x0.755)
# Норильск                    AxesSubplot(0.125,0.125;0.775x0.755)
# Омск                        AxesSubplot(0.125,0.125;0.775x0.755)
# Орел                        AxesSubplot(0.125,0.125;0.775x0.755)
# Оренбург                    AxesSubplot(0.125,0.125;0.775x0.755)
# Орехово-Зуево               AxesSubplot(0.125,0.125;0.775x0.755)
# Пенза                       AxesSubplot(0.125,0.125;0.775x0.755)
# Пермь                       AxesSubplot(0.125,0.125;0.775x0.755)
# Персиановский               AxesSubplot(0.125,0.125;0.775x0.755)
# Петрозаводск                AxesSubplot(0.125,0.125;0.775x0.755)
# Петропавловск-Камчатский    AxesSubplot(0.125,0.125;0.775x0.755)
# Псков                       AxesSubplot(0.125,0.125;0.775x0.755)
# Пущино                      AxesSubplot(0.125,0.125;0.775x0.755)
# Пятигорск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Ростов-на-Дону              AxesSubplot(0.125,0.125;0.775x0.755)
# Рыбинск                     AxesSubplot(0.125,0.125;0.775x0.755)
# Рязань                      AxesSubplot(0.125,0.125;0.775x0.755)
# Самара                      AxesSubplot(0.125,0.125;0.775x0.755)
# Санкт-Петербург             AxesSubplot(0.125,0.125;0.775x0.755)
# Саранск                     AxesSubplot(0.125,0.125;0.775x0.755)
# Саратов                     AxesSubplot(0.125,0.125;0.775x0.755)
# Севастополь                 AxesSubplot(0.125,0.125;0.775x0.755)
# Сергиев Посад               AxesSubplot(0.125,0.125;0.775x0.755)
# Симферополь                 AxesSubplot(0.125,0.125;0.775x0.755)
# Сколково                    AxesSubplot(0.125,0.125;0.775x0.755)
# Смоленск                    AxesSubplot(0.125,0.125;0.775x0.755)
# Сочи                        AxesSubplot(0.125,0.125;0.775x0.755)
# Ставрополь                  AxesSubplot(0.125,0.125;0.775x0.755)
# Сургут                      AxesSubplot(0.125,0.125;0.775x0.755)
# Сходня                      AxesSubplot(0.125,0.125;0.775x0.755)
# Сыктывкар                   AxesSubplot(0.125,0.125;0.775x0.755)
# Таганрог                    AxesSubplot(0.125,0.125;0.775x0.755)
# Тамбов                      AxesSubplot(0.125,0.125;0.775x0.755)
# Тверь                       AxesSubplot(0.125,0.125;0.775x0.755)
# Тольятти                    AxesSubplot(0.125,0.125;0.775x0.755)
# Томск                       AxesSubplot(0.125,0.125;0.775x0.755)
# Троицк                      AxesSubplot(0.125,0.125;0.775x0.755)
# Тула                        AxesSubplot(0.125,0.125;0.775x0.755)
# Тюмень                      AxesSubplot(0.125,0.125;0.775x0.755)
# Улан-Удэ                    AxesSubplot(0.125,0.125;0.775x0.755)
# Ульяновск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Уссурийск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Уфа                         AxesSubplot(0.125,0.125;0.775x0.755)
# Ухта                        AxesSubplot(0.125,0.125;0.775x0.755)
# Хабаровск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Ханты-Мансийск              AxesSubplot(0.125,0.125;0.775x0.755)
# Химки                       AxesSubplot(0.125,0.125;0.775x0.755)
# Чебоксары                   AxesSubplot(0.125,0.125;0.775x0.755)
# Челябинск                   AxesSubplot(0.125,0.125;0.775x0.755)
# Череповец                   AxesSubplot(0.125,0.125;0.775x0.755)
# Черкесск                    AxesSubplot(0.125,0.125;0.775x0.755)
# Чита                        AxesSubplot(0.125,0.125;0.775x0.755)
# Чурапча                     AxesSubplot(0.125,0.125;0.775x0.755)
# Шадринск                    AxesSubplot(0.125,0.125;0.775x0.755)
# Электроизолятор             AxesSubplot(0.125,0.125;0.775x0.755)
# Элиста                      AxesSubplot(0.125,0.125;0.775x0.755)
# Южно-Сахалинск              AxesSubplot(0.125,0.125;0.775x0.755)
# Якутск                      AxesSubplot(0.125,0.125;0.775x0.755)
# Ярославль                   AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Points, dtype: object

# %%
Медианные значения рейтинга для вузов первых пяти городов

# %% [markdown]
# Боксплоты для групп вузов по категориям участия в программе "Приоритет-2030"

# %% [markdown]
# # <center> Matplotlib

# %%
groups_by_status.loc[['«Над программой»', 
                      'Базовый грант', 
                      'Первая лига', 
                      'Вторая лига', 
                      'Третья лига', 
                       ]].plot(kind='bar', title='Распределение вузов в рейтинге по типам грантов программы "Приоритет-2030"'
                                )

# %% [markdown]
# Matplotlib – одна из самых популярных библиотек Python для визуализации данных.
#
# Импорт: import matplotlib.pyplot as plt
#
# Документация: https://matplotlib.org/contents.html

# %%
# первый позиционный аргумент – точки по X, второй – точки по y. По умолчанию это единичные отрезки
plt.plot(5, 5, 'x')
# plt.show()

# %%
plt.plot([25, 20, 15, 12, 9, 4, 2], [1, 2, 3, 4, 5, 6, 7], color='red', marker='o')
# plt.show()
plt.plot([25, 20, 15, 12, 9, 4, 2], color='green')
# plt.show()

# %% [markdown]
# Поработаем с данными о продажах и оценках видеоигр с [Kaggle Datasets](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/stat_case_study/vgsales.csv')

# %%
print(df.shape)
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df.info()
# что видим?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
# почему в User_Score object?
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
df['User_Score'] = df['User_Score'].replace('tbd', np.NaN)
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
# исправим типы данных
df['Year_of_Release'] = df['Year_of_Release'].astype('Int64')
df['User_Count'] = df['User_Count'].astype('Int64')
df['User_Score'] = df['User_Score'].astype('float64')
df['Critic_Count'] = df['Critic_Count'].astype('Int64')

# # переводим оценки в один формат
df['User_Score'] = df['User_Score'] * 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  Int64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   Int64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   Int64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: Int64(3), float64(7), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# ## График
# Построим график динамики продаж видеоигр

# %%
dynamics_by_region = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Year_of_Release']] \
    .groupby('Year_of_Release').sum()
dynamics_by_region
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year_of_Release
# 1980                10.59      0.67      0.00         0.12         11.38
# 1981                33.40      1.96      0.00         0.32         35.77
# 1982                26.92      1.65      0.00         0.31         28.86
# 1983                 7.76      0.80      8.10         0.14         16.79
# 1984                33.28      2.10     14.27         0.70         50.36
# 1985                33.73      4.74     14.56         0.92         53.94
# 1986                12.50      2.84     19.81         1.93         37.07
# 1987                 8.46      1.41     11.63         0.20         21.74
# 1988                23.87      6.59     15.76         0.99         47.22
# 1989                45.15      8.44     18.36         1.50         73.45
# 1990                25.46      7.63     14.88         1.40         49.39
# 1991                12.76      3.95     14.78         0.74         32.23
# 1992                33.89     11.71     28.91         1.65         76.17
# 1993                16.90      5.18     25.36         0.97         48.40
# 1994                28.16     14.88     33.99         2.20         79.18
# 1995                24.83     14.90     45.75         2.64         88.11
# 1996                86.76     47.26     57.44         7.69        199.15
# 1997                94.75     48.32     48.87         9.13        200.98
# 1998               128.36     66.90     50.04        11.01        256.45
# 1999               126.06     62.67     52.34        10.04        251.25
# 2000                94.50     52.77     42.77        11.62        201.58
# 2001               173.98     94.89     39.86        22.73        331.47
# 2002               216.19    109.75     41.76        27.27        395.51
# 2003               193.61    103.81     34.20        25.92        357.80
# 2004               222.51    107.28     41.65        47.24        419.05
# 2005               242.15    121.11     54.27        40.29        458.31
# 2006               262.13    127.89     73.74        53.95        518.22
# 2007               309.89    157.82     60.29        76.75        605.37
# 2008               348.69    181.14     60.25        81.42        671.79
# 2009               335.55    187.94     61.89        73.44        658.88
# 2010               300.65    171.42     59.49        58.57        590.59
# 2011               238.79    162.97     53.07        52.75        507.79
# 2012               153.26    114.59     51.80        36.19        355.84
# 2013               153.65    121.55     47.69        38.35        361.24
# 2014               132.27    122.74     39.69        36.83        331.51
# 2015               106.86     96.72     34.09        30.31        268.05
# 2016                44.93     51.22     19.31        14.48        130.10
# 2017                 0.00      0.00      0.06         0.00          0.06
# 2020                 0.27      0.00      0.00         0.02          0.29

# %%
# применяем функцию plot из matplotlib
# для каждой дополнительной настройки есть своя функция
plt.plot(dynamics_by_region.index, dynamics_by_region['Global_Sales'])
plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.')
plt.savefig('11.jpeg')

# %%
# можем использовать цикл, чтобы построить графики для каждого региона
for region in dynamics_by_region.columns:
    plt.plot(dynamics_by_region.index, dynamics_by_region[region])
plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.') 
plt.legend(dynamics_by_region)

# %% [markdown]
# Метод .plot() в pandas основан на matplotlib. Если мы работаем с датафреймами, то это, как правило, более удобный вариант, чем использование matplotlib самой по себе. Мы сконцентрируемся на этом варианте.
#
# Документация: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
# если работает с табличными структурами, то можем воспользоваться функционалом, 
# встроенным в pandas. Так удобнее
# Метод plot по-умолчанию использует индекс датафрейма для оси X
# метод plot по-умолчанию строит график
dynamics_by_region['Global_Sales'].plot(title='Динамика продаж видеоигр',
                                        xlabel='Год', 
                                        ylabel='Продажи, млн.')

# %%
# plot без цикла построит графики для каждого региона (столбца)
# если у plot нету нужных методов, то можно применить функции matplotlib
dynamics_by_region.plot(title='Динамика продаж видеоигр', 
                             xlabel='Год', 
                             ylabel='Продажи, млн.')
plt.text(2007, 680, 'Почему отсюда начался спад?')  

plt.legend(loc='upper left')

# %% [markdown]
# ## Area chart

# %%
# по-умолчанию  Area chart всегда накопительный
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='area',
                             title='Динамика продаж видеоигр', 
                             xlabel='Год', 
                                # stacked=False,
                             ylabel='Продажи, млн.')

# %% [markdown]
# # Гистограммы

# %%
# распределение оценок пользователей
df['User_Score'].plot(kind='hist', 
                   title='Распределение оценок пользователей', bins=20)

# %%
# распределение оценок критиков
df['Critic_Score'].plot(kind='hist', 
                     title='Распределение оценок критиков', bins=20)

# %%
# сравнение
df['Critic_Score'].plot(kind='hist', 
                     alpha = 0.5,
                     bins=20,
                     density = True)


df['User_Score'].plot(kind='hist', 
                     alpha = 0.5,
                     bins=20,
                     density = True)
plt.legend(loc='upper left')
plt.title('Сравнение распределений оценок видеоигр')
# Out:
# Text(0.5, 1.0, 'Сравнение распределений оценок видеоигр')

# %% [markdown]
# ## Столбчатая диаграмма

# %%
# количество игр в разрезе платформ
games_by_platforms = df[['Name', 'Platform']].groupby('Platform').count()
games_by_platforms
# Out:
#           Name
# Platform
# 2600       133
# 3DO          3
# 3DS        520
# DC          52
# DS        2152
# GB          98
# GBA        822
# GC         556
# GEN         27
# GG           1
# N64        319
# NES         98
# NG          12
# PC         974
# PCFX         1
# PS        1197
# PS2       2161
# PS3       1331
# PS4        393
# PSP       1209
# PSV        432
# SAT        173
# SCD          6
# SNES       239
# TG16         2
# WS           6
# Wii       1320
# WiiU       147
# X360      1262
# XB         824
# XOne       247

# %%
# топ-5 жанров по продажам
top5_genres = df[['Global_Sales', 'Genre']].groupby('Genre').sum().sort_values('Global_Sales', ascending=False).head(5)
top5_genres.plot(kind='bar', title='Топ 5 жанров по продажам',
                             xlabel='Платформа',
                             ylabel='Количество игр')
for i, val in enumerate(top5_genres.values):
    plt.text(i, val, int(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'size':14})

# %%
# динамика продаж в разрезе регионов. Выглядит фигово
dynamics_by_region.plot(kind='bar')

# %%
# Сделаем с накоплением!
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Круговая диаграмма

# %%
# количество игр по платформам
pie_data = df['Platform'].value_counts()
# pie_data
pie_data.plot(kind='pie', title='Количество игр по платформам')

# %%
# количество игр по платформам (берем только топ-5)
top_platforms = df['Platform'].value_counts().head(5)
top_platforms.plot(kind='pie')
plt.legend(bbox_to_anchor=(0.6, .5, 0.5, 0.5))

# %% [markdown]
# ## Boxplot

# %%
# очень хорошо подходит для поиска выбросов!
df['User_Score'].plot(kind='box',
                   title='Распределение оценок пользователей', grid=True)

# %%
df[['User_Score', 'Critic_Score']].plot(kind='box',
                                        title='Распределение оценок', grid=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## Точечная диаграмма

# %%
# посмотрим на взаимосвязь оценок и продаж
df.plot(kind='scatter', 
        x='User_Score', 
        y='Global_Sales', 
        title='Зависимость между продажами и оценками пользователей')
plt.ylim(0, 40)
df.plot(kind='scatter', 
        x='Critic_Score', 
        y='Global_Sales', 
        title='Зависимость между продажами и оценками критиков')
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %%
# добавим третью ось
df.plot(kind='scatter', 
        x='User_Score', 
        y='Critic_Score', 
        s=df['Global_Sales']*20,
        title='Зависимость между оценкой критиков, пользоваталей и продажами'
       )

# %% [markdown]
# ## Стилизация таблиц

# %%
# выведем информацию о топ-10 издателях по продажам
top_developers_df = df.groupby('Developer')[['Global_Sales']].sum()\
    .sort_values('Global_Sales', ascending=False).head(10)
    
top_developers_df
# Out:
#                    Global_Sales
# Developer
# Nintendo                 531.71
# EA Sports                175.38
# EA Canada                142.32
# Ubisoft                  132.54
# Rockstar North           119.47
# Capcom                   115.71
# Ubisoft Montreal         108.31
# Treyarch                 103.16
# EA Tiburon                96.12
# Traveller's Tales         79.22

# %%
top_developers_df.style.bar(align='mid')
# Out:
# <style type="text/css">
# #T_0efc6_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_0efc6_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.0%, transparent 33.0%);
# }
# #T_0efc6_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.8%, transparent 26.8%);
# }
# #T_0efc6_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 24.9%, transparent 24.9%);
# }
# #T_0efc6_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.5%, transparent 22.5%);
# }
# #T_0efc6_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.8%, transparent 21.8%);
# }
# #T_0efc6_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
# }
# #T_0efc6_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
# }
# #T_0efc6_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.1%, transparent 18.1%);
# }
# #T_0efc6_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
# }
# </style>
# <table id="T_0efc6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Global_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Developer</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0efc6_level0_row0" class="row_heading level0 row0" >Nintendo</th>
#       <td id="T_0efc6_row0_col0" class="data row0 col0" >531.710000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row1" class="row_heading level0 row1" >EA Sports</th>
#       <td id="T_0efc6_row1_col0" class="data row1 col0" >175.380000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row2" class="row_heading level0 row2" >EA Canada</th>
#       <td id="T_0efc6_row2_col0" class="data row2 col0" >142.320000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row3" class="row_heading level0 row3" >Ubisoft</th>
#       <td id="T_0efc6_row3_col0" class="data row3 col0" >132.540000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row4" class="row_heading level0 row4" >Rockstar North</th>
#       <td id="T_0efc6_row4_col0" class="data row4 col0" >119.470000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row5" class="row_heading level0 row5" >Capcom</th>
#       <td id="T_0efc6_row5_col0" class="data row5 col0" >115.710000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row6" class="row_heading level0 row6" >Ubisoft Montreal</th>
#       <td id="T_0efc6_row6_col0" class="data row6 col0" >108.310000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row7" class="row_heading level0 row7" >Treyarch</th>
#       <td id="T_0efc6_row7_col0" class="data row7 col0" >103.160000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row8" class="row_heading level0 row8" >EA Tiburon</th>
#       <td id="T_0efc6_row8_col0" class="data row8 col0" >96.120000</td>
#     </tr>
#     <tr>
#       <th id="T_0efc6_level0_row9" class="row_heading level0 row9" >Traveller's Tales</th>
#       <td id="T_0efc6_row9_col0" class="data row9 col0" >79.220000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <center> Seaborn

# %%
import seaborn as sns

# %%
# посмотрим зависимость продаж и оценок критиков
sns.regplot(data=df, x='Critic_Score', y='Global_Sales', color='green', marker='+')
plt.title('Корреляция между продажами и оценками критиков')
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %% [markdown]
# C помощью `seaborn` можно построить достаточно сложные визуализации, которые были бы очень сложны для представления в коде при использовании `matplotlib`. Рассмотрим часть из них.

# %% [markdown]
# Посмотрим на **распределение оценок критиков `Critic_Score`**. Для этого построим __`histplot`__.

# %%
sns.histplot(df['Critic_Score'])
plt.title('Распределение оценок критиков')
# Out:
# Text(0.5, 1.0, 'Распределение оценок критиков')

# %% [markdown]
# Для того чтобы подробнее посмотреть на взаимосвязь двух численных признаков можно использовать __`joint_plot`__ – это гибрид `scatter plot` и `histogram`. Посмотрим на то, как связаны между собой **оценка критиков `Critic_Score` и оценка пользователя `User_Score`**.

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg')

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg', marginal_kws=dict(bins=10, fill=False))

# %% [markdown]
# **pair plot (scatter plot matrix)** поможет нам посмотреть на одной картинке, как связаны между собой различные признаки в наборе данных

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'User_Score']])

# %% [markdown]
# Давайте **сравним оценки критиков игр для топ-10 крупнейших игровых платформ** при помощи `boxplot`.

# %%
top_platforms = df['Platform'].value_counts().sort_values(ascending=False).head(10).index.values
# top_platforms
sns.boxplot(x="Platform", y="Critic_Score", 
            data=df[df['Platform'].isin(top_platforms)])

# %% [markdown]
# `Heat map` позволяет посмотреть на распределение какого-то численного признака по двум категориальным. Визуализируем **суммарные продажи игр по жанрам и игровым платформам**.

# %%
platform_genre_sales = df[df['Platform'].isin(top_platforms)].pivot_table(
                        index='Platform', 
                        columns='Genre', 
                        values='Global_Sales', 
                        aggfunc=sum).fillna(0)

platform_genre_sales
# Out:
# Genre     Action  Adventure  Fighting    Misc  Platform  Puzzle  Racing  \
# Platform
# DS        112.70      45.90      7.11  135.72     75.92   82.72   38.10
# GBA        55.76      14.68      4.21   36.25     78.30   12.92   18.80
# PC         31.71      10.04      0.29    8.57      0.49    0.92    3.99
# PS        127.05      20.97     72.68   44.90     64.21   12.08  103.19
# PS2       272.76      21.16     92.60  101.14     72.51    5.90  156.28
# PS3       301.55      22.28     51.08   46.88     29.71    0.58   72.13
# PSP        64.11      10.68     21.82   13.91     17.09    5.52   34.29
# Wii       114.51      17.83     23.36  216.37     88.92   15.37   60.25
# X360      239.69      14.94     37.34   91.54     11.32    0.85   65.00
# XB         49.28       3.06     13.55    9.58      9.66    0.42   31.49
#
# Genre     Role-Playing  Shooter  Simulation  Sports  Strategy
# Platform
# DS              124.44     7.92      130.29   31.41     14.87
# GBA              64.21     3.60        5.91   16.41      7.45
# PC               47.72    45.92       52.61   12.01     46.03
# PS               78.30    39.31       25.33  120.97     21.69
# PS2              93.50   108.57       42.66  273.41     15.15
# PS3              73.67   192.46       10.39  133.88      4.82
# PSP              48.98    19.66        6.23   41.51     10.50
# Wii              13.70    28.15       36.03  288.61      5.03
# X360             71.31   276.98       14.18  138.45     10.03
# XB               13.51    63.55        7.11   54.27      2.78

# %%
sns.heatmap(platform_genre_sales, cmap='PuBu')

# %% [markdown]
# https://www.python-graph-gallery.com/

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

data = []

for genre in df.Genre.unique():
    data.append(
        go.Box(y=df[df.Genre==genre].Critic_Score, 
               name=genre)
    )
iplot(data, show_link = False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f9685a42-9ebb-4e99-9d9e-72ac6e945f0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f
63.0,null,82.0,84.0,80.0,50.0,79.0,85.0,null,84.0,78.0,73.0,88.0,82.0,88.0,78.0,null,76.0,77.0,null,82.0,89.0,48.0,null,null,80.0,73.0,82.0,72.0,46.0,70.0,79.0,64.0,76.0,89.0,null,null,86.0,60.0,72.0,null,69.0,60.0,71.0,null,null,44.0,null,70.0,null,88.0,73.0,90.0,null,72.0,null,73.0,74.0,null,null,81.0,90.0,null,84.0,null,null,null,86.0,null,79.0,91.0,78.0,null,70.0,null,null,90.0,null,85.0,null,86.0,null,88.0,null,null,56.0,77.0,66.0,78.0,63.0,55.0,77.0,null,null,68.0,72.0,91.0,81.0,null,88.0,null,null,null,null,76.0,93.0,81.0,null,null,80.0,null,null,80.0,75.0,null,null,84.0,81.0,87.0,null,89.0,80.0,81.0,88.0,46.0,78.0,78.0,78.0,78.0,null,null,63.0,null,null,81.0,79.0,73.0,90.0,76.0,75.0,null,78.0,null,80.0,90.0,null,81.0,null,null,94.0,null,null,64.0,76.0,null,85.0,82.0,76.0,71.0,null,82.0,77.0,null,88.0,81.0,59.0,null,68.0,null,null,80.0,82.0,null,null,81.0,70.0,null,81.0,null,null,null,null,84.0,null,78.0,80.0,78.0,null,null,null,null,null,80.0,81.0,72.0,null,69.0,null,56.0,n ...

# %%
scores_genres_df = df.groupby('Genre')[['Critic_Score', 'User_Score']].mean()
sales_genres_df = df.groupby('Genre')[['Global_Sales']].sum()

genres_df = scores_genres_df.join(sales_genres_df)
    
genres_df.head()
trace0 = go.Scatter(
    x=genres_df.Critic_Score,
    y=genres_df.User_Score,
    mode = 'markers+text',
    text = genres_df.index,
    textposition='bottom center',
    marker = dict(
        size = 1/10*genres_df.Global_Sales,
        color = [
            'aqua', 'azure', 'beige', 'lightgreen',
            'lavender', 'lightblue', 'pink', 'salmon',
            'wheat', 'ivory', 'silver'
        ]
    )
)

data = [trace0]
layout = {
    'title': 'Statistics of video games genres',
    'xaxis': {'title': 'Critic Score'},
    'yaxis': {'title': 'User Score'}
}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2bec3685-4601-46e7-9e00-4fd10561965c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bec3685-4601-46e7-9e00-4fd10561965c")) {                    Plotly.newPlot(                        "2bec3685-4601-46e7-9e00-4fd10561965c",                        [{"marker":{"color":["aqua","azure","beige","lightgreen","lavender","lightblue","pink","salmon","wheat","ivory","silver"],"size":[174.52700000000002,23.769000000000002,44.748000000000005,80.318,82.808,24.302000000000003,72.89,93.44,105.29400000000001,39.042,133.20000000000002,17.45]},"mode":"markers+text","text":["Action","Adventure","Fighting","Misc","Platform","Puzzle","Racing","Role-Playing","Shooter","Simulation","Sports","Strategy"],"textposition":"bottom center","x":[66.62910052910053,65.3312693498452,69.21760391198045,66.61950286806884,68.05835010060362,67.42410714285714,67.96361185983828,72.65264586160109,70.18114406779661,68.61931818181819,71.96817420435511,72.08609271523179],"y":[70.54043715846994,71.33,73.02506265664161,68.19362186788155,73.01401869158879,71.75,70.3619344773791,76.19515477792733,70.41883116883118,71.34593023255815,69.61196736174071,72.95176848874598],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...
