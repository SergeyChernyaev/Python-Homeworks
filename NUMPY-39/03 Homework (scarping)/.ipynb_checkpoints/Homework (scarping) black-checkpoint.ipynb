# %% [markdown]
# ###### Домашнее задание к лекции "Основы веб-скрапинга"
# Обязательная часть
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.
# Дополнительная часть (необязательная)
#
# Функция из обязательной части задания должна быть расширена следующим образом:
#
#     кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
#     в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
#
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
import pandas as pd

import requests

# метод get
res = requests.get('https://habr.com')
# res
res.status_code

# %%
from bs4 import BeautifulSoup

# %%
# cформируем поисковый запрос, с  выводом по дате
URL = 'https://habr.com/ru/search/?q=python&target_type=posts&order=date'

# %%
# выполним запрос
req = requests.get(URL)

# %%
#  проверка на возврат нормального отвтета от сервера
req.status_code

# %%
req.text

# %%
# создаем объект, через методы которого будем искать нужные теги и извлекать их содержимое
soup = BeautifulSoup(req.text)

# %%
# Заголовок страницы c тегами
print(soup.title)

# %%
# Сам текст заголовка
print(soup.title.text)

# %%
# HTML-код его родителя
print(soup.title.parent)

# %%
# функция find_all позволяет найти все указанные теги с нужными атрибутами (с вложениями), возвращает список
news = soup.find_all('div', class_='posts__item')
print(len(news))
print(news[0])

# %%
# Вывод отформатированной страницы:
print(soup.prettify())

# %%
# функцей find_all  находим контейнеры всех публикаций, возвращаем список
articles = soup.find_all('div', class_='tm-article-snippet tm-article-snippet')
print('Всего на странице:', len(articles))

# %%
# Выводим информацию по первой статье в нормальном виде
print(articles[0].prettify())
print(type(articles[0]))

# %%
# Выделить время
el_time = articles[0].find('span', class_='tm-article-snippet__datetime-published')
time_daytime = el_time.find('time').get('datetime')
print (time_daytime)

# Выделить ссылку на статью
el_ref =  articles[0].find('a', class_='tm-article-snippet__title-link')
# Выделить заголовок
title_ = el_ref.text
print (text_link)
# Скомпоновать полную ссылку
link = 'https://www.habr.com' + el_ref.get('href')
print (link)

# %%
# Обернуть в цикл:

for el in articles:
    # Выделить время
    el_time = el.find('span', class_='tm-article-snippet__datetime-published')
    time_daytime = el_time.find('time').get('datetime')
    print (time_daytime)
    # Выделить ссылку на статью
    el_ref =  el.find('a', class_='tm-article-snippet__title-link')
    # Выделить заголовок
    title_ = el_ref.text
    print (title_)
    # Скомпоновать полную ссылку
    link = 'https://www.habr.com' + el_ref.get('href')
    print (link)
    print()

# %%
# Функция возврата статей по запросу
# Пока с одним запросом
def get_habr_articles(request, order='relevance'):
    
    url = 'https://habr.com/ru/search/?q=' + request + '&target_type=posts&order=' +  order
    print(url)
    req = requests.get(url).text
    soup = BeautifulSoup(req)

    # функцей find_all  находим контейнеры всех публикаций, возвращаем список
    articles = soup.find_all('div', class_='tm-article-snippet tm-article-snippet')
    habr_articles = pd.DataFrame()
    for el in articles:
    # Выделить время
        el_time = el.find('span', class_='tm-article-snippet__datetime-published')
        day_time = el_time.find('time').get('datetime')
    # Выделить ссылку на статью
        el_ref =  el.find('a', class_='tm-article-snippet__title-link')
    # Выделить заголовок
        title_ = el_ref.text
    # Скомпоновать полную ссылку
        link = 'https://www.habr.com' + el_ref.get('href')
        row = {'Дата':  day_time, 'Заголовок': title_, 'Ссылка': link}
        habr_articles = pd.concat([habr_articles, pd.DataFrame([row])]) 
        
    return habr_articles.reset_index(drop=True)
 
# Есть три варианта сортировки:
# по релевантоности - relevance ( параметр по умолчанию)
# по времени - date 
# по рейтингу - rating


df_articles = get_habr_articles('python для анализа данных', 'rating')

df_articles.info()
df_articles.head(20)

# %%
import time

# Функция поиска текста и числа лайков
def request_text_and_likes(url_txt):
    # Если ссылка с меткой post, то используй 2 иначе 1
    if 'post' in url_txt:
        class_num = '1'
    else:
        class_num = '2' 
    req = requests.get(url_txt).text
    time.sleep(0.1) # задержка на возможный повторный запрос
    soup_text = BeautifulSoup(req)
   # Ищем количество лайков 
    cl_likes_positiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive "  
    cl_likes_positiv += "tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"
   # Или дизлайков     
    cl_likes_negotiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_negative"
    cl_likes_negotiv += " tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"   
    
    likes_ = soup_text.find('span', class_= cl_likes_positiv)
    
    if likes_!= None:
        likes_count = int(likes_.text)
    else:  # а вдруг нет лайков??
        likes_ = soup_text.find('span', class_= cl_likes_negotiv) # тогда считаем дизлайки
        if likes_!= None: 
            likes_count = int(likes_.text)
        else: # а вдруг нет и дизлайков??
            likes_count = 0 
    
   # Пробуем класс форматироваия версии 1 -'article-formatted-body article-formatted-body article-formatted-body_version-1'
    text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-1' 
                           )
    form_version = 1
    
    if text_ == None:# Ничего не найдено. Нужент формат версии 2:
        text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-2' 
                               ) 
        form_version = 2
        
    print (f'Получен текст по ссылке: {url_txt}. Формат версии: {form_version}. Поставлено лайков/дизлайков: {likes_count}')
    return [text_.text, likes_count]

 


# Функция возврата статей по запросу

def get_habr_articles_list(request_lst, order='relevance', pages=1):
# 
    habr_articles = pd.DataFrame()
    
    # Обернём всё в цикл по списку запросов 
    for request in request_lst:
        url = 'https://habr.com/ru/search/?q=' + str(request) + '&target_type=posts&order=' +  order
        req = requests.get(url).text
        time.sleep(0.1)
        soup = BeautifulSoup(req)

    # функцей find_all  находим контейнеры всех публикаций, возвращаем список
        articles = soup.find_all('div', class_='tm-article-snippet tm-article-snippet')
        for el in articles:
    # Выделить время
            el_time = el.find('span', class_='tm-article-snippet__datetime-published')
            day_time = el_time.find('time').get('datetime')
    # Выделить ссылку на статью
            el_ref =  el.find('a', class_='tm-article-snippet__title-link')
    # Выделить заголовок
            title_ = el_ref.text
    # Скомпоновать полную ссылку
            link = 'https://www.habr.com' + el_ref.get('href')
    # Получить текст поста, новости, записи или новости из блога 
    # компании по ссылке c количеством лайков в виде списка
            text_likes_lst = request_text_and_likes(link)
        
    # Добавить новую строку в датафрейм    
            row = {'Дата':  day_time, 
                   'Заголовок': title_, 
                   'Ссылка': link, 
                   'Текст': text_likes_lst[0], 
                   'Лайки': text_likes_lst[1]
                  }
            habr_articles = pd.concat([habr_articles, pd.DataFrame([row])]) 
    # Получиь уникальные строки на основе столбца ссылок, поскольку в нем содержатся уникальные значения:
    habr_articles = habr_articles.drop_duplicates (subset=['Ссылка'])
    
    return habr_articles.reset_index(drop=True)
     
    
# Есть три варианта сортировки:
# по релевантоности - relevance ( параметр по умолчанию)
# по времени - date 
# по рейтингу - rating

search_list = ['анализ данных', 
               'python', 
               'python для анализа данных',
               'python в аналитике больших данных']

df_articles = get_habr_articles_list( search_list, 'date')

#df_articles.info()

print('\n\nНайдено уникальных', len(df_articles), ' значений по ', len(search_list), ' запросам:' )

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 6)
pd.set_option("display.width", 1000)
pd.set_option("display.colheader_justify", "center")
pd.set_option("display.precision", 2)

display(df_articles.sort_values(by='Ссылка'))
# Out:
# Получен текст по ссылке: https://www.habr.com/ru/post/707514/. Формат версии: 2. Поставлено лайков/дизлайков: -23
# Получен текст по ссылке: https://www.habr.com/ru/post/707496/. Формат версии: 2. Поставлено лайков/дизлайков: 16
# Получен текст по ссылке: https://www.habr.com/ru/post/707474/. Формат версии: 2. Поставлено лайков/дизлайков: 18
# Получен текст по ссылке: https://www.habr.com/ru/post/707464/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/news/t/707450/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/707392/. Формат версии: 2. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/news/t/707364/. Формат версии: 2. Поставлено лайков/дизлайков: 24
# Получен текст по ссылке: https://www.habr.com/ru/post/707358/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/swd_es/blog/707356/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/news/t/707354/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/company/jetinfosystems/news/t/707332/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/rshb/news/t/707330/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/news/t/707324/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/ua-hosting/blog/706516/. Формат версии: 1. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/post/707304/. Формат версии: 2. Поставлено лайков/дизлайков: 11
# Получен текст по ссылке: https://www.habr.com/ru/post/707302/. Формат версии: 2. Поставлено лайков/дизлайков: -9
# Получен текст по ссылке: https://www.habr.com/ru/post/707298/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/first/blog/707246/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/company/eaeconsult/blog/707182/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/707264/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/alfa/blog/707466/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/post/707222/. Формат версии: 1. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/707442/. Формат версии: 2. Поставлено лайков/дизлайков: -9
# Получен текст по ссылке: https://www.habr.com/ru/post/707380/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/post/707374/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/707006/. Формат версии: 1. Поставлено лайков/дизлайков: 23
# Получен текст по ссылке: https://www.habr.com/ru/company/selectel/blog/707346/. Формат версии: 1. Поставлено лайков/дизлайков: 27
# Получен текст по ссылке: https://www.habr.com/ru/company/swd_es/blog/707356/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/706418/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/707298/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/inDrive/blog/706842/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/707250/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/707230/. Формат версии: 2. Поставлено лайков/дизлайков: 135
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/707136/. Формат версии: 1. Поставлено лайков/дизлайков: 1
# Получен текст по ссылке: https://www.habr.com/ru/post/707206/. Формат версии: 2. Поставлено лайков/дизлайков: 20
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/707130/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/garage8/blog/707180/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/post/707158/. Формат версии: 2. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/company/X5Tech/blog/707156/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/707092/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/company/swd_es/blog/707356/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/707298/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/garage8/blog/707180/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/post/707158/. Формат версии: 2. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/707092/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/post/707098/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/postgrespro/blog/701220/. Формат версии: 2. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/706946/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/post/706856/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/rvision/blog/706046/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/706646/. Формат версии: 2. Поставлено лайков/дизлайков: 12
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/706164/. Формат версии: 1. Поставлено лайков/дизлайков: 40
# Получен текст по ссылке: https://www.habr.com/ru/post/706624/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/706610/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/tinkoff/blog/706544/. Формат версии: 2. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/solarsecurity/blog/705986/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/post/706250/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog
# 2   2022-12-24T11:02:37.000Z  «Мутные» перспективы производителя ламп Thomso...               https://www.habr.com/ru/post/707474/  Всем привет!Я популяризирую требовательное отн...    18
# 1   2022-12-24T16:21:17.000Z  Мощь декораторов TypeScript на живых примерах....               https://www.habr.com/ru/post/707496/  Photo by TOMMY VAN KESSEL on UnsplashДекоратор...    16
# 0   2022-12-24T21:33:28.000Z                                 Половой вопрос — 2               https://www.habr.com/ru/post/707514/  Стоит ли бороться за гендерное равенство? Авто...   -23

# %%
link_post = 'https://habr.com/ru/post/707222/'

# %%
# Функция формирования текста
def request_text(url_txt):
    # Если ссылка с меткой post, то используй 2 иначе 1
    if 'post' in url_txt:
        class_num = '1'
    else:
        class_num = '2' 
    
    req = requests.get(url_txt).text
    time.sleep(0.3) # задержка на возможный повторный запрос
    soup_text = BeautifulSoup(req)
   # Нужный класс для постов - 'article-formatted-body article-formatted-body article-formatted-body_version-1' 
   # Нужный класс для всего КРОМЕ post - 'article-formatted-body article-formatted-body article-formatted-body_version-2'
    text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-' + 
                       str(class_num))
    print ('------------------------------Текст по ссылке:', url_txt, '----------------------')
    #print(text_.text)
    print ('------------------------------Конец блока----------------------\n')
    return text_.text

link_post_lst = ['https://habr.com/ru/post/707222/', 
                 'https://habr.com/ru/company/alfa/blog/707466/',
                 'https://habr.com/ru/company/southbridge/news/t/595093/',
                 'https://habr.com/ru/news/t/654707/']

for link in link_post_lst:             
    request_text(link)
# Out:
# ------------------------------Текст по ссылке: https://habr.com/ru/post/707222/ ----------------------
# ------------------------------Конец блока----------------------
#
# ------------------------------Текст по ссылке: https://habr.com/ru/company/alfa/blog/707466/ ----------------------
# ------------------------------Конец блока----------------------
#
# ------------------------------Текст по ссылке: https://habr.com/ru/company/southbridge/news/t/595093/ ----------------------
# ------------------------------Конец блока----------------------
#
# ------------------------------Текст по ссылке: https://habr.com/ru/news/t/654707/ ----------------------
# ------------------------------Конец блока----------------------

# %%
link_company_blogs = 'https://habr.com/ru/company/alfa/blog/707466/'

# %%
# Пробуем для блогов компаний 
link_company_blogs = 'https://habr.com/ru/company/alfa/blog/707466/'
req = requests.get(link_company_blogs).text
soup_text = BeautifulSoup(req)

# Нужный класс для команий - 'article-formatted-body article-formatted-body article-formatted-body_version-2'
class_num  = '2' 
text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-' + 
                       class_num)
print(text_.text)

# %%
link_company_news = 'https://habr.com/ru/company/southbridge/news/t/595093/'

req = requests.get(link_company_news).text
soup_text = BeautifulSoup(req)

# Нужный класс для новостей компаний - 'article-formatted-body article-formatted-body article-formatted-body_version-2'

text_ = soup_text.find('div', class_='article-formatted-body article-formatted-body article-formatted-body_version-2')
print(text_.text)

# %%
# Просто новость
link_news = 'https://habr.com/ru/company/southbridge/news/t/595093/'
req = requests.get(link_news).text
soup_text = BeautifulSoup(req)

# Нужный класс для новостей - 'article-formatted-body article-formatted-body article-formatted-body_version-2'

text_ = soup_text.find('div', class_='article-formatted-body article-formatted-body article-formatted-body_version-2')
#print(text_.text)

#Лайки
#<span title="Всего голосов 11: ↑10 и ↓1" 
cl_name = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"
like_ = soup_text.find('span', class_=cl_name)
print(like_)
print(int(like_.text))
# Out:
# <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 11: ↑10 и ↓1">+9</span>
# 9

# %%
# Страница результато запроса

link_search_req = 'https://habr.com/ru/search/?q=python&target_type=posts&order=relevance'
req = requests.get(link_company_blogs).text
soup_req = BeautifulSoup(req)
#print(soup_req.prettify())
pages = soup_req.find('pagesCount')
print(pages)
# Out:
# None

# %%
import time

# Функция поиска текста и числа лайков
def request_text_and_likes(url_txt):
    # Если ссылка с меткой post, то используй 2 иначе 1
    if 'post' in url_txt:
        class_num = '1'
    else:
        class_num = '2' 
    req = requests.get(url_txt).text
    time.sleep(0.1) # задержка на возможный повторный запрос
    soup_text = BeautifulSoup(req)
   # Ищем количество лайков 
    cl_likes_positiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive "  
    cl_likes_positiv += "tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"
   # Или дизлайков     
    cl_likes_negotiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_negative"
    cl_likes_negotiv += " tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"   
    
    likes_ = soup_text.find('span', class_= cl_likes_positiv)
    
    if likes_!= None:
        likes_count = int(likes_.text)
    else:  # а вдруг нет лайков??
        likes_ = soup_text.find('span', class_= cl_likes_negotiv) # тогда считаем дизлайки
        if likes_!= None: 
            likes_count = int(likes_.text)
        else: # а вдруг нет и дизлайков??
            likes_count = 0 
    
   # Пробуем класс форматироваия версии 1 -'article-formatted-body article-formatted-body article-formatted-body_version-1'
    text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-1' 
                           )
    form_version = 1
    
    if text_ == None:# Ничего не найдено. Нужент формат версии 2:
        text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-2' 
                               ) 
        form_version = 2
        
    print (f'Получен текст по ссылке: {url_txt}. Формат версии: {form_version}. Поставлено лайков/дизлайков: {likes_count}')
    return [text_.text, likes_count]

 


# Функция возврата статей по запросу

def get_habr_articles_list(request_lst, order='relevance', pages=1):
# 
    habr_articles = pd.DataFrame()
    
    # Обернём всё в цикл по списку запросов 
    for request in request_lst:
        
        for page in range (1, pages+1):
            # https://habr.com/ru/search/page1/?q=python&target_type=posts&order=relevance
            url = 'https://habr.com/ru/search/page'+str(page)+'/?q=' + str(request) + '&target_type=posts&order=' +  order
            
            req = requests.get(url)
            time.sleep(0.1)
             # Проверить на успех:
            if req.status_code != 200: # что-то пошло не так, например кончились страницы
                break # выход из цикла
            
            soup = BeautifulSoup(req.text)
            print ('Запрос:', url, 'страница выдачи:', page)
    # функцей find_all  находим контейнеры всех публикаций, возвращаем список
            articles = soup.find_all('div', class_='tm-article-snippet tm-article-snippet')
            for el in articles:
    # Выделить время
                el_time = el.find('span', class_='tm-article-snippet__datetime-published')
                day_time = el_time.find('time').get('datetime')
    # Выделить ссылку на статью
                el_ref =  el.find('a', class_='tm-article-snippet__title-link')
    # Выделить заголовок
                title_ = el_ref.text
    # Скомпоновать полную ссылку
                link = 'https://www.habr.com' + el_ref.get('href')
    # Получить текст поста, новости, записи или новости из блога 
    # компании по ссылке c количеством лайков в виде списка
                text_likes_lst = request_text_and_likes(link)
        
    # Добавить новую строку в датафрейм    
                row = {'Дата':  day_time, 
                       'Заголовок': title_, 
                       'Ссылка': link, 
                       'Текст': text_likes_lst[0], 
                       'Лайки': text_likes_lst[1]
                      }
                habr_articles = pd.concat([habr_articles, pd.DataFrame([row])]) 
    
    
    
    
    # Получиь уникальные строки на основе столбца ссылок, поскольку в нем содержатся уникальные значения:
    habr_articles = habr_articles.drop_duplicates (subset=['Ссылка'])
    
    return habr_articles.reset_index(drop=True)
     
    
# Есть три варианта сортировки:
# по релевантоности - relevance ( параметр по умолчанию)
# по времени - date 
# по рейтингу - rating

'''
search_list = ['анализ данных', 
               'python', 
               'python для анализа данных',
               'python в аналитике больших данных']
'''
search_list = ['python', 
               'python для анализа данных'
              ]

max_pages = 60
df_articles = get_habr_articles_list( search_list, 'date', max_pages)

#df_articles.info()

print('\n\nНайдено уникальных', len(df_articles), 
      ' значений по ', len(search_list), 
      ' запросам на', max_pages, 'или меньше (см. выдачу) страницах')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 6)
pd.set_option("display.width", 1000)
pd.set_option("display.colheader_justify", "center")
pd.set_option("display.precision", 2)

display(df_articles.sort_values(by='Дата', ascending = True))
# Out:
# Запрос: https://habr.com/ru/search/page1/?q=python&target_type=posts&order=date страница выдачи: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/alfa/blog/707466/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/post/707222/. Формат версии: 1. Поставлено лайков/дизлайков: 16
# Получен текст по ссылке: https://www.habr.com/ru/post/707442/. Формат версии: 2. Поставлено лайков/дизлайков: -9
# Получен текст по ссылке: https://www.habr.com/ru/post/707380/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/post/707374/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/707006/. Формат версии: 1. Поставлено лайков/дизлайков: 23
# Получен текст по ссылке: https://www.habr.com/ru/company/selectel/blog/707346/. Формат версии: 1. Поставлено лайков/дизлайков: 27
# Получен текст по ссылке: https://www.habr.com/ru/company/swd_es/blog/707356/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/706418/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/707298/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/inDrive/blog/706842/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/707250/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/707230/. Формат версии: 2. Поставлено лайков/дизлайков: 141
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/707136/. Формат версии: 1. Поставлено лайков/дизлайков: 1
# Получен текст по ссылке: https://www.habr.com/ru/post/707206/. Формат версии: 2. Поставлено лайков/дизлайков: 20
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/707130/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/garage8/blog/707180/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/post/707158/. Формат версии: 2. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/company/X5Tech/blog/707156/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/707092/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Запрос: https://habr.com/ru/search/page2/?q=python&target_type=posts&order=date страница выдачи: 2
# Получен текст по ссылке: https://www.habr.com/ru/post/707098/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/post/706230/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/707064/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/706872/. Формат версии: 1. Поставлено лайков/дизлайков: -1
# Получен текст по ссылке: https://www.habr.com/ru/company/postgrespro/blog/701220/. Формат версии: 2. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/706946/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/post/706856/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/rvision/blog/706046/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/706754/. Формат версии: 2. Поставлено лайков/дизлайков: 32
# Получен текст по ссылке: https://www.habr.com/ru/company/tochka/blog/706726/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/news/t/706720/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/706702/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/706646/. Формат версии: 2. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/706458/. Формат версии: 1. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/706164/. Формат версии: 1. Поставлено лайков/дизлайков: 40
# Получен текст по ссылке: https://www.habr.com/ru/post/706624/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/706610/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/706590/. Формат версии: 2. Поставлено лайков/дизлайков: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/cloud4y/blog/706588/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/news/t/706582/. Формат версии: 2. Поставлено лайков/дизлайков: 1
# Запрос: https://habr.com/ru/search/page3/?q=python&target_type=posts&order=date страница выдачи: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/tinkoff/blog/706544/. Формат версии: 2. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/lanit/blog/706358/. Формат версии: 2. Поставлено лайков/дизлайков: 40
# Получен текст по ссылке: https://www.habr.com/ru/post/706446/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/706362/. Формат версии: 2. Поставлено лайков/дизлайков: -1
# Получен текст по ссылке: https://www.habr.com/ru/post/706436/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/706406/. Формат версии: 1. Поставлено лайков/дизлайков: 28
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/706394/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/post/706402/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/post/706374/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/solarsecurity/blog/705986/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/post/706250/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog
Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/company/kryptonite/blog/702480/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/post/702458/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/post/702432/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/702370/. Формат версии: 2. Поставлено лайков/дизлайков: 12
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/702328/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Запрос: https://habr.com/ru/search/page11/?q=python&target_type=posts&order=date страница выдачи: 11
# Получен текст по ссылке: https://www.habr.com/ru/company/spbifmo/blog/702202/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/698532/. Формат версии: 1. Поставлено лайков/дизлайков: 46
# Получен текст по ссылке: https://www.habr.com/ru/company/qiwi/blog/702302/. Формат версии: 2. Поставлено лайков/дизлайков: 24
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701588/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/company/kaspersky/blog/701670/. Формат версии: 1. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/post/702162/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/post/702218/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/first/blog/702168/. Формат версии: 2. Поставлено лайков/дизлайков: 23
# Получен текст по ссылке: https://www.habr.com/ru/post/702210/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/magnit/blog/702196/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/post/702160/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/post/702148/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/post/702104/. Формат версии: 2. Поставлено лайков/дизлайков: 76
# Получен текст по ссылке: https://www.habr.com/ru/company/mango_telecom/blog/702072/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/robouniver/blog/702064/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/702026/. Формат версии: 1. Поставлено лайков/дизлайков: 23
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/701982/. Формат версии: 2. Поставлено лайков/дизлайков: 17
# Получен текст по ссылке: https://www.habr.com/ru/company/quadcode/blog/701112/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/post/701682/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/news/t/701884/. Формат версии: 1. Поставлено лайков/дизлайков: 4
# Запрос: https://habr.com/ru/search/page12/?q=python&target_type=posts&order=date страница выдачи: 12
# Получен текст по ссылке: https://www.habr.com/ru/post/701894/. Формат версии: 2. Поставлено лайков/дизлайков: 12
# Получен текст по ссылке: https://www.habr.com/ru/post/701890/. Формат версии: 2. Поставлено лайков/дизлайков: -1
# Получен текст по ссылке: https://www.habr.com/ru/post/701794/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/post/701802/. Формат версии: 2. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/post/701800/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/post/701798/. Формат версии: 2. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/701530/. Формат версии: 1. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/vasexperts/blog/701600/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/701686/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/701552/. Формат версии: 2. Поставлено лайков/дизлайков: 320
# Получен текст по ссылке: https://www.habr.com/ru/post/697630/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/689234/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/701458/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/company/cloud_mts/blog/701444/. Формат версии: 1. Поставлено лайков/дизлайков: 15
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701412/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/rshb/blog/701278/. Формат версии: 2. Поставлено лайков/дизлайков: 18
# Получен текст по ссылке: https://www.habr.com/ru/company/evraz/blog/701362/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/701198/. Формат версии: 2. Поставлено лайков/дизлайков: 32
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701324/. Формат версии: 2. Поставлено лайков/дизлайков: 22
# Получен текст по ссылке: https://www.habr.com/ru/post/699560/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Запрос: https://habr.com/ru/search/page13/?q=python&target_type=posts&order=date страница выдачи: 13
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/701302/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/office_partner/blog/701272/. Формат версии: 2. Поставлено лайков/дизлайков: -4
# Получен текст по ссылке: https://www.habr.com/ru/post/701268/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/700918/. Формат версии: 1. Поставлено лайков/дизлайков: 28
# Получен текст по ссылке: https://www.habr.com/ru/news/t/701260/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/company/hh/blog/700734/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/700248/. Формат версии: 1. Поставлено лайков/дизлайков: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701144/. Формат версии: 2. Поставлено лайков/дизлайков: 11
# Получен текст по ссылке: https://www.habr.com/ru/post/701098/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/selectel/blog/700996/. Формат версии: 1. Поставлено лайков/дизлайков: 44
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/700520/. Формат версии: 1. Поставлено лайков/дизлайков: 38
# Получен текст по ссылке: https://www.habr.com/ru/article/700656/. Формат версии: 2. Поставлено лайков/дизлайков: 25
# Получен текст по ссылке: https://www.habr.com/ru/company/simbirsoft/blog/701020/. Формат версии: 2. Поставлено лайков/дизлайков: 16
# Получен текст по ссылке: https://www.habr.com/ru/company/redmadrobot/blog/701030/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/jetinfosystems/blog/701026/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/post/701016/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/post/699600/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/postgrespro/blog/694996/. Формат версии: 1. Поставлено лайков/дизлайков: 17
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/700246/. Формат версии: 1. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/news/t/700958/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Запрос: https://habr.com/ru/search/page14/?q=python&target_type=posts&order=date страница выдачи: 14
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog
Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/post/676170/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/news/t/676200/. Формат версии: 1. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/post/676128/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/675796/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/675978/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/675954/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/company/alfastrah/blog/675838/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/post/675700/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Запрос: https://habr.com/ru/search/page20/?q=python для анализа данных&target_type=posts&order=date страница выдачи: 20
# Получен текст по ссылке: https://www.habr.com/ru/company/redmadrobot/blog/675666/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/rostelecom/blog/675554/. Формат версии: 2. Поставлено лайков/дизлайков: 11
# Получен текст по ссылке: https://www.habr.com/ru/company/constanta/blog/675408/. Формат версии: 1. Поставлено лайков/дизлайков: 12
# Получен текст по ссылке: https://www.habr.com/ru/company/sberbank/blog/675388/. Формат версии: 2. Поставлено лайков/дизлайков: 11
# Получен текст по ссылке: https://www.habr.com/ru/company/icl_services/blog/675336/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/timeweb/blog/674800/. Формат версии: 1. Поставлено лайков/дизлайков: 13
# Получен текст по ссылке: https://www.habr.com/ru/post/674494/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/675044/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/post/675220/. Формат версии: 2. Поставлено лайков/дизлайков: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/675110/. Формат версии: 1. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/post/675124/. Формат версии: 2. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/post/675106/. Формат версии: 2. Поставлено лайков/дизлайков: -2
# Получен текст по ссылке: https://www.habr.com/ru/company/swordfish_security/news/t/675040/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/674880/. Формат версии: 2. Поставлено лайков/дизлайков: 8
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/674960/. Формат версии: 1. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/news/t/674920/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/sberbank/blog/674896/. Формат версии: 2. Поставлено лайков/дизлайков: 12
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/674866/. Формат версии: 2. Поставлено лайков/дизлайков: 94
# Получен текст по ссылке: https://www.habr.com/ru/post/674764/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/news/t/674792/. Формат версии: 1. Поставлено лайков/дизлайков: 0
# Запрос: https://habr.com/ru/search/page21/?q=python для анализа данных&target_type=posts&order=date страница выдачи: 21
# Получен текст по ссылке: https://www.habr.com/ru/post/674802/. Формат версии: 2. Поставлено лайков/дизлайков: -9
# Получен текст по ссылке: https://www.habr.com/ru/post/674658/. Формат версии: 2. Поставлено лайков/дизлайков: -2
# Получен текст по ссылке: https://www.habr.com/ru/company/fsight/blog/674462/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/timeweb/blog/674248/. Формат версии: 1. Поставлено лайков/дизлайков: 16
# Получен текст по ссылке: https://www.habr.com/ru/post/674476/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/673992/. Формат версии: 1. Поставлено лайков/дизлайков: 38
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/673320/. Формат версии: 1. Поставлено лайков/дизлайков: 19
# Получен текст по ссылке: https://www.habr.com/ru/post/673726/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/blog/673656/. Формат версии: 2. Поставлено лайков/дизлайков: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/swordfish_security/blog/673520/. Формат версии: 2. Поставлено лайков/дизлайков: 6
# Получен текст по ссылке: https://www.habr.com/ru/news/t/673514/. Формат версии: 1. Поставлено лайков/дизлайков: 9
# Получен текст по ссылке: https://www.habr.com/ru/post/673474/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/673416/. Формат версии: 2. Поставлено лайков/дизлайков: 10
# Получен текст по ссылке: https://www.habr.com/ru/company/bigdataplatform/blog/673098/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Получен текст по ссылке: https://www.habr.com/ru/company/rosatom/blog/671442/. Формат версии: 2. Поставлено лайков/дизлайков: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/672450/. Формат версии: 2. Поставлено лайков/дизлайков: 7
# Получен текст по ссылке: https://www.habr.com/ru/post/673110/. Формат версии: 2. Поставлено лайков/дизлайков: 14
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/672934/. Формат версии: 2. Поставлено лайков/дизлайков: 4
# Получен текст по ссылке: https://www.habr.com/ru/post/672952/. Формат версии: 2. Поставлено лайков/дизлайков: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/spbifmo/blog/671776/. Формат версии: 2. Поставлено лайков/дизлайков: 0
# Запрос: https://habr.com/ru/search/page22/?q=python для анализа данных&target_type=posts&order=date страница выдачи: 22
