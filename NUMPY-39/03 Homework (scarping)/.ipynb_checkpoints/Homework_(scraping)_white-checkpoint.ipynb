# %% [markdown]
# #### Домашнее задание к лекции "Основы веб-скрапинга"
# Обязательная часть
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.
# Дополнительная часть (необязательная)
#
# Функция из обязательной части задания должна быть расширена следующим образом:
#
#     кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
#     в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
#
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
#----- Окончательный вариант-------------

import pandas as pd
import requests
import time
from datetime import datetime
from dateutil import parser
from bs4 import BeautifulSoup

# Функция преобразования ISO 8601 строки в дату
def covert_to_date (date_time_str):
    # Можно распознать парсером отметку даты и сразу её вернуть
    return parser.parse(date_time_str).date()

# Функция поиска текста и числа лайков
def request_text_and_likes(url_txt):
    
    req = requests.get(url_txt).text
    time.sleep(0.1) # задержка на возможный повторный запрос
    soup_text = BeautifulSoup(req)
    # Пробуем класс форматироваия версии 1:
    # 'article-formatted-body article-formatted-body article-formatted-body_version-1'
    text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-1' 
                           )
    form_version = 1
    
    if text_ == None:# Ничего не найдено. Нужент формат версии 2:
        text_ = soup_text.find('div', 
                       class_='article-formatted-body article-formatted-body article-formatted-body_version-2' 
                               ) 
# В выдаче по дате ссылка на 33 странице запроса "python для анализа данных" на одном из прогонов
# запрос: https://habr.com/ru/search/page33/?q=python для анализа данных&target_type=posts&order=date страница выдачи: 33
# новость https://www.habr.com/ru/company/JetBrains-education/news/t/647151/
# осущетвляет редирект на  https://habr.com/ru/company/JetBrains-education/blog/
# пустую страницу компании "JetBrains"
# чтобы это обойти пришлось усложнить код...
        
        if text_ == None: # Опять не сработало??? Значит ссылка не рабочая. Выбросить   
            print (f'В поисковой выдаче ссылка {url_txt} не адресует к конкретной информации на сайте.')
            return []
        else: # сработало на новом формате который 2
            form_version = 2
            # определим лайки
            likes_count = likes_counter(soup_text)
            print(f'Получен текст по ссылке: {url_txt}. Формат версии шаблона: {form_version}.') 
            print(f'Поставлено пользователями лайков(+)/дизлайков(-): {likes_count}.')
            return [text_.text, likes_count]
    else:# сработало сразу на формате 1, чего суетиться..
        likes_count = likes_counter(soup_text)
        print(f'Получен текст по ссылке: {url_txt}. Формат версии шаблона: {form_version}.') 
        print(f'Поставлено пользователями лайков(+)/дизлайков(-): {likes_count}.')
        return [text_.text, likes_count] 
 
# Функция определения количества  лайков
def likes_counter(soup):
   # Ищем количество лайков 
    cl_likes_positiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive "  
    cl_likes_positiv += "tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"
   # Или дизлайков     
    cl_likes_negotiv = "tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_negative"
    cl_likes_negotiv += " tm-votes-meter__value_appearance-article tm-votes-meter__value_rating"   
    
    likes_count = 0 # обнуление - нет ни лайков, ни дизлайков
    likes_ = soup.find('span', class_= cl_likes_positiv)
    
    if likes_ != None:
        likes_count = int(likes_.text)
    else:  # а вдруг нет лайков??
        likes_ = soup.find('span', class_= cl_likes_negotiv) # тогда считаем дизлайки
        if likes_!= None: 
            likes_count = int(likes_.text)
    return likes_count

# Функция возврата статей по запросу
def get_habr_articles_list(request_lst=[], order='relevance', page_start=1, page_finish=1):
 
    habr_articles = pd.DataFrame()
    
    # Обернём всё в цикл по списку запросов 
    for request in request_lst:
        
        for page in range (page_start, page_finish+1):
            # https://habr.com/ru/search/page1/?q=python&target_type=posts&order=relevance
            url = 'https://habr.com/ru/search/page'+str(page)+'/?q=' + str(request) + '&target_type=posts&order=' +  order
            
            req = requests.get(url)
            time.sleep(0.1)
             # Проверить на успех:
            if req.status_code != 200: # что-то пошло не так, например кончились страницы
                break # выход из цикла
            
            soup = BeautifulSoup(req.text)
            print ('Запрос:', url, 'страница выдачи:', page)
            # функцей find_all  находим контейнеры всех публикаций, возвращаем список
            articles = soup.find_all('div', class_='tm-article-snippet tm-article-snippet')
            for el in articles:
            # Выделить дату и время в виде строки ISO даты и времени
                el_time = el.find('span', class_='tm-article-snippet__datetime-published')
                # Извлечь дату из объекта datetime
                data_ = covert_to_date(el_time.find('time').get('datetime'))
                # Выделить ссылку на статью
                el_ref =  el.find('a', class_='tm-article-snippet__title-link')
                # Выделить заголовок
                title_ = el_ref.text
                # Скомпоновать полную ссылку
                link = 'https://www.habr.com' + el_ref.get('href')
                # Получить текст поста, новости, записи или новости из блога 
                # компании по ссылке c количеством лайков в виде списка
                text_likes_lst = request_text_and_likes(link)
                if text_likes_lst: # если есть реальные данные
                # Добавить новую строку в датафрейм    
                    row = {'Дата':  data_, 
                           'Заголовок': title_, 
                           'Ссылка': link, 
                           'Текст': text_likes_lst[0], # собсвенно текст
                           'Лайки': text_likes_lst[1]  # лайки/дизлайки
                          }
                    habr_articles = pd.concat([habr_articles, pd.DataFrame([row])]) 
                  
    # Получить уникальные строки на основе столбца ссылок, поскольку в нем содержатся уникальные значения:
    habr_articles = habr_articles.drop_duplicates (subset=['Ссылка'])
    return habr_articles.reset_index(drop=True)
     
    
# Есть три варианта сортировки:
# по релевантоности - relevance (параметр по умолчанию)
# по времени - date 
# по рейтингу - rating
'''
search_list = ['анализ данных', 
               'python', 
               'python для анализа данных',
               'python в аналитике больших данных', 
               'Половой вопрос — 2'
              ]
'''
#search_list = ['Половой вопрос — 2'] # прекрасный тест на дизлайки
#search_list = [] # для краш-теста, который функция уже проходит

search_list = ['python', 
               'python для анализа данных',
               'python в аналитике больших данных', 
               ]

# Есть три варианта сортировки:
# по релевантности - relevance (параметр по умолчанию)
# по времени - date 
# по рейтингу - rating
sort_type = 'relevance'

# Стартовая страница для записи поиcковой 
# выдачи в датафрейм ( а вдруг нужно не начало выдачи?). По умолчанию - 1. 
start_page = 1

# Конечная страница выдачи. По умолчанию - 1. 
finish_page = 5

df_articles = get_habr_articles_list(search_list, sort_type, start_page, finish_page)

print('\n\n')
df_articles.info()

print('\n\nНайдено уникальных', len(df_articles), 
      ' значений по ', len(search_list), 
      ' запросам на', finish_page-start_page+1, 
      'страницах')
print ('\nВсего обработано значений:', 20*len(search_list)*(finish_page-start_page+1),'\n')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 6)
pd.set_option("display.width", 1000)
pd.set_option("display.colheader_justify", "center")
pd.set_option("display.precision", 2)
if not df_articles.empty:
    display(df_articles.sort_index(ascending = True)) # по возрастанию индекса, т.е. по выдаче в запросе
# Out:
# Запрос: https://habr.com/ru/search/page1/?q=python&target_type=posts&order=relevance страница выдачи: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/595093/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/646825/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/498364/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/raiffeisenbank/news/t/566370/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/645485/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/531402/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/654707/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/itsumma/news/t/490834/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 31.
# В поисковой выдаче ссылка https://www.habr.com/ru/company/epam_systems/news/t/589555/ не адресует к конкретной информации на сайте.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/683604/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/505096/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/527858/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 21.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/695298/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/473926/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/581862/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/582682/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex_praktikum/news/t/669486/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/684376/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/703652/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/705358/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Запрос: https://habr.com/ru/search/page2/?q=python&target_type=posts&order=relevance страница выдачи: 2
# Получен текст по ссылке: https://www.habr.com/ru/news/t/519414/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 22.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/645777/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/666476/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/656419/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/662437/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/680662/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/690692/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/580100/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/netologyru/news/t/594683/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/649717/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/667478/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/692528/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/579264/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/itsumma/news/t/584010/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 39.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/584584/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/673668/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/kts/news/t/688988/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/evrone/news/t/698054/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/news/t/594325/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/company/usetech/news/t/661427/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Запрос: https://habr.com/ru/search/page3/?q=python&target_type=posts&order=relevance страница выдачи: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/678866/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/147281/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 108.
# Получен текст по ссылке: https://www.habr.com/ru/post/205944/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 142.
# Получен текст по ссылке: https://www.habr.com/ru/company/intersystems/blog/486984/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/538706/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/post/161931/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/post/168083/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 64.
# Получен текст по ссылке: https://www.habr.com/ru/post/168827/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/post/169639/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 35.
# Получен текст по ссылке: https://www.habr.com/ru/post/203516/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 29.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/234747/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 77.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/254727/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 42.
# Получен текст по ссылке: https://www.habr.com/ru/post/269411/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/337364/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 54.
# Получен текст по ссылке: https://www.habr.com/ru/company/ods/blog/348260/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 39.
# Получен текст по ссылке: https://www.habr.com/ru/post/415513/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/418449/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 45.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/418823/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 51.
# Получен текст по ссылке: https://www.habr.com/ru/company/microsoft/blog/423067/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 21.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/425233/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Запрос: https://habr.com/ru/search/page4/?q=python&target_type=posts&order=relevance страница выдачи: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/454324/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 65.
# Получен текст по ссылке: https://www.habr.com/ru/post/455796/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/457942/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/475392/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Получен текст по ссылке: https://www.habr.com/ru/company/edison/blog/477442/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/480898/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/post/484634/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -3.
# Получен текст по ссылке: https://www.habr.com/ru/post/495480/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/post/495636/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/499534/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 66.
# Получен текст по ссылке: https://www.habr.com/ru/post/501920/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/516310/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 44.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/528232/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/528880/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/563098/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/572748/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 39.
# Получен текст по ссылке: https://www.habr.com/ru/company/timeweb/blog/579080/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/586360/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 57.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/589367/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/company/raiffeisenbank/blog/593047/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 35.
# Запрос: https://habr.com/ru/search/page5/?q=python&target_type=posts&order=relevance страница выдачи: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/etmc_exponenta/blog/596397/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/598647/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 21.
# Получен текст по ссылке: https://www.habr.com/ru/company/evrone/blog/685264/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 54.
# Получен текст по ссылке: https://www.habr.com/ru/company/jugru/blog/686150/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 38.
# Получен текст по ссылке: https://www.habr.com/ru/post/686186/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): -5.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/695146/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/696634/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/701982/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/post/46350/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 48.
# Получен текст по ссылке: https://www.habr.com/ru/post/88972/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 33.
# Получен текст по ссылке: https://www.habr.com/ru/post/150302/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 32.
# Получен текст по ссылке: https://www.habr.com/ru/post/167261/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 68.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/201778/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 56.
# Получен текст по ссылке: https://www.habr.com/ru/post/246699/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 26.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/263457/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/post/347406/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/418447/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 18.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/425469/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 27.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/425473/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 30.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/433358/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 29.
# Запрос: https://habr.com/ru/search/page1/?q=python для анализа данных&target_type=posts&order=relevance страница выдачи: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/stepic/blog/309258/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/post/458930/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/post/271773/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 147.
# Получен текст по ссылке: https://www.habr.com/ru/company/sas/blog/344512/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/sbercloud/news/t/584084/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/sibur_official/news/t/593027/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/500952/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 18.
# Получен текст по ссылке: https://www.habr.com/ru/post/246941/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/post/491326/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/560146/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/post/693402/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/442516/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 26.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/700082/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/500426/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 33.
# Получен текст по ссылке: https://www.habr.com/ru/post/323516/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/666862/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/post/695556/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/512208/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/post/583304/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/post/501492/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Запрос: https://habr.com/ru/search/page2/?q=python для анализа данных&target_type=posts&order=relevance страница выдачи: 2
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/559388/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/504900/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/595807/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/post/279213/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 20.
# Получен текст по ссылке: https://www.habr.com/ru/post/582840/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/post/654407/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/post/658225/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/post/661657/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/binarydistrict/blog/422463/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/309580/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/349968/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/588190/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/589593/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/post/495404/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/post/549376/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/post/593535/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/post/453094/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -18.
# Получен текст по ссылке: https://www.habr.com/ru/post/661285/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/company/dataart/blog/531808/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/post/704988/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Запрос: https://habr.com/ru/search/page3/?q=python для анализа данных&target_type=posts&order=relevance страница выдачи: 3
# Получен текст по ссылке: https://www.habr.com/ru/post/706624/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/company/ods/blog/348260/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 39.
# Получен текст по ссылке: https://www.habr.com/ru/company/wirex/blog/406363/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/nlmk/blog/645943/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701588/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/551000/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/210160/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 33.
# Получен текст по ссылке: https://www.habr.com/ru/company/ods/blog/327242/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 51.
# Получен текст по ссылке: https://www.habr.com/ru/post/565782/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): -1.
# Получен текст по ссылке: https://www.habr.com/ru/company/skypro/blog/579278/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/intersystems/blog/486984/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/post/500498/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/post/229667/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 54.
# Получен текст по ссылке: https://www.habr.com/ru/post/501338/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 28.
# Получен текст по ссылке: https://www.habr.com/ru/company/visiology/blog/580284/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/post/280238/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 22.
# Получен текст по ссылке: https://www.habr.com/ru/post/350952/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/532622/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/457354/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 38.
# Получен текст по ссылке: https://www.habr.com/ru/post/669980/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Запрос: https://habr.com/ru/search/page4/?q=python для анализа данных&target_type=posts&order=relevance страница выдачи: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/dsec/blog/685920/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 26.
# Получен текст по ссылке: https://www.habr.com/ru/company/beeline/blog/274921/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -1.
# Получен текст по ссылке: https://www.habr.com/ru/post/270895/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 29.
# Получен текст по ссылке: https://www.habr.com/ru/post/196560/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 90.
# Получен текст по ссылке: https://www.habr.com/ru/company/southbridge/news/t/666476/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/post/205944/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 142.
# Получен текст по ссылке: https://www.habr.com/ru/company/it_people/blog/228067/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 35.
# Получен текст по ссылке: https://www.habr.com/ru/post/351232/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/418823/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 51.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/328404/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 66.
# Получен текст по ссылке: https://www.habr.com/ru/post/337494/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/cloud_mts/blog/418909/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/company/edison/blog/480716/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/540526/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/558146/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillbox/blog/570472/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/683880/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 20.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/501924/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 41.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/586360/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 57.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/589367/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Запрос: https://habr.com/ru/search/page5/?q=python для анализа данных&target_type=posts&order=relevance страница выдачи: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/700474/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 27.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/701982/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/post/206736/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 25.
# Получен текст по ссылке: https://www.habr.com/ru/post/230493/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 35.
# Получен текст по ссылке: https://www.habr.com/ru/post/233009/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 35.
# Получен текст по ссылке: https://www.habr.com/ru/post/245491/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -13.
# Получен текст по ссылке: https://www.habr.com/ru/post/258079/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/rambler_and_co/blog/258371/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/post/320590/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 34.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/330606/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -20.
# Получен текст по ссылке: https://www.habr.com/ru/post/426699/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillbox/blog/438960/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/post/464113/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 22.
# Получен текст по ссылке: https://www.habr.com/ru/company/wolfram/blog/471814/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Получен текст по ссылке: https://www.habr.com/ru/post/505510/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/514538/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 26.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/519816/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/574736/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/wunderfund/blog/581994/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/post/587480/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Запрос: https://habr.com/ru/search/page1/?q=python в аналитике больших данных&target_type=posts&order=relevance страница выдачи: 1
# Получен текст по ссылке: https://www.habr.com/ru/company/habr_career/blog/456746/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/company/netologyru/news/t/594683/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/659657/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/nix/blog/413269/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/smileexpo/blog/428223/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/313162/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/company/dell_technologies/blog/247669/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/agima/blog/492204/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/332688/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 33.
# Получен текст по ссылке: https://www.habr.com/ru/company/geekfactor/blog/689094/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/post/701794/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/349968/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/326762/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/562266/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/company/bigdataplatform/blog/673098/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/intel/blog/337056/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 12.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/519346/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/541882/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/549768/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/X5Tech/blog/653571/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Запрос: https://habr.com/ru/search/page2/?q=python в аналитике больших данных&target_type=posts&order=relevance страница выдачи: 2
# Получен текст по ссылке: https://www.habr.com/ru/post/661657/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/beeline/blog/270619/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/sap/blog/321156/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/jugru/blog/336866/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 32.
# Получен текст по ссылке: https://www.habr.com/ru/post/551652/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/post/596479/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/677696/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 25.
# Получен текст по ссылке: https://www.habr.com/ru/post/542718/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/avito/blog/573734/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 19.
# Получен текст по ссылке: https://www.habr.com/ru/company/jugru/blog/568638/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 29.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/556962/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/501492/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/post/566568/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/559388/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/579838/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 29.
# Получен текст по ссылке: https://www.habr.com/ru/post/351440/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/epam_systems/blog/495478/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/669980/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/post/674476/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/post/227111/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Запрос: https://habr.com/ru/search/page3/?q=python в аналитике больших данных&target_type=posts&order=relevance страница выдачи: 3
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/452746/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/company/piter/blog/657351/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/340806/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/company/netologyru/blog/494808/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex/blog/353546/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 34.
# Получен текст по ссылке: https://www.habr.com/ru/company/pixonic/blog/414921/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 42.
# Получен текст по ссылке: https://www.habr.com/ru/post/227135/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 42.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillbox/blog/420819/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/company/factory5/blog/569066/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): -2.
# Получен текст по ссылке: https://www.habr.com/ru/company/goto/blog/427489/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/ruvds/blog/528030/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 28.
# Получен текст по ссылке: https://www.habr.com/ru/post/530406/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/post/567582/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): -2.
# Получен текст по ссылке: https://www.habr.com/ru/post/706624/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 10.
# Получен текст по ссылке: https://www.habr.com/ru/post/225589/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 38.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/459354/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 11.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/520540/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Получен текст по ссылке: https://www.habr.com/ru/company/visiology/blog/536734/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Получен текст по ссылке: https://www.habr.com/ru/company/skypro/blog/579278/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/visiology/blog/580284/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Запрос: https://habr.com/ru/search/page4/?q=python в аналитике больших данных&target_type=posts&order=relevance страница выдачи: 4
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/584810/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 13.
# Получен текст по ссылке: https://www.habr.com/ru/company/it_people/blog/332870/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillbox/blog/443412/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -15.
# Получен текст по ссылке: https://www.habr.com/ru/company/lamoda/blog/518620/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/company/T1Holding/blog/324124/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 23.
# Получен текст по ссылке: https://www.habr.com/ru/company/newprolab/blog/340582/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/habr_career/blog/454182/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 17.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/528232/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/555706/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 6.
# Получен текст по ссылке: https://www.habr.com/ru/post/557736/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/X5Tech/blog/564664/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/otus/blog/701588/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/post/532622/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 3.
# Получен текст по ссылке: https://www.habr.com/ru/company/rostelecom/blog/677284/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 14.
# Получен текст по ссылке: https://www.habr.com/ru/post/223903/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 39.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/425473/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 30.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/436996/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 28.
# Получен текст по ссылке: https://www.habr.com/ru/post/490114/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/post/506114/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/508992/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): -7.
# Запрос: https://habr.com/ru/search/page5/?q=python в аналитике больших данных&target_type=posts&order=relevance страница выдачи: 5
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/519702/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 18.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/550540/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 24.
# Получен текст по ссылке: https://www.habr.com/ru/company/ozontech/blog/598381/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 45.
# Получен текст по ссылке: https://www.habr.com/ru/company/garage8/blog/707180/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 8.
# Получен текст по ссылке: https://www.habr.com/ru/company/lesta_studio/blog/215189/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 16.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/551000/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 4.
# Получен текст по ссылке: https://www.habr.com/ru/company/stc_spb/blog/594483/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/656777/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
# Получен текст по ссылке: https://www.habr.com/ru/post/684418/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 2.
# Получен текст по ссылке: https://www.habr.com/ru/company/iticapital/blog/331940/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 9.
# Получен текст по ссылке: https://www.habr.com/ru/company/oleg-bunin/blog/358984/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 52.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/539060/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 18.
# Получен текст по ссылке: https://www.habr.com/ru/company/neoflex/blog/586056/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 7.
# Получен текст по ссылке: https://www.habr.com/ru/company/vtb/blog/691530/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 5.
# Получен текст по ссылке: https://www.habr.com/ru/company/skillfactory/blog/536012/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 20.
# Получен текст по ссылке: https://www.habr.com/ru/company/netologyru/blog/334914/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 21.
# Получен текст по ссылке: https://www.habr.com/ru/company/yandex_praktikum/news/t/672670/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/post/706856/. Формат версии шаблона: 2.
# Поставлено пользователями лайков(+)/дизлайков(-): 0.
# Получен текст по ссылке: https://www.habr.com/ru/company/productstar/blog/509988/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 1.
# Получен текст по ссылке: https://www.habr.com/ru/company/vk/blog/671642/. Формат версии шаблона: 1.
# Поставлено пользователями лайков(+)/дизлайков(-): 15.
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...
# 187  2020-09-19  Учимся обращаться к данным и запрашивать их пр...  https://www.habr.com/ru/company/piter/blog/519...  Привет, Хабр!\n\r\nСовсем недавно у нас вышла ...     4
# 188  2021-08-26  Анализируем данные с помощью визуализации: рис...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, я Катя, системный аналитик в Ozon. Одн...    16
# 189  2021-10-11  Разбираемся с параллельными и конкурентными вы...  https://www.habr.com/ru/company/wunderfund/blo...  Я собираюсь рассказать историю о еде, раскрыва...    23
# 190  2021-12-17  Заметки по языку R | Часть 2: Используем синта...               https://www.habr.com/ru/post/587480/  Заметки по языку R - это серия статей, в котор...     6
# 191  2019-06-19  Большие данные — большая ответственность, боль...  https://www.habr.com/ru/company/habr_career/bl...  \n\r\nТермин Big Data подпорчен современным фа...    23
# 192  2022-04-07  17 лучших инструментов и технологий для работы...  https://www.habr.com/ru/company/otus/blog/659657/  Мир больших данных становится только еще больш...     7
# 193  2018-06-05  Как машины анализируют большие данные: введени...   https://www.habr.com/ru/company/nix/blog/413269/  \n\nПеревод How Machines Make Sense of Big Dat...    19
# 194  2018-10-30                       Города и их «большие данные»  https://www.habr.com/ru/company/smileexpo/blog...  О чем рассказывают «большие данные» города? Ка...     8
# 195  2016-10-20  Много ли надо, чтобы сделать стартап с использ...  https://www.habr.com/ru/company/newprolab/blog...  Предположим, вы хотите создать приложение, кот...    10
# 196  2015-01-13  Рецепт «Быстрых данных» на основе решения для ...  https://www.habr.com/ru/company/dell_technolog...  \nИсточник изображения\n\nПри обсуждении работ...     7
# 197  2020-03-13  Как обойти ошибки при построении отчетности в ...  https://www.habr.com/ru/company/agima/blog/492...  \n\r\nЗа красивыми и понятными дашбордами Powe...     8
# 198  2017-07-10  Лекция о двух библиотеках Яндекса для работы с...  https://www.habr.com/ru/company/yandex/blog/33...  Пару недель назад в Яндексе прошла встреча PyD...    33
# 199  2022-10-05  Большим данным настал конец. Databricks, Snowf...  https://www.habr.com/ru/company/geekfactor/blo...  Тридцать восемь миллиардов долларов — это не к...     1
# 200  2022-11-27  Анализ больших данных в Excel: используем свод...               https://www.habr.com/ru/post/701794/  Всем привет! Меня зовут Сергей Коньков - я раб...     9
# 201  2017-04-18  «Big Data — это понятно и просто» — интервью с...  https://www.habr.com/ru/company/newprolab/blog...  Хабр, привет! Мы взяли интервью у выпускника п...     4
# 202  2021-06-11  Майним еще больше данных: настраиваем сбор рек...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, меня зовут Маша, я работаю маркетингов...     6
# 203  2022-06-24  Лучше, чем специалист по данным: инженер-анали...  https://www.habr.com/ru/company/bigdataplatfor...  Не так давно нам попался материал BBC, в котор...     0
# 204  2017-09-05  BigDL: глубинное обучение — к услугам пользова...  https://www.habr.com/ru/company/intel/blog/337...  Большие данные и их анализ играют важнейшую ро...    12
# 205  2020-09-16     HDTree: настраиваемое дерево решений на Python  https://www.habr.com/ru/company/skillfactory/b...  \r\nПредставляем настраиваемую и интерактивную...    17
# 206  2021-02-11  SQL для аналитики — рейтинг прикладных задач с...  https://www.habr.com/ru/company/otus/blog/541882/  Привет, Хабр! У кого из вас black belt на sql-...    19
# 207  2021-03-31  Книга «Роман с Data Science. Как монетизироват...  https://www.habr.com/ru/company/piter/blog/549...   Привет, Хаброжители! Мы сдали в типографию но...     4
# 208  2022-02-26                            Школа аналитиков данных  https://www.habr.com/ru/company/X5Tech/blog/65...  X5 Tech приглашает студентов и выпускников вуз...     2
# 209  2015-11-11  Как мы учим машинному обучению и анализу данны...  https://www.habr.com/ru/company/beeline/blog/2...  \n\r\nПосле длительной подготовки, подборки ма...     7
# 210  2017-02-06  Как платформа SAP HANA работает с большими дан...   https://www.habr.com/ru/company/sap/blog/321156/  Привет, Хабр! В прошлой статье мы рассказали п...    11
# 211  2017-08-31  Big Data и Одноклассники: как поступают с данн...  https://www.habr.com/ru/company/jugru/blog/336...  У Одноклассников не отнять главного — это втор...    32
# 212  2021-04-09  Большие данные, хакатон с «Норникелем» и метал...               https://www.habr.com/ru/post/551652/  Привет, Хабр! Тема этой статьи — большие данны...     2
# 213  2021-12-18  Пастух больших данных: как мы используем Azure...               https://www.habr.com/ru/post/596479/  Многие в ходе проектов сталкиваются с проблемо...     0
# 214  2022-07-20  Голосовые приложения для Маруси: идеи и разраб...    https://www.habr.com/ru/company/vk/blog/677696/  Привет,  Хабр! В прошлом году мы в Just AI про...    25
# 215  2021-02-16      Обзор современных инструментов дата-аналитика               https://www.habr.com/ru/post/542718/  \n\r\nСразу уточню, что видов аналитиков очень...     0
# 216  2021-08-23  Аналитики данных в Авито: ожидания и спектр задач  https://www.habr.com/ru/company/avito/blog/573...  Привет, я Дина Симкина, директор по аналитике ...    19
# 217  2021-08-06  Обзор технологий хранения больших данных. Плюс...  https://www.habr.com/ru/company/jugru/blog/568...  Если вы собираетесь построить или перестроить ...    29
# 218  2021-05-12  Книга «Роман с Data Science. Как монетизироват...  https://www.habr.com/ru/company/piter/blog/556...   Привет, Хаброжители! Как выжать все из своих ...     4
# 219  2021-07-07        Диаграмма Сэнкей (Sankey diagram) на Python               https://www.habr.com/ru/post/566568/  Я занимаюсь аналитикой данных в Aliradar. Мы н...    16
# 220  2021-09-24  Геоаналитика с помощью Python и открытых данны...               https://www.habr.com/ru/post/579838/  Каждый бизнес желает знать, где сидит фазан це...    29
# 221  2018-03-19  Как создать приложение c 3D аналитикой для iPh...               https://www.habr.com/ru/post/351440/  \n\r\nСуществует множество трендов и направлен...     4
# 222  2020-04-07  Тестировщик больших и маленьких данных: тренды...  https://www.habr.com/ru/company/epam_systems/b...  Всем привет, меня зовут Александр, и я Data Qu...     4
# 223  2022-06-30  Мистика культурных ценностей Петербурга глазам...               https://www.habr.com/ru/post/674476/  На днях мне позвонил друг и сказал, что хочет ...     7
# 224  2014-06-23  HP Vertica, проектирование хранилища данных, б...               https://www.habr.com/ru/post/227111/  UPD: Продолжение статьи по ссылке — habrahabr....    15
# 225  2019-05-21  Книга «Искусство программирования на R. Погруж...  https://www.habr.com/ru/company/piter/blog/452...   Привет, Хаброжители! Многие пользователи испо...    14
# 226  2022-03-25  Сеть данных: как уравновесить централизацию и ...  https://www.habr.com/ru/company/piter/blog/657...  Архитектура сети данных (data mesh) распределя...     3
# 227  2017-10-24  “Главный вызов — это кадровый голод” — панельн...  https://www.habr.com/ru/company/newprolab/blog...  Привет, Хабр! Публикуем заключительную часть о...     5
# 228  2020-04-01  Продуктовый аналитик: что делает, сколько зара...  https://www.habr.com/ru/company/netologyru/blo...  Продуктовый аналитик — мостик между бизнесом и...     6
# 229  2018-04-15  JupyterHub, или как управлять сотнями пользова...  https://www.habr.com/ru/company/yandex/blog/35...  Платформа Jupyter позволяет начинающим разрабо...    34
# 230  2018-06-24  Допинг для аналитики: почему стоит обратить вн...  https://www.habr.com/ru/company/pixonic/blog/4...  Все рано или поздно приходят к аналитике за да...    42
# 231  2014-06-22  Дайджест статей по анализу данных №3 (09.06.20...               https://www.habr.com/ru/post/227135/   \r\nДобрый день, уважаемые читатели.\r\nПроле...    42
# 232  2018-08-21  Топ-10 инструментов Python для машинного обуче...  https://www.habr.com/ru/company/skillbox/blog/...   \n\r\nPython — один из наиболее популярных яз...     6
# 233  2021-07-22  Платформы анализа данных: что они умеют и как ...  https://www.habr.com/ru/company/factory5/blog/...  Рынок ИТ- продуктов переполнен предложениями п...    -2
# 234  2018-10-24  ДомоДанные: как анализ данных используется в а...  https://www.habr.com/ru/company/goto/blog/427489/  Преподавали мы в GoTo свои нейроночки, XGBoos’...     3
# 235  2020-11-14  Профессия системный аналитик: развитие сообщес...  https://www.habr.com/ru/company/ruvds/blog/528...  \r\nНедавно на нашем ютуб-канале выступил Алек...    28
# 236  2020-11-29            Что и кому должен продуктовый аналитик?               https://www.habr.com/ru/post/530406/  \nЧасть 1\n\r\nПоследние несколько месяцев я п...     4
# 237  2021-07-16  Большая подборка телеграмм-каналов для аналитиков               https://www.habr.com/ru/post/567582/  Работа аналитика требует постоянного пополнени...    -2
# 238  2014-06-08  Дайджест статей по анализу данных №2 (26.05.20...               https://www.habr.com/ru/post/225589/   Добрый день, уважаемые читатели.\r\nПредставл...    38
# 239  2019-07-09  В чем разница между исследователем данных и ст...  https://www.habr.com/ru/company/otus/blog/459354/  Всем привет. Открыт набор на новый курс от Otu...    11
# 240  2020-09-25  Сколько зарабатывает аналитик данных: обзор за...  https://www.habr.com/ru/company/skillfactory/b...  \r\nПривет, Хабр! 28 сентября Skillfactory зап...    15
# 241  2021-03-04  Бесплатный удобный ETL инструмент с открытым к...  https://www.habr.com/ru/company/visiology/blog...  Мы давно ищем идеальный ETL инструмент для наш...    15
# 242  2021-10-22              Зарплаты в Python за последние 10 лет  https://www.habr.com/ru/company/skillfactory/b...  2021 год — знаковый для Python: в рейтинге поп...    13
# 243  2017-07-12  Интервью с программистом из Тинькофф Банка Анд...  https://www.habr.com/ru/company/it_people/blog...  Серию интервью с докладчиками PyCon Russia про...     7
# 244  2019-03-12  Почему программисты продолжают использовать мн...  https://www.habr.com/ru/company/skillbox/blog/...  \n\nОт переводчика: эта статья — попытка автор...   -15
# 245  2020-09-22  Как мы оркестрируем процессы обработки данных ...  https://www.habr.com/ru/company/lamoda/blog/51...  Всем привет! Меня зовут Никита Василюк, я инже...    23
# 246  2017-03-21  Использование ArcGIS API for Python в Jupyter ...  https://www.habr.com/ru/company/T1Holding/blog...  \n\nВсем привет! Это блог компании "Техносерв"...    23
# 247  2017-10-20  “Без data engineer-а ценность модели аналитика...  https://www.habr.com/ru/company/newprolab/blog...  Привет, Хабр! Data Engineering становится все ...     7
# 248  2019-05-30  Полное интервью с деканом факультета Python в ...  https://www.habr.com/ru/company/habr_career/bl...  \n\r\nВчера мы опубликовали первый выпуск в ци...    17
# 249  2021-05-04  Перспективные архитектуры для современных инфр...  https://www.habr.com/ru/company/otus/blog/555706/  На сегодняшний день базы данных класса Massive...     6
# 250  2021-05-17  DBT: новый способ трансформации данных в The T...               https://www.habr.com/ru/post/557736/  В заключительной статье о DBT хочу поделиться ...     0
# 251  2021-06-25                               Аналитик на прокачку  https://www.habr.com/ru/company/X5Tech/blog/56...  Ни для кого не секрет, что область Data Scienc...     4
# 252  2022-08-02  Сам себе data scientist или зачем нужен анализ...  https://www.habr.com/ru/company/rostelecom/blo...  Всем привет! Меня зовут Михаил Тимофеев. Когда...    14
# 253  2014-05-23       Дайджест статей по анализу данных и big data               https://www.habr.com/ru/post/223903/   Частенько читаю Хабр и заметил что в последне...    39
# 254  2019-01-22  Завершающий курс специализации по Python от Ma...    https://www.habr.com/ru/company/vk/blog/436996/  \n\r\nPython — простой и гибкий язык, применяе...    28
# 255  2020-02-26  Яндекс.Практикум – Аналитик данных. Окончание ...               https://www.habr.com/ru/post/490114/  Первая статья здесь.\n\r\nОбучение в Яндекс.Пр...     7
# 256  2020-06-09                               Кто ты, IT-аналитик?               https://www.habr.com/ru/post/506114/  Не все работающие в IT — разработчики, да?\n\r...     4
# 257  2020-06-30  8 трюков в Python, используемых опытными прогр...  https://www.habr.com/ru/company/skillfactory/b...  \n\r\nВот восемь изящных приемов Python, котор...    -7
# 258  2020-09-18  Pysa: как избежать проблем безопасности в коде...  https://www.habr.com/ru/company/skillfactory/b...  \r\n7 августа Facebook представил Pysa — ориен...    18
# 259  2021-04-04          Все важные фичи и изменения в Python 3.10  https://www.habr.com/ru/company/skillfactory/b...  Если вам хочется попробовать все фичи великоле...    24
# 260  2021-12-28  Почему я перешёл с Python на Go: choose your f...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, Хабр! Меня зовут Саша, я бэкенд-разраб...    45
# 261  2022-12-22  Что делают дата-инженеры, когда данные сами дв...  https://www.habr.com/ru/company/garage8/blog/7...  Привет, Хабр! Меня зовут Андрей Гончаров, я да...     8
# 262  2014-03-10                   Python Meetup: январская встреча  https://www.habr.com/ru/company/lesta_studio/b...  \n\r\nВеликий и могучий Python, неформальная о...    16
# 263  2021-12-09                       Оперативная аналитика данных  https://www.habr.com/ru/company/stc_spb/blog/5...  Ночь, улица, фонарь, аптека,\r\nБлок-схема, да...     1
# 264  2022-03-23  Как в PayPal разработали Dione — Open-source-б...    https://www.habr.com/ru/company/vk/blog/656777/  \nMaksym Kaharlytsky on Unsplash\n\nКоманда VK...    15
# 265  2022-08-24  Как анализировать данные из облачных сервисов ...               https://www.habr.com/ru/post/684418/  Всем привет! Меня зовут Елена Боброва, и мы в ...     2
# 266  2017-06-29  Руководство: как использовать Python для алгор...  https://www.habr.com/ru/company/iticapital/blo...  \n\r\nМы продолжаем публикацию адаптации руков...     9
# 267  2018-05-31                           Как устроены базы данных  https://www.habr.com/ru/company/oleg-bunin/blo...  Нельзя сказать, что в этой статье вас ждут отб...    52
# 268  2021-01-27  Как предотвратить появление неверных данных в ...  https://www.habr.com/ru/company/skillfactory/b...  \r\nДля команд специалистов DS сломанные конве...    18
# 269  2021-10-28        Миграция данных из различных RDBMS в HADOOP  https://www.habr.com/ru/company/neoflex/blog/5...  В статье будет рассмотрен процесс экспорта дан...     7
# 270  2022-10-14  Школьники на «Больших вызовах-2022». Как мы ​​...   https://www.habr.com/ru/company/vtb/blog/691530/  Иногда взрослые думают, что школьные проекты —...     5
# 271  2021-01-03        6 принципов эффективной визуализации данных  https://www.habr.com/ru/company/skillfactory/b...  Ключевые принципы создания полезных и информат...    20
# 272  2017-08-04  10 типов структур данных, которые нужно знать ...  https://www.habr.com/ru/company/netologyru/blo...  Екатерина Малахова, редактор-фрилансер, специа...    21
# 273  2022-06-21  Яндекс Практикум запускает программу по матема...  https://www.habr.com/ru/company/yandex_praktik...  Яндекс Практикум разработал образовательную пр...     1
# 274  2022-12-21                    Как стать аналитиком? (и зачем)               https://www.habr.com/ru/post/706856/  В этом материале я расскажу вам о роли аналити...     0
# 275  2020-07-09   Как сменить профессию и стать крутым аналитиком?  https://www.habr.com/ru/company/productstar/bl...  Зачем нужна аналитика? На что обратить внимани...     1
# 276  2022-06-17  Создание современной платформы для работы с да...    https://www.habr.com/ru/company/vk/blog/671642/  \n\r\nКоманда VK Cloud Solutions перевела крат...    15

# %% [markdown]
# ###### Ошибки выдачи уже несуществующих материалов  поисковым движком Хабр

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %% [markdown]
# В выдаче по дате ссылка на 33 странице запроса "python для анализа данных" одного из прогонов
#
# запрос по адресу https://habr.com/ru/search/page33/?q=python для анализа данных&target_type=posts&order=date
# страница выдачи: 33
#
# новость https://www.habr.com/ru/company/JetBrains-education/news/t/647151/
#
# осущетвляет автоматический редирект на
# https://habr.com/ru/company/JetBrains-education/blog/ -пустую страница компании
# "JetBrains":

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %% [markdown]
# Ещё такая же ссылка поймана уже написанным обработчиком ошибки в функции
# ###### request_text_and_likes(url_txt):
# Запрос: https://habr.com/ru/search/page1/?q=python&target_type=posts&order=relevance страница выдачи: 1
#
# В поисковой выдаче ссылка https://www.habr.com/ru/company/epam_systems/news/t/589555/
# не адресует к конкретной информации на сайте.

# %% [markdown]
# ###### Примеры на посмотреть данные

# %%
# Записпть наскрепленное непосильным трудом Хабра на диск в CSV
df_articles.to_csv (r'habr_articles.csv', index= False )

# %%
# Записать наскрепленное непосильным трудом Хабра на диск  в формате Excel:
df_articles.to_excel (r'habr_articles.xlsx', index= False )

# %%
# Самый популярный пост из найденного:
df_articles[df_articles['Лайки'] == df_articles['Лайки'].max()]
# Согласен. Сам читал.
# Out:
#         Дата                        Заголовок                                      Ссылка                                      Текст                         Лайки
# 101  2015-11-26  Найди коррупционера. Анализ данных чиновников ...  https://www.habr.com/ru/post/271773/  Как определить чиновников, наиболее подозрител...   147

# %%
# Самый непопулярный пост:
df_articles[df_articles['Лайки'] == df_articles['Лайки'].min()]
# Out:
#         Дата                        Заголовок                                            Ссылка                                             Текст                         Лайки
# 180  2017-06-09  Набор на курс Python: почему мы думаем, что Py...  https://www.habr.com/ru/company/otus/blog/330606/  Пару дней назад мы открыли набор на один из са...  -20

# %%
# Сколько и каких постов оставили всех равнодушными:
df_articles[df_articles['Лайки'] == 0]
# Out:
#         Дата                        Заголовок                                            Ссылка                                             Текст                         Лайки
# 6    2022-03-08  Вышел мартовский релиз расширения Python для V...             https://www.habr.com/ru/news/t/654707/  Вышел выпуск расширения Python для Visual Stud...    0
# 38   2022-04-18  Онлайн-митап от руководителя практики Python U...  https://www.habr.com/ru/company/usetech/news/t...  В конце марта Мстислав Казаков, руководитель п...    0
# 126  2022-04-20  Формирование однородных групп для сплит-тестир...               https://www.habr.com/ru/post/661657/  Всем привет! Если перед вами стоит задача пров...    0
# 131  2021-11-16                         Диаграмма воронки в Python  https://www.habr.com/ru/company/otus/blog/589593/  Диаграммы воронки зачастую используются для пр...    0
# 137  2020-12-07  Thank you points: сетевой анализ социальных св...  https://www.habr.com/ru/company/dataart/blog/5...  \n\r\nСвятослав Зборовский из BI-команды DataA...    0
# 156  2022-06-07  Визуализируем данные из xml в виде социальной ...               https://www.habr.com/ru/post/669980/  Если у Вас есть данные о связях людей в XML фо...    0
# 203  2022-06-24  Лучше, чем специалист по данным: инженер-анали...  https://www.habr.com/ru/company/bigdataplatfor...  Не так давно нам попался материал BBC, в котор...    0
# 213  2021-12-18  Пастух больших данных: как мы используем Azure...               https://www.habr.com/ru/post/596479/  Многие в ходе проектов сталкиваются с проблемо...    0
# 215  2021-02-16      Обзор современных инструментов дата-аналитика               https://www.habr.com/ru/post/542718/  \n\r\nСразу уточню, что видов аналитиков очень...    0
# 250  2021-05-17  DBT: новый способ трансформации данных в The T...               https://www.habr.com/ru/post/557736/  В заключительной статье о DBT хочу поделиться ...    0
# 274  2022-12-21                    Как стать аналитиком? (и зачем)               https://www.habr.com/ru/post/706856/  В этом материале я расскажу вам о роли аналити...    0

# %%
# Какие посты имеют положительные отзывы:
df_articles[df_articles['Лайки'] > 0].sort_values('Лайки', ascending = False) # по убыванию
# Out:
#         Дата                        Заголовок                                            Ссылка                                             Текст                         Лайки
# 101  2015-11-26  Найди коррупционера. Анализ данных чиновников ...               https://www.habr.com/ru/post/271773/  Как определить чиновников, наиболее подозрител...   147
# 41   2013-12-18                                    Python на Хабре               https://www.habr.com/ru/post/205944/  Некоторое время назад, в силу определенных при...   142
# 40   2012-07-09                                   Мысли о Python 3               https://www.habr.com/ru/post/147281/  Предлагаю вашему вниманю пересказ замечательно...   108
# 160  2013-10-07   Введение в анализ сложности алгоритмов (часть 1)               https://www.habr.com/ru/post/196560/  От переводчика: данный текст даётся с незначит...    90
# 49   2014-08-28                Python, каким бы я хотел его видеть    https://www.habr.com/ru/company/vk/blog/234747/  Всем известно, что мне не нравится третья верс...    77
# 90   2013-01-27  Использование Python в многопоточном приложени...               https://www.habr.com/ru/post/167261/  Все более или менее знающие Python разработчик...    68
# 163  2017-05-15  О том, как в Instagram отключили сборщик мусор...  https://www.habr.com/ru/company/wunderfund/blo...  Отключив сборщик мусора Python (GC), который о...    66
# 68   2020-04-29  Практическое руководство по разработке бэкенд-...  https://www.habr.com/ru/company/yandex/blog/49...  Привет, меня зовут Александр Васин, я бэкенд-р...    66
# 59   2019-06-03                    Указатели в Python: в чём суть?    https://www.habr.com/ru/company/vk/blog/454324/  \r\nЕсли вы когда-нибудь работали с такими низ...    65
# 45   2013-02-03  Объединяя C++ и Python. Тонкости Boost.Python....               https://www.habr.com/ru/post/168083/  Boost.Python во всех отношениях замечательная ...    64
# 76   2021-11-01  Глобальная блокировка интерпретатора (GIL) и е...  https://www.habr.com/ru/company/wunderfund/blo...  Как вы, наверное, знаете, глобальная блокировк...    57
# 91   2013-11-11  Профилирование и отладка Python, переходим к п...    https://www.habr.com/ru/company/vk/blog/201778/  В прошлой статье мы определили понятия профили...    56
# 81   2022-08-30                 Мифы и легенды современного Python  https://www.habr.com/ru/company/evrone/blog/68...  Мы в Evrone часто сталкиваемся с легендой, что...    54
# 149  2014-07-13  Python-digest #32. Новости, интересные проекты...               https://www.habr.com/ru/post/229667/   Очередной выпуск новостей из мира Python. Мы ...    54
# 52   2017-09-07                                Что за чёрт, Python    https://www.habr.com/ru/company/vk/blog/337364/  \nНедавно мы писали о забавных, хитрых и стран...    54
# 267  2018-05-31                           Как устроены базы данных  https://www.habr.com/ru/company/oleg-bunin/blo...  Нельзя сказать, что в этой статье вас ждут отб...    52
# 56   2018-08-01                     Python — это медленно. Почему?  https://www.habr.com/ru/company/ruvds/blog/418...  В последнее время можно наблюдать рост популяр...    51
# 145  2017-04-24  Открытый курс машинного обучения. Тема 9. Анал...   https://www.habr.com/ru/company/ods/blog/327242/  Доброго дня! Мы продолжаем наш цикл статей отк...    51
# 87   2008-12-07                     Emacs и Python, Python и Emacs                https://www.habr.com/ru/post/46350/  В сети часто возникают разговоры на тему «Pyth...    48
# 260  2021-12-28  Почему я перешёл с Python на Go: choose your f...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, Хабр! Меня зовут Саша, я бэкенд-разраб...    45
# 55   2018-08-29                         Бинарные модули для Python  https://www.habr.com/ru/company/oleg-bunin/blo...  Python — классный. Мы говорим «pip install» и ...    45
# 70   2020-08-25  Разбор особенностей официального Docker-образа...  https://www.habr.com/ru/company/ruvds/blog/516...  Официальный Docker-образ Python весьма популяр...    44
# 231  2014-06-22  Дайджест статей по анализу данных №3 (09.06.20...               https://www.habr.com/ru/post/227135/   \r\nДобрый день, уважаемые читатели.\r\nПроле...    42
# 230  2018-06-24  Допинг для аналитики: почему стоит обратить вн...  https://www.habr.com/ru/company/pixonic/blog/4...  Все рано или поздно приходят к аналитике за да...    42
# 50   2015-04-02           Асинхронная работа с Tarantool на Python    https://www.habr.com/ru/company/vk/blog/254727/  На Хабре уже есть статьи о NoSQL СУБД Tarantoo...    42
# 171  2020-05-19  Как построить диаграмму Венна с 50 кругами? Ви...  https://www.habr.com/ru/company/yandex/blog/50...  Всем привет, меня зовут Фёдор Индукаев, я рабо...    41
# 53   2018-11-08         Совмещение R и Python: зачем, когда и как?   https://www.habr.com/ru/company/ods/blog/348260/  \n\r\nНаверное, многие из тех, кто занимается ...    39
# 32   2021-10-18  Intel оптимизировала библиотеку Numpy под AVX-...  https://www.habr.com/ru/company/itsumma/news/t...  \nРасположение векторного регистрового файла (...    39
# 74   2021-08-14                          Заглянем в будущее Python  https://www.habr.com/ru/company/oleg-bunin/blo...  На конференции Russian Python Week 2020 мы поо...    39
# 253  2014-05-23       Дайджест статей по анализу данных и big data               https://www.habr.com/ru/post/223903/   Частенько читаю Хабр и заметил что в последне...    39
# 155  2019-06-24    Обфускация данных для тестов производительности  https://www.habr.com/ru/company/yandex/blog/45...  Пользователи ClickHouse знают, что его главное...    38
# 82   2022-09-02  Что было в голове у Гвидо, когда он создавал P...  https://www.habr.com/ru/company/jugru/blog/686...  Источник: сайт Гвидо https://gvanrossum.github...    38
# 238  2014-06-08  Дайджест статей по анализу данных №2 (26.05.20...               https://www.habr.com/ru/post/225589/   Добрый день, уважаемые читатели.\r\nПредставл...    38
# 78   2021-12-03     Python — серьезный язык для разработки backend  https://www.habr.com/ru/company/raiffeisenbank...  Всем привет! Меня зовут Денис Аникин, я тимлид...    35
# 161  2014-06-30         PyCon Russia 2014 — два дня python-счастья  https://www.habr.com/ru/company/it_people/blog...  2-3 июня в Екатеринбурге прошла вторая междуна...    35
# 174  2014-07-21  Python-digest #33. Новости, интересные проекты...               https://www.habr.com/ru/post/230493/   Очередной выпуск новостей из мира Python. Мы ...    35
# 175  2014-09-15  Python-digest #35. Новости, интересные проекты...               https://www.habr.com/ru/post/233009/   \nДайджест был опубликован ранее, но определе...    35
# 47   2013-02-17  Путешествие исключений между C++ и Python или ...               https://www.habr.com/ru/post/169639/  В этой главе сказа про дружбу C++ и Python буд...    35
# 229  2018-04-15  JupyterHub, или как управлять сотнями пользова...  https://www.habr.com/ru/company/yandex/blog/35...  Платформа Jupyter позволяет начинающим разрабо...    34
# 179  2017-01-30  Pygest #2. Релизы, статьи, интересные проекты ...               https://www.habr.com/ru/post/320590/  \n\r\nВсем привет! \n\r\nВторой выпуск дайджес...    34
# 88   2010-03-26   Code Like a Pythonista: Idiomatic Python (part0)                https://www.habr.com/ru/post/88972/  \nОт переводчика: \n\nЯ только начал изучать P...    33
# 144  2014-01-24  Python-digest #11. Новости, интересные проекты...               https://www.habr.com/ru/post/210160/   Продолжаем собирать свежие новости, информаци...    33
# 198  2017-07-10  Лекция о двух библиотеках Яндекса для работы с...  https://www.habr.com/ru/company/yandex/blog/33...  Пару недель назад в Яндексе прошла встреча PyD...    33
# 112  2020-05-10  Python, pandas и решение трёх задач из мира Excel  https://www.habr.com/ru/company/ruvds/blog/500...  Excel — это чрезвычайно распространённый инстр...    33
# 211  2017-08-31  Big Data и Одноклассники: как поступают с данн...  https://www.habr.com/ru/company/jugru/blog/336...  У Одноклассников не отнять главного — это втор...    32
# 89   2012-08-27                            Учим Python качественно               https://www.habr.com/ru/post/150302/  Здравствуйте всем!\n\r\nРешил поделиться метод...    32
# 7    2020-03-03  В начале этого года Python сместил Java и стал...  https://www.habr.com/ru/company/itsumma/news/t...  Согласно отчету RedMonk за январь 2020 года, P...    31
# 97   2018-10-16               Конференция про Python и про общение  https://www.habr.com/ru/company/oleg-bunin/blo...  Традиционно Python используют для создания сет...    30
# 220  2021-09-24  Геоаналитика с помощью Python и открытых данны...               https://www.habr.com/ru/post/579838/  Каждый бизнес желает знать, где сидит фазан це...    29
# 48   2013-11-25                             Менеджер версий python               https://www.habr.com/ru/post/203516/  Иногда полезно держать несколько версий python...    29
# 217  2021-08-06  Обзор технологий хранения больших данных. Плюс...  https://www.habr.com/ru/company/jugru/blog/568...  Если вы собираетесь построить или перестроить ...    29
# 98   2018-12-16           Знакомство с тестированием в Python. Ч.1  https://www.habr.com/ru/company/otus/blog/433358/  Всем доброго!\n\nОт нашего стола к вашему... Т...    29
# 159  2015-11-26  Анализ изменения цен в российских интернет-маг...               https://www.habr.com/ru/post/270895/  \r\nВ последние пару лет меня достаточно сильн...    29
# 235  2020-11-14  Профессия системный аналитик: развитие сообщес...  https://www.habr.com/ru/company/ruvds/blog/528...  \r\nНедавно на нашем ютуб-канале выступил Алек...    28
# 254  2019-01-22  Завершающий курс специализации по Python от Ma...    https://www.habr.com/ru/company/vk/blog/436996/  \n\r\nPython — простой и гибкий язык, применяе...    28
# 150  2020-05-12          Внутри виртуальной машины Python. Часть 1               https://www.habr.com/ru/post/501338/  \nОглавление\n\n1 часть\n2 часть\n\nВведение\n...    28
# 172  2022-11-21  Полное руководство по модулю asyncio в Python....  https://www.habr.com/ru/company/wunderfund/blo...  Python-модуль asyncio позволяет заниматься аси...    27
# 96   2018-10-05  Автор Python больше не руководит разработкой. ...  https://www.habr.com/ru/company/oleg-bunin/blo...  Всё Python-сообщество надеется, что это не отр...    27
# 92   2014-12-25  Проектирование RESTful API с помощью Python и ...               https://www.habr.com/ru/post/246699/  В последние годы REST (REpresentational State ...    26
# 157  2022-09-13   Что мы используем для анализа Android-приложений  https://www.habr.com/ru/company/dsec/blog/685920/  Всем привет! В этой статье расскажем про инстр...    26
# 186  2020-08-10  А вы знаете о том, что в Python есть встроенна...  https://www.habr.com/ru/company/ruvds/blog/514...  Если вы — программист, то я полагаю, что вы, н...    26
# 110  2019-03-04  Руководство по использованию pandas для анализ...  https://www.habr.com/ru/company/ruvds/blog/442...  При использовании библиотеки pandas для анализ...    26
# 214  2022-07-20  Голосовые приложения для Маруси: идеи и разраб...    https://www.habr.com/ru/company/vk/blog/677696/  Привет,  Хабр! В прошлом году мы в Just AI про...    25
# 173  2013-12-20  Python-digest #7. Новости, интересные проекты,...               https://www.habr.com/ru/post/206736/  Много новостей хороших и разных о Python и жиз...    25
# 259  2021-04-04          Все важные фичи и изменения в Python 3.10  https://www.habr.com/ru/company/skillfactory/b...  Если вам хочется попробовать все фичи великоле...    24
# 246  2017-03-21  Использование ArcGIS API for Python в Jupyter ...  https://www.habr.com/ru/company/T1Holding/blog...  \n\nВсем привет! Это блог компании "Техносерв"...    23
# 191  2019-06-19  Большие данные — большая ответственность, боль...  https://www.habr.com/ru/company/habr_career/bl...  \n\r\nТермин Big Data подпорчен современным фа...    23
# 189  2021-10-11  Разбираемся с параллельными и конкурентными вы...  https://www.habr.com/ru/company/wunderfund/blo...  Я собираюсь рассказать историю о еде, раскрыва...    23
# 43   2021-01-22                             Трассировка Python GIL    https://www.habr.com/ru/company/vk/blog/538706/  \n\r\nЕсть много статей, объясняющих, для чего...    23
# 12   2019-10-31  Создатель Python Гвидо ван Россум ушел из Drop...             https://www.habr.com/ru/news/t/473926/  \n\r\nСоздатель языка программирования Python ...    23
# 245  2020-09-22  Как мы оркестрируем процессы обработки данных ...  https://www.habr.com/ru/company/lamoda/blog/51...  Всем привет! Меня зовут Никита Василюк, я инже...    23
# 63   2019-11-26    56 проектов на Python с открытым исходным кодом  https://www.habr.com/ru/company/edison/blog/47...  \n\n1. Flask\r\nЭто микро-фреймворк, написанны...    23
# 58   2018-10-03                                Python 3 в Facebook  https://www.habr.com/ru/company/otus/blog/425233/  Всем привет!\n\r\nЗапустили юбилейный пятый по...    23
# 46   2013-02-10  Конвертация типов в Boost.Python. Делаем преоб...               https://www.habr.com/ru/post/168827/  Данная статья не является продолжением повеств...    23
# 183  2019-08-19  «САПР для всех, даром, и пусть никто не уйдет…...               https://www.habr.com/ru/post/464113/  Возможно, вам уже ранее попадались мои заметки...    22
# 152  2016-03-26                      Web Scraping с помощью python               https://www.habr.com/ru/post/280238/  Введение\r\nНедавно заглянув на КиноПоиск, я о...    22
# 19   2020-09-16  Астрономам порекомендовали меньше использовать...             https://www.habr.com/ru/news/t/519414/  \n\r\nАстрономы из Лейденской обсерватории опу...    22
# 57   2018-09-21  Python Developer Tools от Microsoft. Начало ра...  https://www.habr.com/ru/company/microsoft/blog...  Последние несколько лет специалисты Microsoft ...    21
# 80   2021-12-29  TalkPython: лучшие пакеты Python по итогам 202...  https://www.habr.com/ru/company/skillfactory/b...  На КДПВ в гостях у TalkPython вы видите Гвидо ...    21
# 272  2017-08-04  10 типов структур данных, которые нужно знать ...  https://www.habr.com/ru/company/netologyru/blo...  Екатерина Малахова, редактор-фрилансер, специа...    21
# 10   2020-11-13  Создатель Python Гвидо ван Россум выходит на р...             https://www.habr.com/ru/news/t/527858/  \n\r\nСоздатель языка программирования Python ...    21
# 122  2016-03-14  Pandasql vs Pandas для решения задач анализа д...               https://www.habr.com/ru/post/279213/  О чем речь?\r\nВ этой статье я бы хотела расск...    20
# 170  2022-08-29     Логирование в Python: руководство разработчика  https://www.habr.com/ru/company/wunderfund/blo...  Сталкивались ли вы с трудностями при отладке P...    20
# 271  2021-01-03        6 принципов эффективной визуализации данных  https://www.habr.com/ru/company/skillfactory/b...  Ключевые принципы создания полезных и информат...    20
# 2    2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...             https://www.habr.com/ru/news/t/498364/  \r\n20 апреля 2020 года, спустя почти десять л...    19
# 61   2019-06-27               Что я узнал про оптимизацию в Python  https://www.habr.com/ru/company/otus/blog/457942/  Всем привет. Сегодня хотим поделиться еще одни...    19
# 9    2020-06-03  Вышла версия 0.0.2 snakeware — дистрибутива Li...             https://www.habr.com/ru/news/t/505096/  \n\r\n31 мая 2020 года разработчик Джош Мур (J...    19
# 216  2021-08-23  Аналитики данных в Авито: ожидания и спектр задач  https://www.habr.com/ru/company/avito/blog/573...  Привет, я Дина Симкина, директор по аналитике ...    19
# 206  2021-02-11  SQL для аналитики — рейтинг прикладных задач с...  https://www.habr.com/ru/company/otus/blog/541882/  Привет, Хабр! У кого из вас black belt на sql-...    19
# 60   2019-06-12  Объектно-ориентированное программирование в Ja...               https://www.habr.com/ru/post/455796/  Привет, Хабр! Представляю вашему вниманию пере...    19
# 64   2020-05-26  Python.org рекомендует: Программирование для Н...  https://www.habr.com/ru/company/skillfactory/b...  Предлагаем вашему вниманию подборку материалов...    19
# 69   2020-05-27          Внутри виртуальной машины Python. Часть 2               https://www.habr.com/ru/post/501920/  \r\nПривет, Хабр. Перевод этой статьи занял на...    19
# 193  2018-06-05  Как машины анализируют большие данные: введени...   https://www.habr.com/ru/company/nix/blog/413269/  \n\nПеревод How Machines Make Sense of Big Dat...    19
# 138  2022-12-12  Как из данных узнавать о том, что в продукте ч...               https://www.habr.com/ru/post/704988/  Привет! Меня зовут Дима Дынников, я руководите...    19
# 95   2018-08-17                Почему Moscow Python Conf теперь ++  https://www.habr.com/ru/company/oleg-bunin/blo...  Собрались мы с Олегом Буниным (olegbunin) и Ва...    18
# 268  2021-01-27  Как предотвратить появление неверных данных в ...  https://www.habr.com/ru/company/skillfactory/b...  \r\nДля команд специалистов DS сломанные конве...    18
# 105  2020-05-07                Ключевые навыки Python-программиста               https://www.habr.com/ru/post/500952/  В наше динамичное время программисту необходим...    18
# 258  2020-09-18  Pysa: как избежать проблем безопасности в коде...  https://www.habr.com/ru/company/skillfactory/b...  \r\n7 августа Facebook представил Pysa — ориен...    18
# 14   2021-10-11  Python вышел на первое место рейтинга TIOBE, и...             https://www.habr.com/ru/news/t/582682/  TIOBE представила рейтинг популярности языков ...    17
# 141  2022-01-17           Python в металлургической промышленности  https://www.habr.com/ru/company/nlmk/blog/645943/  Когда речь заходит о тяжелой промышленности и ...    17
# 248  2019-05-30  Полное интервью с деканом факультета Python в ...  https://www.habr.com/ru/company/habr_career/bl...  \n\r\nВчера мы опубликовали первый выпуск в ци...    17
# 205  2020-09-16     HDTree: настраиваемое дерево решений на Python  https://www.habr.com/ru/company/skillfactory/b...  \r\nПредставляем настраиваемую и интерактивную...    17
# 86   2022-11-28  Полное руководство по модулю asyncio в Python....  https://www.habr.com/ru/company/wunderfund/blo...  Публикуем вторую часть руководства по модулю a...    17
# 77   2021-11-16     Пишем Python-расширение на Ассемблере (зачем?)  https://www.habr.com/ru/company/wunderfund/blo...  Прим. Wunder Fund: в жизни каждого человека сл...    17
# 262  2014-03-10                   Python Meetup: январская встреча  https://www.habr.com/ru/company/lesta_studio/b...  \n\r\nВеликий и могучий Python, неформальная о...    16
# 188  2021-08-26  Анализируем данные с помощью визуализации: рис...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, я Катя, системный аналитик в Ozon. Одн...    16
# 71   2020-11-19  57 отборных репозиториев для всех разработчико...  https://www.habr.com/ru/company/skillfactory/b...  Специально к старту нового потока курса «Pytho...    16
# 109  2022-10-14  Проверка автокорреляции с использованием крите...               https://www.habr.com/ru/post/693402/  Постановка задачиКритерий Дарбина-Уотсона (Dur...    16
# 5    2020-12-04  Python как компилируемый статически типизирова...             https://www.habr.com/ru/news/t/531402/  По данным широко известного в узких кругах Tio...    16
# 85   2022-10-31  Топ-30 онлайн-ресурсов для обучения детей осно...               https://www.habr.com/ru/post/696634/  Python – один из наиболее широко распространен...    16
# 219  2021-07-07        Диаграмма Сэнкей (Sankey diagram) на Python               https://www.habr.com/ru/post/566568/  Я занимаюсь аналитикой данных в Aliradar. Мы н...    16
# 276  2022-06-17  Создание современной платформы для работы с да...    https://www.habr.com/ru/company/vk/blog/671642/  \n\r\nКоманда VK Cloud Solutions перевела крат...    15
# 184  2019-10-17  WolframClientForPython | Новая клиентская библ...  https://www.habr.com/ru/company/wolfram/blog/4...  \nОригинал перевода в моём блоге\n\nПолучение ...    15
# 224  2014-06-23  HP Vertica, проектирование хранилища данных, б...               https://www.habr.com/ru/post/227111/  UPD: Продолжение статьи по ссылке — habrahabr....    15
# 240  2020-09-25  Сколько зарабатывает аналитик данных: обзор за...  https://www.habr.com/ru/company/skillfactory/b...  \r\nПривет, Хабр! 28 сентября Skillfactory зап...    15
# 241  2021-03-04  Бесплатный удобный ETL инструмент с открытым к...  https://www.habr.com/ru/company/visiology/blog...  Мы давно ищем идеальный ETL инструмент для наш...    15
# 264  2022-03-23  Как в PayPal разработали Dione — Open-source-б...    https://www.habr.com/ru/company/vk/blog/656777/  \nMaksym Kaharlytsky on Unsplash\n\nКоманда VK...    15
# 62   2019-11-11                   Зачем использовать python -m pip  https://www.habr.com/ru/company/otus/blog/475392/  И снова здравствуйте. В преддверии старта ново...    15
# 165  2018-08-01  «Python выходит в лидеры»: кто и почему его ис...  https://www.habr.com/ru/company/cloud_mts/blog...  В январе Stack Overflow провели ежегодный опро...    14
# 225  2019-05-21  Книга «Искусство программирования на R. Погруж...  https://www.habr.com/ru/company/piter/blog/452...   Привет, Хаброжители! Многие пользователи испо...    14
# 252  2022-08-02  Сам себе data scientist или зачем нужен анализ...  https://www.habr.com/ru/company/rostelecom/blo...  Всем привет! Меня зовут Михаил Тимофеев. Когда...    14
# 133  2021-03-28        Анализ и построение ROC-кривых: связь с РЛС               https://www.habr.com/ru/post/549376/  Постановка задачиМногие слышали о ROC-кривой, ...    14
# 106  2014-12-28  Анализ Вконтакте на примере книжных предпочтен...               https://www.habr.com/ru/post/246941/  \r\n Рис.  3. – Книги каких авторов из рейтинг...    14
# 22   2022-03-18  24 марта Слёрм проведёт открытый урок «Первый ...  https://www.habr.com/ru/company/southbridge/ne...  Думаете, написать свою первую программу на Pyt...    14
# 123  2021-10-11  Веб приложение для анализа и визуализации резу...               https://www.habr.com/ru/post/582840/  Выборы прошли 17-19 сентября, и новости о них ...    14
# 162  2018-04-10  Pygest #24. Новости, релизы, статьи, интересны...               https://www.habr.com/ru/post/351232/   Всем привет! Это уже двадцать четвертый выпус...    13
# 121  2021-12-16  Mito — быстрый старт на Python для тех, кто пр...  https://www.habr.com/ru/company/skillfactory/b...  Mito — это графический интерфейс для быстрой р...    13
# 132  2020-04-03  Перспективны ли просевшие акции? Проанализируе...               https://www.habr.com/ru/post/495404/  Проанализируем динамику акций аутсайдеров и ли...    13
# 178  2015-05-20  Moscow Python Meetup на тему «Async: why and w...  https://www.habr.com/ru/company/rambler_and_co...  \n\r\nДрузья, спешу сообщить, что 28 мая в 19:...    13
# 242  2021-10-22              Зарплаты в Python за последние 10 лет  https://www.habr.com/ru/company/skillfactory/b...  2021 год — знаковый для Python: в рейтинге поп...    13
# 94   2018-01-27  Python для обучения научной информатике: Модел...               https://www.habr.com/ru/post/347406/  Аннотация\r\nВ этой статье мы представляем мет...    13
# 72   2020-12-08  Книга «Простой Python. Современный стиль прогр...  https://www.habr.com/ru/company/piter/blog/528...   Привет, Хаброжители! «Простой Python» познако...    12
# 107  2020-03-06           Конспект по методам классификации данных               https://www.habr.com/ru/post/491326/  При изучении Data Science, я решил составить д...    12
# 13   2021-10-06          Вышел язык программирования Python 3.10.0             https://www.habr.com/ru/news/t/581862/  В официальном блоге языка Python заявили о вых...    12
# 136  2022-04-16  [препринт] Уход из Strava позволил мне проанал...               https://www.habr.com/ru/post/661285/  Из-за * событий в Украине попал под санкции сп...    12
# 93   2015-07-24                  R и Python — достойные соперники?  https://www.habr.com/ru/company/piter/blog/263...  \n\r\nВсем доброй пятницы, дорогие читатели!\n...    12
# 204  2017-09-05  BigDL: глубинное обучение — к услугам пользова...  https://www.habr.com/ru/company/intel/blog/337...  Большие данные и их анализ играют важнейшую ро...    12
# 99   2016-09-06   Онлайн-программа по анализу данных на Stepik.org  https://www.habr.com/ru/company/stepic/blog/30...  Осень 2016 года выдастся насыщенной: СПбАУ РАН...    12
# 210  2017-02-06  Как платформа SAP HANA работает с большими дан...   https://www.habr.com/ru/company/sap/blog/321156/  Привет, Хабр! В прошлой статье мы рассказали п...    11
# 51   2015-10-23  10 приложений для изучения Python на Android-у...               https://www.habr.com/ru/post/269411/  В процессе изучения языка мы обычно пользуемся...    11
# 26   2021-09-27  «Разработчикам вход запрещен» или курс «Python...  https://www.habr.com/ru/company/southbridge/ne...  Полгода назад мы анонсировали первый поток кур...    11
# 239  2019-07-09  В чем разница между исследователем данных и ст...  https://www.habr.com/ru/company/otus/blog/459354/  Всем привет. Открыт набор на новый курс от Otu...    11
# 140  2017-09-04   Анализируя криптовалютные рынки с помощью Python  https://www.habr.com/ru/company/wirex/blog/406...  Как ведут себя Биткоин-рынки? Каковы причины в...    11
# 177  2015-05-16         Moscow Python Meetup «Async: Why and When»               https://www.habr.com/ru/post/258079/  \n\r\nПривет, хочу пригласить вас на втору вст...    11
# 11   2022-10-25                                  Вышел Python 3.11             https://www.habr.com/ru/news/t/695298/  Разработчики опубликовали выпуск языка програм...    11
# 100  2019-07-09  Как студенты из Перми попали в финал междунаро...               https://www.habr.com/ru/post/458930/  Всем привет. В этой статье я расскажу о нашем ...    11
# 181  2019-04-20  Python Testing with pytest. Просто, Быстро, Эф...               https://www.habr.com/ru/post/426699/  Дальше \nСистематическое тестирование программ...    10
# 84   2022-10-24  Книга «Python без проблем: решаем реальные зад...  https://www.habr.com/ru/company/piter/blog/695...   Привет, Хаброжители!\n\r\nКомпьютер способен ...    10
# 127  2018-09-07     Изучаем климат городов России с помощью Python  https://www.habr.com/ru/company/binarydistrict...  На Python можно работать с данными и визуализи...    10
# 195  2016-10-20  Много ли надо, чтобы сделать стартап с использ...  https://www.habr.com/ru/company/newprolab/blog...  Предположим, вы хотите создать приложение, кот...    10
# 153  2018-03-12       Тестирование проектов C/C++ с помощью Python               https://www.habr.com/ru/post/350952/  Введение\r\nХорошо известна возможность интегр...    10
# 139  2022-12-20  50+ бесплатных курсов и ресурсов по аналитике ...               https://www.habr.com/ru/post/706624/  Всем привет, меня зовут Маруся, я аналитик дан...    10
# 1    2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...  https://www.habr.com/ru/company/southbridge/ne...  Курс нацелен дать максимальную пользу, поэтому...    10
# 4    2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...  https://www.habr.com/ru/company/southbridge/ne...  19 января Слёрм проведёт открытый урок «Пишем ...    10
# 119  2021-05-28  Clustergram: визуализация кластерного анализа ...  https://www.habr.com/ru/company/skillfactory/b...  В этой статье, переводом которой мы решили под...    10
# 200  2022-11-27  Анализ больших данных в Excel: используем свод...               https://www.habr.com/ru/post/701794/  Всем привет! Меня зовут Сергей Коньков - я раб...     9
# 128  2016-09-09  Анализ данных с электросчетчика Eastron SDM220...               https://www.habr.com/ru/post/309580/  Всем привет. В статье на geektimes я рассказыв...     9
# 29   2022-05-24  Дайджест Слёрма: тест на уровень кунг-фу по Py...  https://www.habr.com/ru/company/southbridge/ne...  Сделали для вас подборку свежих статей и выгод...     9
# 28   2022-02-04  В Visual Studio Code добавили новые возможност...             https://www.habr.com/ru/news/t/649717/  В блоге Microsoft сообщили о нововведениях пла...     9
# 266  2017-06-29  Руководство: как использовать Python для алгор...  https://www.habr.com/ru/company/iticapital/blo...  \n\r\nМы продолжаем публикацию адаптации руков...     9
# 0    2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...  https://www.habr.com/ru/company/southbridge/ne...  21 декабря Слёрм проведёт открытый урок «ChatO...     9
# 124  2022-03-04        Основы теории вероятностей с помощью Python               https://www.habr.com/ru/post/654407/  Привет, Хабр! Я очень долго собирался с мыслям...     9
# 164  2017-09-08  Использование Python для обработки в реальном ...               https://www.habr.com/ru/post/337494/  Постановка задачи\r\nЦифровые и аналоговые дат...     9
# 142  2022-11-29  33 питона: зоопарк позиций, которые требуют зн...  https://www.habr.com/ru/company/otus/blog/701588/  ПредисловиеВ прошлом году передо мной встала з...     9
# 166  2019-12-17                        Matlab vs. Julia vs. Python  https://www.habr.com/ru/company/edison/blog/48...  Я использовал MATLAB более 25 лет. (А до этого...     9
# 194  2018-10-30                       Города и их «большие данные»  https://www.habr.com/ru/company/smileexpo/blog...  О чем рассказывают «большие данные» города? Ка...     8
# 66   2020-04-03  Создание Python-обвязки для библиотек, написан...               https://www.habr.com/ru/post/495480/  Иногда во время работы над проектом на языке P...     8
# 24   2022-08-03   Последний поток Python для инженеров в этом году  https://www.habr.com/ru/company/southbridge/ne...  29 августа мы запускаем 4 поток курса «Python ...     8
# 42   2020-02-05                 Python Gateway в InterSystems IRIS  https://www.habr.com/ru/company/intersystems/b...  Эта статья посвящена Python Gateway — комьюнит...     8
# 261  2022-12-22  Что делают дата-инженеры, когда данные сами дв...  https://www.habr.com/ru/company/garage8/blog/7...  Привет, Хабр! Меня зовут Андрей Гончаров, я да...     8
# 108  2021-06-03  Новая система автоматически очищает массивы не...  https://www.habr.com/ru/company/skillfactory/b...  Специально к старту курса о Data Science мы пе...     8
# 129  2018-02-26  Как собрать сильную команду аналитиков и инжен...  https://www.habr.com/ru/company/newprolab/blog...  В первой части мы рассмотрели, как в компании ...     8
# 103  2021-10-18  AI Journey Contest 2021: какие задачи мы подго...  https://www.habr.com/ru/company/sbercloud/news...  Нарисовать карту лесных пожаров и распознать п...     8
# 197  2020-03-13  Как обойти ошибки при построении отчетности в ...  https://www.habr.com/ru/company/agima/blog/492...  \n\r\nЗа красивыми и понятными дашбордами Powe...     8
# 30   2022-10-11  Прокачаться в асинхронном программировании на ...  https://www.habr.com/ru/company/southbridge/ne...  Через два дня стартует курс по асинхронному пр...     7
# 147  2021-09-22  Что почитать аналитику данных: 5 книг для само...  https://www.habr.com/ru/company/skypro/blog/57...  Аналитик данных — профессия перспективная, и с...     7
# 196  2015-01-13  Рецепт «Быстрых данных» на основе решения для ...  https://www.habr.com/ru/company/dell_technolog...  \nИсточник изображения\n\nПри обсуждении работ...     7
# 223  2022-06-30  Мистика культурных ценностей Петербурга глазам...               https://www.habr.com/ru/post/674476/  На днях мне позвонил друг и сказал, что хочет ...     7
# 209  2015-11-11  Как мы учим машинному обучению и анализу данны...  https://www.habr.com/ru/company/beeline/blog/2...  \n\r\nПосле длительной подготовки, подборки ма...     7
# 243  2017-07-12  Интервью с программистом из Тинькофф Банка Анд...  https://www.habr.com/ru/company/it_people/blog...  Серию интервью с докладчиками PyCon Russia про...     7
# 247  2017-10-20  “Без data engineer-а ценность модели аналитика...  https://www.habr.com/ru/company/newprolab/blog...  Привет, Хабр! Data Engineering становится все ...     7
# 67   2020-04-04  Создание Python-обвязки для библиотек, написан...               https://www.habr.com/ru/post/495636/  В первой части статьи мы рассмотрели основы ра...     7
# 34   2022-06-27  В стороннем официальном репозитории Python был...             https://www.habr.com/ru/news/t/673668/  В официальном стороннем репозитории Python был...     7
# 35   2022-09-19  Асинхронное программирование на Python для джу...  https://www.habr.com/ru/company/kts/news/t/688...  Привет!3 октября начинается 3-й поток нашего ф...     7
# 102  2017-12-12     Приглашаем на итоги конкурса по анализу данных   https://www.habr.com/ru/company/sas/blog/344512/  \n\r\nВ эту пятницу (15 декабря) мы приглашаем...     7
# 192  2022-04-07  17 лучших инструментов и технологий для работы...  https://www.habr.com/ru/company/otus/blog/659657/  Мир больших данных становится только еще больш...     7
# 255  2020-02-26  Яндекс.Практикум – Аналитик данных. Окончание ...               https://www.habr.com/ru/post/490114/  Первая статья здесь.\n\r\nОбучение в Яндекс.Пр...     7
# 269  2021-10-28        Миграция данных из различных RDBMS в HADOOP  https://www.habr.com/ru/company/neoflex/blog/5...  В статье будет рассмотрен процесс экспорта дан...     7
# 20   2022-01-15  Разработчик предложил устроить коммунистическу...             https://www.habr.com/ru/news/t/645777/  \n\r\n14 января 2022 года разработчик jokteur ...     7
# 228  2020-04-01  Продуктовый аналитик: что делает, сколько зара...  https://www.habr.com/ru/company/netologyru/blo...  Продуктовый аналитик — мостик между бизнесом и...     6
# 44   2012-12-09  Дружим Python 3 с MS Visual C++. Строим мост в...               https://www.habr.com/ru/post/161931/  Всем доброго {daytime}!\n\r\nСегодня пришла по...     6
# 169  2021-07-30  13 проектов для Python-программистов уровня in...  https://www.habr.com/ru/company/skillbox/blog/...  Изучение основ Python — прекрасный опыт. Но эй...     6
# 249  2021-05-04  Перспективные архитектуры для современных инфр...  https://www.habr.com/ru/company/otus/blog/555706/  На сегодняшний день базы данных класса Massive...     6
# 202  2021-06-11  Майним еще больше данных: настраиваем сбор рек...  https://www.habr.com/ru/company/ozontech/blog/...  Привет, меня зовут Маша, я работаю маркетингов...     6
# 190  2021-12-17  Заметки по языку R | Часть 2: Используем синта...               https://www.habr.com/ru/post/587480/  Заметки по языку R - это серия статей, в котор...     6
# 232  2018-08-21  Топ-10 инструментов Python для машинного обуче...  https://www.habr.com/ru/company/skillbox/blog/...   \n\r\nPython — один из наиболее популярных яз...     6
# 17   2022-12-05               Python или Golang: что учить в 2023?  https://www.habr.com/ru/company/southbridge/ne...  Python и Golang — одни из самых востребованных...     6
# 270  2022-10-14  Школьники на «Больших вызовах-2022». Как мы ​​...   https://www.habr.com/ru/company/vtb/blog/691530/  Иногда взрослые думают, что школьные проекты —...     5
# 8    2022-08-19  Осталась неделя до старта 4 потока Python для ...  https://www.habr.com/ru/company/southbridge/ne...  29 августа в последний раз в этом году запусти...     5
# 21   2022-05-18  Слёрм запускает 3-дневный интенсив по Python д...  https://www.habr.com/ru/company/southbridge/ne...  24-26 июня пройдёт онлайн-интенсив для инженер...     5
# 118  2020-05-12  Повторяем когортный анализ, выполненный в Powe...               https://www.habr.com/ru/post/501492/  Добрый день уважаемые читатели! Поводом для на...     5
# 79   2021-12-20   Война или мир: используем MATLAB и Python вместе  https://www.habr.com/ru/company/etmc_exponenta...  В этом материале расскажу, как использовать MA...     5
# 54   2018-06-28  Так ли мал Alpine 3.8 Docker для Python 3 runtime               https://www.habr.com/ru/post/415513/  Совсем недавно произошёл релиз минималистичног...     5
# 227  2017-10-24  “Главный вызов — это кадровый голод” — панельн...  https://www.habr.com/ru/company/newprolab/blog...  Привет, Хабр! Публикуем заключительную часть о...     5
# 18   2022-12-14               Юбилейный поток Python для инженеров  https://www.habr.com/ru/company/southbridge/ne...  16 января весь Слёрм будет праздновать: старту...     5
# 143  2021-04-07  Как сделать полнотекстовую поисковую машину на...  https://www.habr.com/ru/company/skillfactory/b...  Полнотекстовый поиск — неотъемлемая часть наше...     4
# 27   2021-12-10  Интенсив для повышения квалификации: как испол...  https://www.habr.com/ru/company/netologyru/new...  14 декабря в Нетологии пройдёт вебинар, посвящ...     4
# 236  2020-11-29            Что и кому должен продуктовый аналитик?               https://www.habr.com/ru/post/530406/  \nЧасть 1\n\r\nПоследние несколько месяцев я п...     4
# 120  2020-07-23  Как проанализировать рынок фотостудий с помощь...               https://www.habr.com/ru/post/504900/  В интернете огромное количество открытых данны...     4
# 256  2020-06-09                               Кто ты, IT-аналитик?               https://www.habr.com/ru/post/506114/  Не все работающие в IT — разработчики, да?\n\r...     4
# 251  2021-06-25                               Аналитик на прокачку  https://www.habr.com/ru/company/X5Tech/blog/56...  Ни для кого не секрет, что область Data Scienc...     4
# 104  2021-12-02  Онлайн-чемпионат SIBUR Challenge 2021 для анал...  https://www.habr.com/ru/company/sibur_official...  Привет, Хабр!Мы с AI Community и AI Today пров...     4
# 115  2022-10-26  Регрессионный анализ в DataScience. Часть 2. П...               https://www.habr.com/ru/post/695556/  АКТУАЛЬНОСТЬ ТЕМЫВ предыдущем обзоре мы рассмо...     4
# 218  2021-05-12  Книга «Роман с Data Science. Как монетизироват...  https://www.habr.com/ru/company/piter/blog/556...   Привет, Хаброжители! Как выжать все из своих ...     4
# 167  2021-02-02   Как строить красивые графики на Python с Seaborn  https://www.habr.com/ru/company/otus/blog/540526/  Будущих студентов курса «Python Developer. Pro...     4
# 185  2020-06-05  Упрощаем работу с Check Point API с помощью Py...               https://www.habr.com/ru/post/505510/  Вся мощь взаимодействия с API раскрывается при...     4
# 187  2020-09-19  Учимся обращаться к данным и запрашивать их пр...  https://www.habr.com/ru/company/piter/blog/519...  Привет, Хабр!\n\r\nСовсем недавно у нас вышла ...     4
# 75   2021-09-21  Решил 50 задач и ответил на вопрос — Python ил...  https://www.habr.com/ru/company/timeweb/blog/5...  \n\r\nПривет, друзья!\nЯ — JavaScript-разработ...     4
# 207  2021-03-31  Книга «Роман с Data Science. Как монетизироват...  https://www.habr.com/ru/company/piter/blog/549...   Привет, Хаброжители! Мы сдали в типографию но...     4
# 39   2022-07-25  Бесплатный курс по бэкенд-разработке на Python...  https://www.habr.com/ru/company/southbridge/ne...  Как людей учат разработке? Вовлекают, дают инт...     4
# 201  2017-04-18  «Big Data — это понятно и просто» — интервью с...  https://www.habr.com/ru/company/newprolab/blog...  Хабр, привет! Мы взяли интервью у выпускника п...     4
# 222  2020-04-07  Тестировщик больших и маленьких данных: тренды...  https://www.habr.com/ru/company/epam_systems/b...  Всем привет, меня зовут Александр, и я Data Qu...     4
# 36   2022-11-08      Показываем полезное с Python meetup от Evrone  https://www.habr.com/ru/company/evrone/news/t/...  Митап завершился, а значит пора поделиться его...     4
# 221  2018-03-19  Как создать приложение c 3D аналитикой для iPh...               https://www.habr.com/ru/post/351440/  \n\r\nСуществует множество трендов и направлен...     4
# 226  2022-03-25  Сеть данных: как уравновесить централизацию и ...  https://www.habr.com/ru/company/piter/blog/657...  Архитектура сети данных (data mesh) распределя...     3
# 3    2021-07-06  Python Community Meetup 8/07: видео и материал...  https://www.habr.com/ru/company/raiffeisenbank...  Первый открытый онлайн-митап сообщества, для к...     3
# 125  2022-03-30  Маркетинговая аналитика на Python. Пишем код д...               https://www.habr.com/ru/post/658225/  RFM - классический инструмент маркетинга для с...     3
# 31   2021-09-22            Открытый вебинар «The Python Packaging»             https://www.habr.com/ru/news/t/579264/  23 сентября в 16:30 в рамках цикла открытых те...     3
# 16   2022-08-24  Python, SQL, С и Java стали самыми популярными...             https://www.habr.com/ru/news/t/684376/  Американский журнал IEEE Spectrum опубликовал ...     3
# 234  2018-10-24  ДомоДанные: как анализ данных используется в а...  https://www.habr.com/ru/company/goto/blog/427489/  Преподавали мы в GoTo свои нейроночки, XGBoos’...     3
# 114  2022-05-20  RFM-анализ для успешного сегментирования клиен...  https://www.habr.com/ru/company/otus/blog/666862/  RFM — это метод, используемый для анализа потр...     3
# 33   2021-10-20  Новый хакатон от СберЗвука для Python-разработ...             https://www.habr.com/ru/news/t/584584/  Привет, Хабр! Если вы хотите проверить свои си...     3
# 116  2020-07-31  Как проанализировать рынок фотостудий с помощь...               https://www.habr.com/ru/post/512208/  В предыдущей статье в рамках коммерческого про...     3
# 154  2020-12-12  Визуализация данных по акциям дивидендных арис...               https://www.habr.com/ru/post/532622/   В этой статье я поделюсь некоторым опытом на ...     3
# 73   2021-06-16  Почему мне так нравится использовать Python дл...  https://www.habr.com/ru/company/otus/blog/563098/      Когда дело доходит до автоматизации тестир...     2
# 23   2022-04-22  TechnoMeetsPython. Онлайн митап о Python-разра...             https://www.habr.com/ru/news/t/662437/  27 апреля в 18:00 собираем питонистов на YouTu...     2
# 37   2021-12-08  Открытый семинар: FastAPI, или как быстро доба...             https://www.habr.com/ru/news/t/594325/  9 декабря в 16:30 Виктор Бебнев (Xperience AI)...     2
# 208  2022-02-26                            Школа аналитиков данных  https://www.habr.com/ru/company/X5Tech/blog/65...  X5 Tech приглашает студентов и выпускников вуз...     2
# 151  2021-10-12  ML-модели в BI: интеграция с Python через Jupy...  https://www.habr.com/ru/company/visiology/blog...  Привет, Хабр! Мы продолжаем рассматривать конк...     2
# 212  2021-04-09  Большие данные, хакатон с «Норникелем» и метал...               https://www.habr.com/ru/post/551652/  Привет, Хабр! Тема этой статьи — большие данны...     2
# 265  2022-08-24  Как анализировать данные из облачных сервисов ...               https://www.habr.com/ru/post/684418/  Всем привет! Меня зовут Елена Боброва, и мы в ...     2
# 182  2019-02-05  Как я отказался от Ruby в пользу Python, работ...  https://www.habr.com/ru/company/skillbox/blog/...  \n\r\nПеревели для вас статью Бенуа Зен, разра...     2
# 111  2022-11-17  Три инструмента для быстрого профилирования да...  https://www.habr.com/ru/company/skillfactory/b...  Анализируйте и сводите данные быстрее с помощь...     1
# 273  2022-06-21  Яндекс Практикум запускает программу по матема...  https://www.habr.com/ru/company/yandex_praktik...  Яндекс Практикум разработал образовательную пр...     1
# 275  2020-07-09   Как сменить профессию и стать крутым аналитиком?  https://www.habr.com/ru/company/productstar/bl...  Зачем нужна аналитика? На что обратить внимани...     1
# 168  2021-05-19            Python, корреляция и регрессия: часть 3               https://www.habr.com/ru/post/558146/  Предыдущий пост см. здесь.Прежде чем перейти к...     1
# 148  2020-05-05  Создаем Python Flask сервис с актуальными данн...               https://www.habr.com/ru/post/500498/  \nНаша команда занимается созданием информацио...     1
# 130  2021-11-09                         Диаграмма воронки в Python  https://www.habr.com/ru/company/otus/blog/588190/  ВведениеДиаграммы-воронки часто используются д...     1
# 134  2021-12-05                 Детерминированный факторный анализ               https://www.habr.com/ru/post/593535/  Детерминированный факторный анализ - это метод...     1
# 263  2021-12-09                       Оперативная аналитика данных  https://www.habr.com/ru/company/stc_spb/blog/5...  Ночь, улица, фонарь, аптека,\r\nБлок-схема, да...     1
# 15   2022-06-03  «Тестирование веб-приложений на Python» — новы...  https://www.habr.com/ru/company/yandex_praktik...  Сервис онлайн-образования Яндекс Практикум зап...     1
# 199  2022-10-05  Большим данным настал конец. Databricks, Snowf...  https://www.habr.com/ru/company/geekfactor/blo...  Тридцать восемь миллиардов долларов — это не к...     1
# 117  2021-10-13              Частотный биграммный анализ на Python               https://www.habr.com/ru/post/583304/  ПредысторияПонадобилось мне для одного проекта...     1
# 25   2022-09-29  Асинхронное программирование на Python для джу...  https://www.habr.com/ru/company/southbridge/ne...  Как джуну выделиться на фоне таких же новичков...     1
# 113  2017-03-09  Полный латентно семантический анализ средствам...               https://www.habr.com/ru/post/323516/  Известные реализация латентно-семантического а...     1

# %%
# Какие посты имеют отрицательные отзывы:
df_articles[df_articles['Лайки'] < 0].sort_values('Лайки', ascending = True) # по возрастанию
# Out:
#         Дата                        Заголовок                                            Ссылка                                             Текст                         Лайки
# 180  2017-06-09  Набор на курс Python: почему мы думаем, что Py...  https://www.habr.com/ru/company/otus/blog/330606/  Пару дней назад мы открыли набор на один из са...  -20
# 135  2019-05-23           Анализ частоты появления цифр в хеше MD5               https://www.habr.com/ru/post/453094/  Все мы знаем, как выглядит хеш, но задавались ...  -18
# 244  2019-03-12  Почему программисты продолжают использовать мн...  https://www.habr.com/ru/company/skillbox/blog/...  \n\nОт переводчика: эта статья — попытка автор...  -15
# 176  2014-12-10                            Память и числа в Python               https://www.habr.com/ru/post/245491/  Hi, All. \n\r\nРанее я работал с C-подобными я...  -13
# 257  2020-06-30  8 трюков в Python, используемых опытными прогр...  https://www.habr.com/ru/company/skillfactory/b...  \n\r\nВот восемь изящных приемов Python, котор...   -7
# 83   2022-09-03  Управление несколькими версиями Python под упр...               https://www.habr.com/ru/post/686186/  Одно из моих первых разочарований при разработ...   -5
# 65   2020-01-20                Node.js VS Python: Which is Better?               https://www.habr.com/ru/post/484634/  \n\r\nIf you are landing on this page you migh...   -3
# 233  2021-07-22  Платформы анализа данных: что они умеют и как ...  https://www.habr.com/ru/company/factory5/blog/...  Рынок ИТ- продуктов переполнен предложениями п...   -2
# 237  2021-07-16  Большая подборка телеграмм-каналов для аналитиков               https://www.habr.com/ru/post/567582/  Работа аналитика требует постоянного пополнени...   -2
# 146  2021-07-02  Гибридное использование RDBMS и NoSQL подходов...               https://www.habr.com/ru/post/565782/  Эксперимент по секвенированию транскриптома (R...   -1
# 158  2016-01-15        Школа Данных «Билайн», каникулы закончились  https://www.habr.com/ru/company/beeline/blog/2...  \n\r\nПривет, Хабр!\n\r\nНадеемся, что в Новог...   -1

# %%
# Доля  положительных+никаких (True) и отрицательных (False) отзывов :
df_articles.groupby(df_articles['Лайки'] >= 0).size() / len(df_articles)
# Out:
# Лайки
# False    0.04
# True     0.96
# dtype: float64
